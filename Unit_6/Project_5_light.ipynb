# %%
import pandas as pd
import numpy as np
import json 
import os
import requests
import seaborn as sns

from pprint import pprint
from bs4 import BeautifulSoup 

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import cross_validate, learning_curve
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

from sklearn.metrics import mean_absolute_error
# from sklearn.metrics import mean_absolute_percentage_error

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# %pylab inline

pd.set_option('display.max_rows', 70) # выведем больше строк
pd.set_option('display.max_columns', 30) # выведем больше колонок
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def num_opt(row):
    if row['sample']==1:
        return train_num_opt(row.Комплектация)
    if row['sample']==0:
        return test_num_opt(row.Комплектация)

def test_num_opt(config):
    decod_config = json.loads(config[2:-2]) if config != '[]' else []
    return sum([len(opt_cat['values']) for opt_cat in decod_config])

def train_num_opt(config):
    point = "'available_options': "
    start = config.find(point)+len(point)+1
    finish = config.find("]",start)
    return len(config[start:finish].split(", "))



def preproc_sfdata(data):
    import re
    
    df = data.copy().drop(columns=['id','start_date', 'hidden', 'model','engineDisplacement'])
    
    cat_cols = ['bodyType','color','fuelType','name','numberOfDoors','vehicleConfiguration',
            'vehicleTransmission','Привод','Владельцы','ПТС']
    
    # bodyType
    df.bodyType = df.bodyType.dropna().apply(lambda x: x.split()[0]).str.lower()
    
    # brand
    df.drop(columns = ['brand'],inplace=True)
    
    # color
    color_codes = {
    '040001': 'чёрный',
    'FAFBFB': 'белый', 
    '0000CC': 'синий', 
    '200204': 'коричневый', 
    'EE1D19': 'красный', 
    'CACECB': 'серый',
    'C49648': 'бежевый', 
    '97948F': 'серебристый', 
    'FFD600': 'золотистый', 
    'FF8649': 'оранжевый', 
    '22A0F8': 'голубой',
    'FFC0CB': 'пурпурный', 
    'DEA522': 'жёлтый', 
    '007F00': 'зелёный', 
    '660099': 'фиолетовый',
    '4A2197': 'фиолетовый'}
    df.color = df.color.map(color_codes)
    
    # fuelType
    to_drop = df.index[df.fuelType=='универсал']
    df.drop(index=to_drop,inplace=True)
    
    # modelDate
    df.modelDate = df.modelDate.dropna().astype(int)
    
    # name
    df.name = df.name.apply(lambda x: x[:x.find(' ')])
    
    # numberOfDoors
    df.numberOfDoors = df.numberOfDoors.astype(int)
    
    # productionDate
    data.productionDate = data.productionDate.astype(int)

    
    # vehicleConfiguration
    df.vehicleConfiguration = df.vehicleConfiguration.str.split().apply(lambda x:x[0])
    
    # vehicleTransmission
    transmission_dict = {
    'автоматическая':'автоматическая',
    'механическая':'механическая',
    'роботизированная':'роботизированная',
    'MECHANICAL':'механическая', 
    'AUTOMATIC':'автоматическая', 
    'ROBOT':'роботизированная', 
    'VARIATOR':'автоматическая'}
    df.vehicleTransmission = df.vehicleTransmission.map(transmission_dict)
    
    # engineDisplacement
#     df.engineDisplacement = df.engineDisplacement.apply(lambda x: x.split()[0])
    
    # enginePower
    df.enginePower = df.enginePower.apply(lambda x: int(x[:-4]) if type(x)==str else int(x)) 

    # description
    df.description = df.description.str.len().fillna(-999)
    
    # mileage
    df.mileage = df.mileage 
    
    # Комплектация
    df.Комплектация = df.apply(num_opt,axis=1)
    
    # Привод
#     df.Привод = pd.get_dummies(df.Привод)
    
    # Руль
    df.drop(columns = ['Руль'],inplace=True)
    
    # Состояние
    df.drop(columns = ['Состояние'],inplace=True)
    
    # Владельцы
    df.Владельцы = df.Владельцы.fillna(0).apply(lambda x: int(x[0]) if type(x) == str else int(x))
    
    # ПТС
    owner_dict = {
    'Оригинал':'Оригинал',
    'Дубликат':'Дубликат',
    'ORIGINAL':'Оригинал',
    'DUPLICATE':'Дубликат'}
    df.ПТС = df.ПТС.fillna('Оригинал').map(owner_dict)
    
    # Таможня
    df.drop(columns = ['Таможня'],inplace=True)
    
    # Владение
    df['ownrshp_know'] = df.Владение.notna().astype(int)
    pattern_yaer = re.compile('\d+(?= (?:год|лет))')
    pattern_month = re.compile('\d+(?= мес)')
    year = lambda x: int(pattern_yaer.search(x).group(0)) if pattern_yaer.search(x) else 0
    month = lambda x: int(pattern_month.search(x).group(0)) if pattern_month.search(x) else 0
    df.Владение = df.Владение.apply(lambda x: year(x)*12 + month(x) if x==x else x).fillna(-999.)
    
    # dummy-кодирование категориальных признаков
    df = pd.get_dummies(df,columns=cat_cols)
    
    return df

def validation(X,y,model):
    '''
    Валидация модели
    '''
    model = model
#     cv_results = cross_validate(model, X, y, scoring='neg_mean_absolute_percentage_error', cv=3,)
    cv_results = cross_validate(model, X, y, scoring='neg_mean_absolute_error', cv=3,)    
    return -cv_results['test_score'].mean()

# %%
RANDOM_SEED = 42

# %%
train = pd.read_csv('./Project_5_data/all_auto_ru_09_09_2020.csv')
test = pd.read_csv('./Project_5_data/test.csv')

# y = train.price
# train.drop(columns = ['price'])

# удаление отброшенных наблюдений
train.dropna(subset=['price'],inplace=True)
train.dropna(subset=['bodyType'],inplace=True)

train['sample'] = 1  # помечаем где у нас трейн
test['sample'] = 0   # помечаем где у нас тест
test['price'] = np.NaN  # в тесте нет значения price -  пока просто заполняем np.NaN

train_reduced = train.loc[train.brand=='BMW']

data = test.append(train_reduced, sort=False).reset_index(drop=True) # объединяем
# big_data = test.append(train, sort=False).reset_index(drop=True) # объединяем

# %%
train.columns
# Out:
# Index(['bodyType', 'brand', 'color', 'fuelType', 'modelDate', 'name',
#        'numberOfDoors', 'productionDate', 'vehicleConfiguration',
#        'vehicleTransmission', 'engineDisplacement', 'enginePower',
#        'description', 'mileage', 'Комплектация', 'Привод', 'Руль', 'Состояние',
#        'Владельцы', 'ПТС', 'Таможня', 'Владение', 'price', 'start_date',
#        'hidden', 'model', 'sample'],
#       dtype='object')

# %%
X = preproc_sfdata(data)

# %% [markdown]
# ### Baseline
# Обучим на подготовленных данных модель LogisticRegression() спараметрами по умолчанию и получим значение метрики. Мы будем рассматривать эту модель как первую итерацию, первое приближение которое нужно улучшить.

# %%
X_train = X[X['sample']==1].drop(columns=['sample','price'])
X_test = X[X['sample']==0].drop(columns=['sample','price'])

y_train = X[X['sample']==1].price

# %%
validation(X_train, y_train, RandomForestRegressor())
# Out:
# C:\Users\GANSOR-PC\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\GANSOR-PC\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\GANSOR-PC\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 461089.21286554536

# %%
validation(X_train, y_train, GradientBoostingRegressor())
# Out:
# 436497.98194508004

# %%
validation(X_train, y_train, AdaBoostRegressor())
# Out:
# 898941.7227620971

# %%
validation(X_train, y_train, XGBRegressor())
# Out:
# C:\Users\GANSOR-PC\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [18:20:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\GANSOR-PC\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [18:20:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\GANSOR-PC\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [18:20:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 438209.2355100136

# %%
validation(X_train, y_train, CatBoostRegressor())
# Out:
# Learning rate set to 0.05181
# 0:	learn: 2288889.7973948	total: 1.77ms	remaining: 1.77s
# 1:	learn: 2190146.7420624	total: 3.35ms	remaining: 1.67s
# 2:	learn: 2100442.8263745	total: 4.9ms	remaining: 1.63s
# 3:	learn: 2013183.3489542	total: 6.46ms	remaining: 1.61s
# 4:	learn: 1932589.4355999	total: 8.01ms	remaining: 1.59s
# 5:	learn: 1856350.1965514	total: 9.54ms	remaining: 1.58s
# 6:	learn: 1779487.4572632	total: 11.2ms	remaining: 1.59s
# 7:	learn: 1707371.4894954	total: 13ms	remaining: 1.62s
# 8:	learn: 1635709.7617404	total: 14.7ms	remaining: 1.61s
# 9:	learn: 1572755.8801832	total: 16.2ms	remaining: 1.6s
# 10:	learn: 1510699.0264275	total: 17.8ms	remaining: 1.6s
# 11:	learn: 1453000.8389328	total: 19.3ms	remaining: 1.59s
# 12:	learn: 1395619.6969706	total: 20.9ms	remaining: 1.59s
# 13:	learn: 1342481.5786235	total: 22.5ms	remaining: 1.58s
# 14:	learn: 1295204.7413103	total: 24ms	remaining: 1.58s
# 15:	learn: 1249786.9675634	total: 25.6ms	remaining: 1.58s
# 16:	learn: 1204734.2710009	total: 27.4ms	remaining: 1.58s
# 17:	learn: 1163136.2790278	total: 29ms	remaining: 1.58s
# 18:	learn: 1122997.2386422	total: 30.5ms	remaining: 1.57s
# 19:	learn: 1089294.0183509	total: 32ms	remaining: 1.57s
# 20:	learn: 1054295.1073763	total: 33.6ms	remaining: 1.57s
# 21:	learn: 1019367.8879656	total: 35.2ms	remaining: 1.56s
# 22:	learn: 987312.5462499	total: 36.7ms	remaining: 1.56s
# 23:	learn: 956874.4214626	total: 38.3ms	remaining: 1.56s
# 24:	learn: 930819.7827379	total: 39.9ms	remaining: 1.55s
# 25:	learn: 905191.6003220	total: 41.5ms	remaining: 1.55s
# 26:	learn: 876305.2153085	total: 43.3ms	remaining: 1.56s
# 27:	learn: 853152.5598817	total: 44.9ms	remaining: 1.56s
# 28:	learn: 832574.9025546	total: 46.4ms	remaining: 1.55s
# 29:	learn: 810155.8380485	total: 48ms	remaining: 1.55s
# 30:	learn: 789431.2952402	total: 49.6ms	remaining: 1.55s
# 31:	learn: 769047.5303563	total: 51.1ms	remaining: 1.55s
# 32:	learn: 751424.3279449	total: 52.7ms	remaining: 1.54s
# 33:	learn: 731914.1720534	total: 54.2ms	remaining: 1.54s
# 34:	learn: 715382.4466009	total: 55.7ms	remaining: 1.54s
# 35:	learn: 701066.9077124	total: 57.4ms	remaining: 1.54s
# 36:	learn: 687507.8138001	total: 59ms	remaining: 1.53s
# 37:	learn: 674670.7065177	total: 60.5ms	remaining: 1.53s
# 38:	learn: 663386.2079274	total: 62.2ms	remaining: 1.53s
# 39:	learn: 652041.6651370	total: 63.7ms	remaining: 1.53s
# 40:	learn: 640491.1746028	total: 65.3ms	remaining: 1.53s
# 41:	learn: 629800.4683464	total: 66.8ms	remaining: 1.52s
# 42:	learn: 620308.0408057	total: 68.4ms	remaining: 1.52s
# 43:	learn: 612282.4219159	total: 70ms	remaining: 1.52s
# 44:	learn: 603612.8854080	total: 71.6ms	remaining: 1.52s
# 45:	learn: 595491.6298836	total: 73.4ms	remaining: 1.52s
# 46:	learn: 587133.9056847	total: 75ms	remaining: 1.52s
# 47:	learn: 580303.7382886	total: 76.6ms	remaining: 1.52s
# 48:	learn: 574622.7501540	total: 78.1ms	remaining: 1.52s
# 49:	learn: 567630.1410856	total: 79.7ms	remaining: 1.51s
# 50:	learn: 561176.1728956	total: 81.2ms	remaining: 1.51s
# 51:	learn: 556213.4892205	total: 82.9ms	remaining: 1.51s
# 52:	learn: 550507.5001324	total: 84.5ms	remaining: 1.51s
# 53:	learn: 546420.7074096	total: 86.1ms	remaining: 1.51s
# 54:	learn: 542377.8321742	total: 90.1ms	remaining: 1.55s
# 55:	learn: 538021.6781531	total: 91.7ms	remaining: 1.54s
# 56:	learn: 532748.0275695	total: 93.2ms	remaining: 1.54s
# 57:	learn: 528238.1146903	total: 94.7ms	remaining: 1.54s
# 58:	learn: 523019.6481135	total: 96.3ms	remaining: 1.54s
# 59:	learn: 519605.0953025	total: 97.9ms	remaining: 1.53s
# 60:	learn: 516301.8827046	total: 99.4ms	remaining: 1.53s
# 61:	learn: 512850.6893298	total: 101ms	remaining: 1.53s
# 62:	learn: 509609.6169401	total: 103ms	remaining: 1.53s
# 63:	learn: 506296.5738292	total: 104ms	remaining: 1.52s
# 64:	learn: 503398.1912135	total: 106ms	remaining: 1.52s
# 65:	learn: 500697.2214402	total: 107ms	remaining: 1.52s
# 66:	learn: 498170.4321033	total: 109ms	remaining: 1.52s
# 67:	learn: 495621.2311908	total: 110ms	remaining: 1.51s
# 68:	learn: 493529.1864101	total: 112ms	remaining: 1.51s
# 69:	learn: 492005.1533645	total: 114ms	remaining: 1.51s
# 70:	learn: 488436.3582112	total: 115ms	remaining: 1.5s
# 71:	learn: 486453.8605384	total: 117ms	remaining: 1.5s
# 72:	learn: 484764.7882422	total: 118ms	remaining: 1.5s
# 73:	learn: 482940.3278067	total: 120ms	remaining: 1.5s
# 74:	learn: 481205.8018174	total: 122ms	remaining: 1.5s
# 75:	learn: 479990.2079942	total: 123ms	remaining: 1.5s
# 76:	learn: 478025.9709066	total: 125ms	remaining: 1.49s
# 77:	learn: 476806.0026986	total: 126ms	remaining: 1.49s
# 78:	learn: 475838.3740955	total: 128ms	remaining: 1.49s
# 79:	learn: 474833.2032925	total: 129ms	remaining: 1.49s
# 80:	learn: 474226.2096460	total: 131ms	remaining: 1.48s
# 81:	learn: 472580.8523879	total: 132ms	remaining: 1.48s
# 82:	learn: 470875.4690534	total: 134ms	remaining: 1.48s
# 83:	learn: 468173.2801927	total: 135ms	remaining: 1.48s
# 84:	learn: 466689.8849242	total: 137ms	remaining: 1.47s
# 85:	learn: 465697.1362064	total: 138ms	remaining: 1.47s
# 86:	learn: 464135.7366713	total: 140ms	remaining: 1.47s
# 87:	learn: 461943.1382450	total: 141ms	remaining: 1.47s
# 88:	learn: 460534.9445217	total: 143ms	remaining: 1.46s
# 89:	learn: 459584.5387829	total: 144ms	remaining: 1.46s
# 90:	learn: 459235.6848073	total: 146ms	remaining: 1.46s
# 91:	learn: 458233.0488995	total: 148ms	remaining: 1.46s
# 92:	learn: 457595.5977343	total: 149ms	remaining: 1.46s
# 93:	learn: 456889.1813538	total: 151ms	remaining: 1.45s
# 94:	learn: 456560.1480745	total: 152ms	remaining: 1.45s
# 95:	learn: 455197.5165733	total: 154ms	remaining: 1.45s
# 96:	learn: 454178.5970244	total: 155ms	remaining: 1.45s
# 97:	learn: 453172.8387860	total: 157ms	remaining: 1.44s
# 98:	learn: 452240.7188889	total: 158ms	remaining: 1.44s
# 99:	learn: 451569.6307246	total: 160ms	remaining: 1.44s
# 100:	learn: 451261.3228902	total: 163ms	remaining: 1.45s
# 101:	learn: 450458.8319166	total: 165ms	remaining: 1.45s
# 102:	learn: 449955.3699838	total: 166ms	remaining: 1.45s
# 103:	learn: 448036.1382788	total: 168ms	remaining: 1.44s
# 104:	learn: 447007.3614804	total: 169ms	remaining: 1.44s
# 105:	learn: 444667.8884409	total: 171ms	remaining: 1.44s
# 106:	learn: 443892.6480965	total: 173ms	remaining: 1.44s
# 107:	learn: 443103.6091111	total: 175ms	remaining: 1.45s
# 108:	learn: 441588.0633443	total: 177ms	remaining: 1.45s
# 109:	learn: 441199.2523172	total: 179ms	remaining: 1.45s
# 110:	learn: 439783.8459154	total: 180ms	remaining: 1.44s
# 111:	learn: 438438.7457704	total: 182ms	remaining: 1.44s
# 112:	learn: 438288.5072910	total: 183ms	remaining: 1.44s
# 113:	learn: 437909.4821229	total: 185ms	remaining: 1.44s
# 114:	learn: 437213.3284918	total: 186ms	remaining: 1.43s
# 115:	learn: 434280.2150763	total: 188ms	remaining: 1.43s
# 116:	learn: 434061.7021034	total: 190ms	remaining: 1.43s
# 117:	learn: 433431.2010441	total: 192ms	remaining: 1.43s
# 118:	learn: 432306.2790182	total: 193ms	remaining: 1.43s
# 119:	learn: 430735.4745166	total: 195ms	remaining: 1.43s
# 120:	learn: 430231.8191442	total: 196ms	remaining: 1.42s
# 121:	learn: 429958.8425875	total: 198ms	remaining: 1.42s
# 122:	learn: 429302.8563472	total: 199ms	remaining: 1.42s
# 123:	learn: 427536.9736775	total: 201ms	remaining: 1.42s
# 124:	learn: 426832.6937615	total: 202ms	remaining: 1.42s
# 125:	learn: 426319.8363519	total: 204ms	remaining: 1.41s
# 126:	learn: 425886.8407657	total: 205ms	remaining: 1.41s
# 127:	learn: 425223.9691995	total: 208ms	remaining: 1.41s
# 128:	learn: 424785.6181094	total: 209ms	remaining: 1.41s
# 129:	learn: 424197.7396119	total: 211ms	remaining: 1.41s
# 130:	learn: 422754.3866049	total: 212ms	remaining: 1.41s
# 131:	learn: 422076.0452728	total: 214ms	remaining: 1.41s
# 132:	learn: 421639.5193896	total: 215ms	remaining: 1.4s
# 133:	learn: 421343.5172303	total: 217ms	remaining: 1.4s
# 134:	learn: 421066.7142800	total: 218ms	remaining: 1.4s
# 135:	learn: 420389.1857232	total: 220ms	remaining: 1.4s
# 136:	learn: 419814.1389915	total: 222ms	remaining: 1.4s
# 137:	learn: 419305.0818147	total: 223ms	remaining: 1.39s
# 138:	learn: 419143.6143949	total: 225ms	remaining: 1.39s
# 139:	learn: 418740.8603256	total: 226ms	remaining: 1.39s
# 140:	learn: 418039.5535298	total: 228ms	remaining: 1.39s
# 141:	learn: 417061.3806596	total: 229ms	remaining: 1.39s
# 142:	learn: 416220.7018872	total: 231ms	remaining: 1.39s
# 143:	learn: 415706.0289139	total: 233ms	remaining: 1.38s
# 144:	learn: 415036.3617679	total: 234ms	remaining: 1.38s
# 145:	learn: 414903.8739308	total: 236ms	remaining: 1.38s
# 146:	learn: 412948.2337682	total: 237ms	remaining: 1.38s
# 147:	learn: 412630.8298327	total: 239ms	remaining: 1.37s
# 148:	learn: 412395.8910270	total: 240ms	remaining: 1.37s
# 149:	learn: 411783.6830416	total: 242ms	remaining: 1.37s
# 150:	learn: 411657.6888370	total: 243ms	remaining: 1.37s
# 151:	learn: 410770.6588757	total: 245ms	remaining: 1.36s
# 152:	learn: 410242.7372622	total: 246ms	remaining: 1.36s
# 153:	learn: 409633.6597817	total: 248ms	remaining: 1.36s
# 154:	learn: 408926.8271882	total: 249ms	remaining: 1.36s
# 155:	learn: 408549.2675602	total: 251ms	remaining: 1.36s
# 156:	learn: 407708.5354454	total: 253ms	remaining: 1.36s
# 157:	learn: 406600.9524073	total: 254ms	remaining: 1.35s
# 158:	learn: 405907.0619462	total: 256ms	remaining: 1.35s
# 159:	learn: 405474.3986124	total: 257ms	remaining: 1.35s
# 160:	learn: 405103.3285547	total: 259ms	remaining: 1.35s
# 161:	learn: 404653.3120126	total: 260ms	remaining: 1.35s
# 162:	learn: 404306.7524413	total: 262ms	remaining: 1.34s
# 163:	learn: 403817.4805291	total: 263ms	remaining: 1.34s
# 164:	learn: 403090.1571146	total: 265ms	remaining: 1.34s
# 165:	learn: 402353.4400826	total: 267ms	remaining: 1.34s
# 166:	learn: 400404.3895282	total: 268ms	remaining: 1.34s
# 167:	learn: 399312.8562015	total: 270ms	remaining: 1.34s
# 168:	learn: 398936.1146363	total: 271ms	remaining: 1.33s
# 169:	learn: 398159.0131993	total: 273ms	remaining: 1.33s
# 170:	learn: 397068.5402755	total: 275ms	remaining: 1.33s
# 171:	learn: 396455.0920820	total: 276ms	remaining: 1.33s
# 172:	learn: 396096.5516811	total: 278ms	remaining: 1.33s
# 173:	learn: 395429.5042977	total: 279ms	remaining: 1.32s
# 174:	learn: 393499.8639407	total: 281ms	remaining: 1.32s
# 175:	learn: 393020.3399619	total: 282ms	remaining: 1.32s
# 176:	learn: 392593.7932928	total: 284ms	remaining: 1.32s
# 177:	learn: 391792.1853181	total: 285ms	remaining: 1.32s
# 178:	learn: 391202.9059818	total: 287ms	remaining: 1.32s
# 179:	learn: 389942.2130329	total: 289ms	remaining: 1.31s
# 180:	learn: 388040.2545696	total: 290ms	remaining: 1.31s
# 181:	learn: 387569.3977679	total: 292ms	remaining: 1.31s
# 182:	learn: 386463.1841696	total: 293ms	remaining: 1.31s
# 183:	learn: 385648.0603415	total: 295ms	remaining: 1.31s
# 184:	learn: 384174.1858659	total: 300ms	remaining: 1.32s
# 185:	learn: 383928.8313646	total: 302ms	remaining: 1.32s
# 186:	learn: 382818.2737198	total: 303ms	remaining: 1.32s
# 187:	learn: 382125.7810886	total: 305ms	remaining: 1.32s
# 188:	learn: 381812.1529912	total: 307ms	remaining: 1.31s
# 189:	learn: 381557.1965044	total: 308ms	remaining: 1.31s
# 190:	learn: 381050.9585889	total: 310ms	remaining: 1.31s
# 191:	learn: 380853.8304968	total: 311ms	remaining: 1.31s
# 192:	learn: 380671.4920752	total: 313ms	remaining: 1.31s
# 193:	learn: 380118.8680229	total: 314ms	remaining: 1.3s
# 194:	learn: 379763.1740886	total: 316ms	remaining: 1.3s
# 195:	learn: 379453.6899733	total: 317ms	remaining: 1.3s
# 196:	learn: 378613.0336338	total: 319ms	remaining: 1.3s
# 197:	learn: 378248.8104712	total: 320ms	remaining: 1.3s
# 198:	learn: 377431.1289058	total: 322ms	remaining: 1.29s
# 199:	learn: 376718.4714280	total: 323ms	remaining: 1.29s
# 200:	learn: 376167.7975166	total: 325ms	remaining: 1.29s
# 201:	learn: 375734.1463992	total: 326ms	remaining: 1.29s
# 202:	learn: 375404.5457286	total: 328ms	remaining: 1.29s
# 203:	learn: 373556.1355494	total: 330ms	remaining: 1.29s
# 204:	learn: 373342.9411582	total: 331ms	remaining: 1.28s
# 205:	learn: 372688.9462671	total: 333ms	remaining: 1.28s
# 206:	learn: 372228.4438285	total: 335ms	remaining: 1.28s
# 207:	learn: 371751.1291426	total: 336ms	remaining: 1.28s
# 208:	learn: 371492.1393729	total: 338ms	remaining: 1.28s
# 209:	learn: 370322.2015809	total: 340ms	remaining: 1.28s
# 210:	learn: 369543.1566783	total: 342ms	remaining: 1.28s
# 211:	learn: 368678.0753215	total: 343ms	remaining: 1.28s
# 212:	learn: 368267.0509798	total: 345ms	remaining: 1.27s
# 213:	learn: 367873.8544636	total: 347ms	remaining: 1.27s
# 214:	learn: 366475.0400955	total: 348ms	remaining: 1.27s
# 215:	learn: 366115.5322980	total: 350ms	remaining: 1.27s
# 216:	learn: 365643.6950984	total: 352ms	remaining: 1.27s
# 217:	learn: 364809.8712246	total: 353ms	remaining: 1.27s
# 218:	learn: 364561.8348551	total: 357ms	remaining: 1.27s
# 219:	learn: 364160.3553566	total: 359ms	remaining: 1.27s
# 220:	learn: 363723.7970049	total: 361ms	remaining: 1.27s
# 221:	learn: 363491.5385446	total: 362ms	remaining: 1.27s
# 222:	learn: 363161.2562759	total: 364ms	remaining: 1.27s
# 223:	learn: 362842.0118544	total: 365ms	remaining: 1.26s
# 224:	learn: 362474.5889854	total: 367ms	remaining: 1.26s
# 225:	learn: 361482.0816128	total: 368ms	remaining: 1.26s
# 226:	learn: 360649.6173544	total: 370ms	remaining: 1.26s
# 227:	learn: 360411.6585509	total: 372ms	remaining: 1.26s
# 228:	learn: 360284.7371674	total: 373ms	remaining: 1.26s
# 229:	learn: 359317.0628362	total: 375ms	remaining: 1.25s
# 230:	learn: 357842.4465204	total: 377ms	remaining: 1.25s
# 231:	learn: 357471.0760547	total: 378ms	remaining: 1.25s
# 232:	learn: 357281.0015427	total: 380ms	remaining: 1.25s
# 233:	learn: 356934.9786802	total: 381ms	remaining: 1.25s
# 234:	learn: 355961.6095818	total: 383ms	remaining: 1.25s
# 235:	learn: 355586.2109391	total: 385ms	remaining: 1.25s
# 236:	learn: 355265.8631055	total: 386ms	remaining: 1.24s
# 237:	learn: 354946.9705962	total: 388ms	remaining: 1.24s
# 238:	learn: 354767.8651274	total: 389ms	remaining: 1.24s
# 239:	learn: 354609.6089701	total: 391ms	remaining: 1.24s
# 240:	learn: 354456.2227457	total: 392ms	remaining: 1.24s
# 241:	learn: 354133.6353248	total: 394ms	remaining: 1.23s
# 242:	learn: 353266.0782150	total: 395ms	remaining: 1.23s
# 243:	learn: 352641.9837311	total: 397ms	remaining: 1.23s
# 244:	learn: 352147.6738720	total: 399ms	remaining: 1.23s
# 245:	learn: 351361.5969769	total: 400ms	remaining: 1.23s
# 246:	learn: 350686.9684964	total: 402ms	remaining: 1.23s
# 247:	learn: 349940.4349331	total: 403ms	remaining: 1.22s
# 248:	learn: 349324.4399247	total: 405ms	remaining: 1.22s
# 249:	learn: 349091.9737287	total: 407ms	remaining: 1.22s
# 250:	learn: 348781.7254046	total: 408ms	remaining: 1.22s
# 251:	learn: 348489.6588970	total: 410ms	remaining: 1.22s
# 252:	learn: 348066.6806485	total: 411ms	remaining: 1.21s
# 253:	learn: 347838.9052665	total: 413ms	remaining: 1.21s
# 254:	learn: 347694.4260560	total: 414ms	remaining: 1.21s
# 255:	learn: 347099.3117595	total: 416ms	remaining: 1.21s
# 256:	learn: 346783.4334754	total: 418ms	remaining: 1.21s
# 257:	learn: 346328.7926476	total: 419ms	remaining: 1.21s
# 258:	learn: 346145.2845627	total: 421ms	remaining: 1.2s
# 259:	learn: 346004.4054644	total: 422ms	remaining: 1.2s
# 260:	learn: 345607.8915688	total: 424ms	remaining: 1.2s
# 261:	learn: 345425.1164072	total: 425ms	remaining: 1.2s
# 262:	learn: 345158.9172142	total: 427ms	remaining: 1.2s
# 263:	learn: 345026.3991645	total: 428ms	remaining: 1.19s
# 264:	learn: 344875.2050228	total: 430ms	remaining: 1.19s
# 265:	learn: 344435.4265991	total: 431ms	remaining: 1.19s
# 266:	learn: 344057.2348247	total: 433ms	remaining: 1.19s
# 267:	learn: 343774.7422692	total: 435ms	remaining: 1.19s
# 268:	learn: 343386.8373846	total: 436ms	remaining: 1.18s
# 269:	learn: 342201.9404641	total: 438ms	remaining: 1.18s
# 270:	learn: 341947.8584593	total: 439ms	remaining: 1.18s
# 271:	learn: 341578.3418727	total: 441ms	remaining: 1.18s
# 272:	learn: 341350.0823272	total: 442ms	remaining: 1.18s
# 273:	learn: 340997.6521585	total: 444ms	remaining: 1.18s
# 274:	learn: 340592.1027341	total: 446ms	remaining: 1.17s
# 275:	learn: 340283.0112025	total: 447ms	remaining: 1.17s
# 276:	learn: 340197.5144879	total: 449ms	remaining: 1.17s
# 277:	learn: 339661.9121045	total: 450ms	remaining: 1.17s
# 278:	learn: 339049.2114472	total: 452ms	remaining: 1.17s
# 279:	learn: 338925.6555713	total: 453ms	remaining: 1.17s
# 280:	learn: 338503.8196187	total: 455ms	remaining: 1.16s
# 281:	learn: 338278.6815158	total: 456ms	remaining: 1.16s
# 282:	learn: 337847.3986933	total: 458ms	remaining: 1.16s
# 283:	learn: 337528.3390716	total: 460ms	remaining: 1.16s
# 284:	learn: 337334.6363799	total: 461ms	remaining: 1.16s
# 285:	learn: 337208.2816179	total: 463ms	remaining: 1.15s
# 286:	learn: 337129.9942583	total: 464ms	remaining: 1.15s
# 287:	learn: 336150.0255311	total: 466ms	remaining: 1.15s
# 288:	learn: 335467.5369386	total: 467ms	remaining: 1.15s
# 289:	learn: 334962.8531079	total: 469ms	remaining: 1.15s
# 290:	learn: 334667.5192273	total: 470ms	remaining: 1.15s
# 291:	learn: 334345.2496566	total: 472ms	remaining: 1.14s
# 292:	learn: 334271.2017273	total: 473ms	remaining: 1.14s
# 293:	learn: 333587.5675103	total: 475ms	remaining: 1.14s
# 294:	learn: 332473.1492522	total: 477ms	remaining: 1.14s
# 295:	learn: 332199.4268603	total: 478ms	remaining: 1.14s
# 296:	learn: 331736.5314700	total: 480ms	remaining: 1.14s
# 297:	learn: 331495.2663785	total: 481ms	remaining: 1.13s
# 298:	learn: 330973.1508700	total: 483ms	remaining: 1.13s
# 299:	learn: 330857.5368642	total: 484ms	remaining: 1.13s
# 300:	learn: 329992.8661039	total: 486ms	remaining: 1.13s
# 301:	learn: 329882.2042139	total: 487ms	remaining: 1.13s
# 302:	learn: 329572.3469594	total: 489ms	remaining: 1.12s
# 303:	learn: 329468.4026729	total: 490ms	remaining: 1.12s
# 304:	learn: 329263.3084628	total: 492ms	remaining: 1.12s
# 305:	learn: 329196.5138602	total: 494ms	remaining: 1.12s
# 306:	learn: 328991.9222998	total: 495ms	remaining: 1.12s
# 307:	learn: 328830.8753571	total: 497ms	remaining: 1.12s
# 308:	learn: 328641.0053741	total: 499ms	remaining: 1.11s
# 309:	learn: 327838.6904327	total: 500ms	remaining: 1.11s
# 310:	learn: 327378.0147138	total: 502ms	remaining: 1.11s
# 311:	learn: 327072.3915472	total: 508ms	remaining: 1.12s
# 312:	learn: 326848.8081518	total: 509ms	remaining: 1.12s
# 313:	learn: 326724.1790813	total: 511ms	remaining: 1.12s
# 314:	learn: 326215.1524846	total: 513ms	remaining: 1.11s
# 315:	learn: 326087.4481146	total: 514ms	remaining: 1.11s
# 316:	learn: 325553.1077126	total: 516ms	remaining: 1.11s
# 317:	learn: 325324.5048677	total: 517ms	remaining: 1.11s
# 318:	learn: 325079.0074564	total: 519ms	remaining: 1.11s
# 319:	learn: 324924.0091576	total: 521ms	remaining: 1.11s
# 320:	learn: 324662.1053645	total: 522ms	remaining: 1.1s
# 321:	learn: 324567.1174658	total: 524ms	remaining: 1.1s
# 322:	learn: 323791.4888380	total: 526ms	remaining: 1.1s
# 323:	learn: 323421.2331595	total: 527ms	remaining: 1.1s
# 324:	learn: 323094.0521277	total: 529ms	remaining: 1.1s
# 325:	learn: 322979.7107641	total: 530ms	remaining: 1.1s
# 326:	learn: 322818.2296920	total: 532ms	remaining: 1.09s
# 327:	learn: 322528.2600393	total: 534ms	remaining: 1.09s
# 328:	learn: 322258.3750664	total: 536ms	remaining: 1.09s
# 329:	learn: 321899.0391296	total: 538ms	remaining: 1.09s
# 330:	learn: 321179.1037529	total: 539ms	remaining: 1.09s
# 331:	learn: 320780.1057634	total: 541ms	remaining: 1.09s
# 332:	learn: 320298.7403897	total: 543ms	remaining: 1.09s
# 333:	learn: 319832.9853319	total: 544ms	remaining: 1.08s
# 334:	learn: 319752.3454197	total: 546ms	remaining: 1.08s
# 335:	learn: 319570.2359450	total: 548ms	remaining: 1.08s
# 336:	learn: 319420.3752421	total: 549ms	remaining: 1.08s
# 337:	learn: 318633.7134595	total: 551ms	remaining: 1.08s
# 338:	learn: 318395.8810026	total: 552ms	remaining: 1.08s
# 339:	learn: 318293.8000206	total: 554ms	remaining: 1.07s
# 340:	learn: 317699.0344639	total: 556ms	remaining: 1.07s
# 341:	learn: 317014.6079954	total: 557ms	remaining: 1.07s
# 342:	learn: 316663.9016117	total: 559ms	remaining: 1.07s
# 343:	learn: 316469.8317784	total: 560ms	remaining: 1.07s
# 344:	learn: 316256.0780123	total: 562ms	remaining: 1.07s
# 345:	learn: 315906.8459491	total: 564ms	remaining: 1.06s
# 346:	learn: 315621.1190091	total: 565ms	remaining: 1.06s
# 347:	learn: 315330.7565109	total: 567ms	remaining: 1.06s
# 348:	learn: 315209.6558609	total: 569ms	remaining: 1.06s
# 349:	learn: 315153.7136270	total: 570ms	remaining: 1.06s
# 350:	learn: 314931.7735034	total: 572ms	remaining: 1.06s
# 351:	learn: 314863.8174947	total: 573ms	remaining: 1.05s
# 352:	learn: 314602.0109876	total: 575ms	remaining: 1.05s
# 353:	learn: 313927.1236185	total: 576ms	remaining: 1.05s
# 354:	learn: 313604.3930259	total: 578ms	remaining: 1.05s
# 355:	learn: 313508.1813885	total: 580ms	remaining: 1.05s
# 356:	learn: 313231.6636324	total: 581ms	remaining: 1.05s
# 357:	learn: 312934.9885991	total: 583ms	remaining: 1.04s
# 358:	learn: 312644.1086181	total: 585ms	remaining: 1.04s
# 359:	learn: 312515.9727926	total: 586ms	remaining: 1.04s
# 360:	learn: 312433.2755779	total: 588ms	remaining: 1.04s
# 361:	learn: 312316.9900999	total: 589ms	remaining: 1.04s
# 362:	learn: 311785.1604381	total: 591ms	remaining: 1.04s
# 363:	learn: 311706.5806128	total: 592ms	remaining: 1.03s
# 364:	learn: 311428.0634342	total: 594ms	remaining: 1.03s
# 365:	learn: 311006.8019134	total: 596ms	remaining: 1.03s
# 366:	learn: 310707.9892487	total: 597ms	remaining: 1.03s
# 367:	learn: 310571.5452450	total: 599ms	remaining: 1.03s
# 368:	learn: 310304.2136787	total: 600ms	remaining: 1.03s
# 369:	learn: 309708.6298334	total: 602ms	remaining: 1.02s
# 370:	learn: 309637.8276400	total: 603ms	remaining: 1.02s
# 371:	learn: 309226.2528863	total: 605ms	remaining: 1.02s
# 372:	learn: 309145.5473891	total: 607ms	remaining: 1.02s
# 373:	learn: 308731.3792149	total: 608ms	remaining: 1.02s
# 374:	learn: 308621.6648057	total: 610ms	remaining: 1.02s
# 375:	learn: 308413.6113380	total: 611ms	remaining: 1.01s
# 376:	learn: 308223.7731123	total: 613ms	remaining: 1.01s
# 377:	learn: 308002.4245920	total: 614ms	remaining: 1.01s
# 378:	learn: 307763.7342767	total: 616ms	remaining: 1.01s
# 379:	learn: 307368.3316225	total: 618ms	remaining: 1.01s
# 380:	learn: 307103.8762716	total: 619ms	remaining: 1.01s
# 381:	learn: 307000.9521254	total: 621ms	remaining: 1s
# 382:	learn: 306481.4375623	total: 623ms	remaining: 1s
# 383:	learn: 305965.5385747	total: 624ms	remaining: 1s
# 384:	learn: 305834.1641146	total: 626ms	remaining: 1000ms
# 385:	learn: 305662.3651662	total: 628ms	remaining: 998ms
# 386:	learn: 305533.9549895	total: 629ms	remaining: 997ms
# 387:	learn: 305319.5425789	total: 631ms	remaining: 995ms
# 388:	learn: 305121.6709757	total: 632ms	remaining: 993ms
# 389:	learn: 304465.1244644	total: 634ms	remaining: 991ms
# 390:	learn: 304306.3790399	total: 635ms	remaining: 990ms
# 391:	learn: 304209.8162919	total: 637ms	remaining: 988ms
# 392:	learn: 303877.9515631	total: 639ms	remaining: 987ms
# 393:	learn: 303766.1872385	total: 640ms	remaining: 985ms
# 394:	learn: 303487.4142962	total: 642ms	remaining: 983ms
# 395:	learn: 303053.9463087	total: 644ms	remaining: 982ms
# 396:	learn: 302956.9862825	total: 645ms	remaining: 980ms
# 397:	learn: 302754.7657692	total: 647ms	remaining: 978ms
# 398:	learn: 302467.0443496	total: 648ms	remaining: 976ms
# 399:	learn: 301893.2490042	total: 650ms	remaining: 975ms
# 400:	learn: 301683.7396388	total: 652ms	remaining: 973ms
# 401:	learn: 301563.5592398	total: 654ms	remaining: 972ms
# 402:	learn: 301301.8751717	total: 655ms	remaining: 971ms
# 403:	learn: 300907.8610302	total: 657ms	remaining: 969ms
# 404:	learn: 300861.2210182	total: 658ms	remaining: 967ms
# 405:	learn: 300817.4137858	total: 660ms	remaining: 965ms
# 406:	learn: 300618.7290730	total: 662ms	remaining: 964ms
# 407:	learn: 300453.2630770	total: 663ms	remaining: 962ms
# 408:	learn: 300198.0323706	total: 665ms	remaining: 961ms
# 409:	learn: 299751.9891827	total: 667ms	remaining: 959ms
# 410:	learn: 299687.5862261	total: 668ms	remaining: 958ms
# 411:	learn: 299433.8260612	total: 670ms	remaining: 956ms
# 412:	learn: 299310.0999700	total: 671ms	remaining: 954ms
# 413:	learn: 299120.0541532	total: 673ms	remaining: 953ms
# 414:	learn: 299076.5309961	total: 675ms	remaining: 951ms
# 415:	learn: 298606.1376755	total: 676ms	remaining: 949ms
# 416:	learn: 297941.7140938	total: 678ms	remaining: 948ms
# 417:	learn: 297544.2614718	total: 697ms	remaining: 971ms
# 418:	learn: 297382.8147158	total: 705ms	remaining: 978ms
# 419:	learn: 297270.9987766	total: 710ms	remaining: 981ms
# 420:	learn: 297087.1904211	total: 714ms	remaining: 983ms
# 421:	learn: 296535.0482383	total: 718ms	remaining: 984ms
# 422:	learn: 296452.3249778	total: 721ms	remaining: 984ms
# 423:	learn: 295948.5864774	total: 724ms	remaining: 984ms
# 424:	learn: 295842.0949365	total: 727ms	remaining: 983ms
# 425:	learn: 295362.0164559	total: 729ms	remaining: 983ms
# 426:	learn: 295212.9389513	total: 732ms	remaining: 982ms
# 427:	learn: 295060.4877548	total: 734ms	remaining: 981ms
# 428:	learn: 294986.0409964	total: 736ms	remaining: 979ms
# 429:	learn: 294735.3554566	total: 738ms	remaining: 978ms
# 430:	learn: 294296.6221907	total: 739ms	remaining: 976ms
# 431:	learn: 294061.0713677	total: 741ms	remaining: 975ms
# 432:	learn: 293466.5291046	total: 743ms	remaining: 973ms
# 433:	learn: 293180.5286757	total: 745ms	remaining: 971ms
# 434:	learn: 293115.7630866	total: 746ms	remaining: 969ms
# 435:	learn: 292961.0803936	total: 748ms	remaining: 967ms
# 436:	learn: 292632.4742949	total: 749ms	remaining: 966ms
# 437:	learn: 292203.3433087	total: 751ms	remaining: 964ms
# 438:	learn: 292125.9651300	total: 752ms	remaining: 962ms
# 439:	learn: 292012.3034502	total: 754ms	remaining: 960ms
# 440:	learn: 291838.1996937	total: 755ms	remaining: 958ms
# 441:	learn: 291750.4335073	total: 757ms	remaining: 956ms
# 442:	learn: 291405.3741031	total: 759ms	remaining: 954ms
# 443:	learn: 291151.6163704	total: 760ms	remaining: 952ms
# 444:	learn: 290947.5553124	total: 762ms	remaining: 950ms
# 445:	learn: 290733.0248985	total: 763ms	remaining: 948ms
# 446:	learn: 290523.0985223	total: 765ms	remaining: 946ms
# 447:	learn: 290364.3253230	total: 767ms	remaining: 944ms
# 448:	learn: 290188.0566203	total: 768ms	remaining: 943ms
# 449:	learn: 289978.8715422	total: 770ms	remaining: 941ms
# 450:	learn: 289919.1172339	total: 771ms	remaining: 939ms
# 451:	learn: 289448.3603434	total: 773ms	remaining: 937ms
# 452:	learn: 289235.1337015	total: 774ms	remaining: 935ms
# 453:	learn: 289071.8046132	total: 776ms	remaining: 933ms
# 454:	learn: 288959.1978747	total: 777ms	remaining: 931ms
# 455:	learn: 288820.1543781	total: 779ms	remaining: 929ms
# 456:	learn: 288527.7885521	total: 780ms	remaining: 927ms
# 457:	learn: 288457.1839620	total: 782ms	remaining: 925ms
# 458:	learn: 288285.4690820	total: 783ms	remaining: 923ms
# 459:	learn: 288233.0982241	total: 785ms	remaining: 921ms
# 460:	learn: 288052.2550317	total: 787ms	remaining: 920ms
# 461:	learn: 287832.2385932	total: 789ms	remaining: 918ms
# 462:	learn: 287645.9444294	total: 790ms	remaining: 917ms
# 463:	learn: 287532.7026851	total: 792ms	remaining: 915ms
# 464:	learn: 287396.2301283	total: 793ms	remaining: 913ms
# 465:	learn: 287193.4587649	total: 795ms	remaining: 911ms
# 466:	learn: 287021.2197390	total: 796ms	remaining: 909ms
# 467:	learn: 286924.4128165	total: 798ms	remaining: 907ms
# 468:	learn: 286572.9156455	total: 800ms	remaining: 905ms
# 469:	learn: 286309.1666207	total: 801ms	remaining: 903ms
# 470:	learn: 286275.1754024	total: 803ms	remaining: 902ms
# 471:	learn: 285993.5002950	total: 805ms	remaining: 900ms
# 472:	learn: 285883.1953363	total: 807ms	remaining: 899ms
# 473:	learn: 285555.8772536	total: 808ms	remaining: 897ms
# 474:	learn: 285077.2128258	total: 810ms	remaining: 895ms
# 475:	learn: 284967.2672470	total: 811ms	remaining: 893ms
# 476:	learn: 284852.8865579	total: 813ms	remaining: 891ms
# 477:	learn: 284713.2293458	total: 814ms	remaining: 889ms
# 478:	learn: 284677.1625252	total: 816ms	remaining: 887ms
# 479:	learn: 284442.2782877	total: 818ms	remaining: 886ms
# 480:	learn: 284332.3878817	total: 819ms	remaining: 884ms
# 481:	learn: 284183.3278446	total: 821ms	remaining: 882ms
# 482:	learn: 284119.4533833	total: 822ms	remaining: 880ms
# 483:	learn: 283960.4046066	total: 824ms	remaining: 879ms
# 484:	learn: 283752.1496593	total: 826ms	remaining: 877ms
# 485:	learn: 283587.1261925	total: 827ms	remaining: 875ms
# 486:	learn: 283386.3408426	total: 829ms	remaining: 873ms
# 487:	learn: 282971.0487030	total: 833ms	remaining: 874ms
# 488:	learn: 282423.4656587	total: 835ms	remaining: 872ms
# 489:	learn: 281860.6705633	total: 836ms	remaining: 871ms
# 490:	learn: 281459.7088735	total: 838ms	remaining: 869ms
# 491:	learn: 281325.6218589	total: 840ms	remaining: 867ms
# 492:	learn: 281263.5181746	total: 841ms	remaining: 865ms
# 493:	learn: 280888.2548044	total: 843ms	remaining: 863ms
# 494:	learn: 280676.3690881	total: 845ms	remaining: 862ms
# 495:	learn: 280573.7989623	total: 846ms	remaining: 860ms
# 496:	learn: 280471.2840076	total: 848ms	remaining: 858ms
# 497:	learn: 280156.5115293	total: 849ms	remaining: 856ms
# 498:	learn: 279843.2087929	total: 851ms	remaining: 855ms
# 499:	learn: 279598.1336743	total: 853ms	remaining: 853ms
# 500:	learn: 279474.9224646	total: 854ms	remaining: 851ms
# 501:	learn: 279389.8360180	total: 856ms	remaining: 849ms
# 502:	learn: 278828.6206807	total: 857ms	remaining: 847ms
# 503:	learn: 278728.6301955	total: 859ms	remaining: 845ms
# 504:	learn: 278477.5770983	total: 861ms	remaining: 844ms
# 505:	learn: 278199.3017258	total: 863ms	remaining: 842ms
# 506:	learn: 278064.6170083	total: 864ms	remaining: 840ms
# 507:	learn: 277945.2343946	total: 866ms	remaining: 839ms
# 508:	learn: 277830.4260329	total: 868ms	remaining: 837ms
# 509:	learn: 277660.1840668	total: 869ms	remaining: 835ms
# 510:	learn: 277454.4302399	total: 871ms	remaining: 834ms
# 511:	learn: 277329.2970543	total: 873ms	remaining: 832ms
# 512:	learn: 277172.8528999	total: 875ms	remaining: 830ms
# 513:	learn: 277091.2725207	total: 876ms	remaining: 829ms
# 514:	learn: 276893.5263223	total: 878ms	remaining: 827ms
# 515:	learn: 276629.4182747	total: 880ms	remaining: 825ms
# 516:	learn: 276526.1824817	total: 881ms	remaining: 823ms
# 517:	learn: 276245.0164312	total: 883ms	remaining: 821ms
# 518:	learn: 276132.7626935	total: 884ms	remaining: 820ms
# 519:	learn: 275889.4330639	total: 886ms	remaining: 818ms
# 520:	learn: 275817.0758466	total: 887ms	remaining: 816ms
# 521:	learn: 275733.7893393	total: 889ms	remaining: 814ms
# 522:	learn: 275657.1711110	total: 891ms	remaining: 812ms
# 523:	learn: 275372.7236472	total: 892ms	remaining: 811ms
# 524:	learn: 274845.9170156	total: 894ms	remaining: 809ms
# 525:	learn: 274642.0272392	total: 896ms	remaining: 807ms
# 526:	learn: 274375.0813356	total: 897ms	remaining: 805ms
# 527:	learn: 274200.7064198	total: 899ms	remaining: 803ms
# 528:	learn: 274017.4067389	total: 900ms	remaining: 802ms
# 529:	learn: 273909.7577271	total: 902ms	remaining: 800ms
# 530:	learn: 273874.2467682	total: 903ms	remaining: 798ms
# 531:	learn: 273590.6145542	total: 905ms	remaining: 796ms
# 532:	learn: 273546.9199045	total: 907ms	remaining: 794ms
# 533:	learn: 273325.7695549	total: 908ms	remaining: 793ms
# 534:	learn: 272912.4015030	total: 910ms	remaining: 791ms
# 535:	learn: 272677.8039372	total: 911ms	remaining: 789ms
# 536:	learn: 272407.8222388	total: 913ms	remaining: 787ms
# 537:	learn: 272341.1309726	total: 915ms	remaining: 785ms
# 538:	learn: 272236.2257995	total: 916ms	remaining: 783ms
# 539:	learn: 272003.5920343	total: 918ms	remaining: 782ms
# 540:	learn: 271876.6972522	total: 919ms	remaining: 780ms
# 541:	learn: 271680.1007716	total: 921ms	remaining: 778ms
# 542:	learn: 271596.3750587	total: 923ms	remaining: 777ms
# 543:	learn: 271505.5535225	total: 924ms	remaining: 775ms
# 544:	learn: 271463.5899424	total: 926ms	remaining: 773ms
# 545:	learn: 271353.7976578	total: 927ms	remaining: 771ms
# 546:	learn: 271149.4955185	total: 929ms	remaining: 769ms
# 547:	learn: 270929.2112618	total: 930ms	remaining: 767ms
# 548:	learn: 270848.4133710	total: 932ms	remaining: 766ms
# 549:	learn: 270795.7781514	total: 934ms	remaining: 764ms
# 550:	learn: 270671.8636086	total: 936ms	remaining: 762ms
# 551:	learn: 270626.3175495	total: 937ms	remaining: 761ms
# 552:	learn: 270578.4883964	total: 939ms	remaining: 759ms
# 553:	learn: 270454.1265705	total: 940ms	remaining: 757ms
# 554:	learn: 270341.3650623	total: 942ms	remaining: 755ms
# 555:	learn: 269948.0542507	total: 943ms	remaining: 753ms
# 556:	learn: 269864.7390178	total: 945ms	remaining: 751ms
# 557:	learn: 269590.3935384	total: 946ms	remaining: 750ms
# 558:	learn: 269412.2359072	total: 948ms	remaining: 748ms
# 559:	learn: 269245.7863562	total: 950ms	remaining: 746ms
# 560:	learn: 269192.3364117	total: 952ms	remaining: 745ms
# 561:	learn: 269119.6650145	total: 953ms	remaining: 743ms
# 562:	learn: 269005.8002730	total: 955ms	remaining: 741ms
# 563:	learn: 268837.4308702	total: 956ms	remaining: 739ms
# 564:	learn: 268795.6901045	total: 958ms	remaining: 737ms
# 565:	learn: 268527.2765200	total: 959ms	remaining: 735ms
# 566:	learn: 268380.4433723	total: 961ms	remaining: 734ms
# 567:	learn: 268095.1764261	total: 962ms	remaining: 732ms
# 568:	learn: 267983.6155727	total: 964ms	remaining: 730ms
# 569:	learn: 267884.4189925	total: 966ms	remaining: 729ms
# 570:	learn: 267800.3342546	total: 967ms	remaining: 727ms
# 571:	learn: 267628.8396081	total: 969ms	remaining: 725ms
# 572:	learn: 267572.3492982	total: 971ms	remaining: 723ms
# 573:	learn: 267382.3913100	total: 972ms	remaining: 721ms
# 574:	learn: 267345.8734349	total: 974ms	remaining: 720ms
# 575:	learn: 267274.1314314	total: 975ms	remaining: 718ms
# 576:	learn: 267110.4938965	total: 977ms	remaining: 716ms
# 577:	learn: 267006.6275316	total: 979ms	remaining: 715ms
# 578:	learn: 266977.1685628	total: 980ms	remaining: 713ms
# 579:	learn: 266828.1806093	total: 982ms	remaining: 711ms
# 580:	learn: 266390.7866875	total: 984ms	remaining: 709ms
# 581:	learn: 266286.5637697	total: 985ms	remaining: 708ms
# 582:	learn: 266247.3313346	total: 987ms	remaining: 706ms
# 583:	learn: 266002.9097310	total: 988ms	remaining: 704ms
# 584:	learn: 265889.4636626	total: 990ms	remaining: 702ms
# 585:	learn: 265832.7548337	total: 991ms	remaining: 700ms
# 586:	learn: 265637.4973235	total: 993ms	remaining: 699ms
# 587:	learn: 265436.6279926	total: 995ms	remaining: 697ms
# 588:	learn: 265337.4605417	total: 997ms	remaining: 696ms
# 589:	learn: 265284.5948973	total: 998ms	remaining: 694ms
# 590:	learn: 265147.3396373	total: 1000ms	remaining: 692ms
# 591:	learn: 265078.0323957	total: 1s	remaining: 690ms
# 592:	learn: 265035.0656484	total: 1s	remaining: 688ms
# 593:	learn: 264966.9348241	total: 1s	remaining: 687ms
# 594:	learn: 264825.9013321	total: 1.01s	remaining: 685ms
# 595:	learn: 264749.5980796	total: 1.01s	remaining: 684ms
# 596:	learn: 264329.9508138	total: 1.01s	remaining: 683ms
# 597:	learn: 263957.9037918	total: 1.01s	remaining: 681ms
# 598:	learn: 263750.2036491	total: 1.01s	remaining: 679ms
# 599:	learn: 263657.1915453	total: 1.02s	remaining: 678ms
# 600:	learn: 263583.2769479	total: 1.02s	remaining: 676ms
# 601:	learn: 263565.3463527	total: 1.02s	remaining: 674ms
# 602:	learn: 263523.5675352	total: 1.02s	remaining: 672ms
# 603:	learn: 263389.0113134	total: 1.02s	remaining: 671ms
# 604:	learn: 263163.5977895	total: 1.02s	remaining: 669ms
# 605:	learn: 262806.4912565	total: 1.02s	remaining: 667ms
# 606:	learn: 262742.9053410	total: 1.03s	remaining: 665ms
# 607:	learn: 262624.5545544	total: 1.03s	remaining: 663ms
# 608:	learn: 262455.3121364	total: 1.03s	remaining: 662ms
# 609:	learn: 262418.2182963	total: 1.03s	remaining: 660ms
# 610:	learn: 262330.5512108	total: 1.03s	remaining: 658ms
# 611:	learn: 262271.4433977	total: 1.03s	remaining: 656ms
# 612:	learn: 262011.7354669	total: 1.04s	remaining: 655ms
# 613:	learn: 261738.3635831	total: 1.04s	remaining: 653ms
# 614:	learn: 261564.6156192	total: 1.04s	remaining: 651ms
# 615:	learn: 261317.3651144	total: 1.04s	remaining: 649ms
# 616:	learn: 261074.1772026	total: 1.04s	remaining: 648ms
# 617:	learn: 260954.9935164	total: 1.04s	remaining: 646ms
# 618:	learn: 260758.1862536	total: 1.05s	remaining: 644ms
# 619:	learn: 260441.1578322	total: 1.05s	remaining: 643ms
# 620:	learn: 260422.1408999	total: 1.05s	remaining: 641ms
# 621:	learn: 260383.6557350	total: 1.05s	remaining: 640ms
# 622:	learn: 260148.6806087	total: 1.05s	remaining: 638ms
# 623:	learn: 259897.8857144	total: 1.05s	remaining: 636ms
# 624:	learn: 259878.8742459	total: 1.06s	remaining: 634ms
# 625:	learn: 259759.1193419	total: 1.06s	remaining: 633ms
# 626:	learn: 259621.0514124	total: 1.06s	remaining: 631ms
# 627:	learn: 259456.6242957	total: 1.06s	remaining: 629ms
# 628:	learn: 259294.4779824	total: 1.06s	remaining: 627ms
# 629:	learn: 259277.1597493	total: 1.06s	remaining: 626ms
# 630:	learn: 259260.5316014	total: 1.07s	remaining: 624ms
# 631:	learn: 259017.7614345	total: 1.07s	remaining: 623ms
# 632:	learn: 258715.0738334	total: 1.07s	remaining: 622ms
# 633:	learn: 258700.3819366	total: 1.07s	remaining: 620ms
# 634:	learn: 258609.6168107	total: 1.07s	remaining: 618ms
# 635:	learn: 258594.4335112	total: 1.08s	remaining: 616ms
# 636:	learn: 258500.8006274	total: 1.08s	remaining: 615ms
# 637:	learn: 258435.9829521	total: 1.08s	remaining: 613ms
# 638:	learn: 258422.1410362	total: 1.08s	remaining: 611ms
# 639:	learn: 258362.9980706	total: 1.08s	remaining: 609ms
# 640:	learn: 258212.5261978	total: 1.08s	remaining: 608ms
# 641:	learn: 258194.4985193	total: 1.09s	remaining: 606ms
# 642:	learn: 258137.5207579	total: 1.09s	remaining: 604ms
# 643:	learn: 258122.7028752	total: 1.09s	remaining: 602ms
# 644:	learn: 258057.8443157	total: 1.09s	remaining: 601ms
# 645:	learn: 257977.0677802	total: 1.09s	remaining: 599ms
# 646:	learn: 257946.8795912	total: 1.09s	remaining: 597ms
# 647:	learn: 257873.5392436	total: 1.09s	remaining: 595ms
# 648:	learn: 257830.5501618	total: 1.1s	remaining: 594ms
# 649:	learn: 257795.7008735	total: 1.1s	remaining: 593ms
# 650:	learn: 257764.7457951	total: 1.1s	remaining: 591ms
# 651:	learn: 257731.2448411	total: 1.1s	remaining: 589ms
# 652:	learn: 257709.7421286	total: 1.1s	remaining: 587ms
# 653:	learn: 257618.5581804	total: 1.11s	remaining: 586ms
# 654:	learn: 257548.7098344	total: 1.11s	remaining: 584ms
# 655:	learn: 257318.7637494	total: 1.11s	remaining: 582ms
# 656:	learn: 257232.4899358	total: 1.11s	remaining: 581ms
# 657:	learn: 257186.6082717	total: 1.11s	remaining: 579ms
# 658:	learn: 257092.7048089	total: 1.11s	remaining: 577ms
# 659:	learn: 257059.4701123	total: 1.12s	remaining: 575ms
# 660:	learn: 257047.6529757	total: 1.12s	remaining: 574ms
# 661:	learn: 256871.1761377	total: 1.12s	remaining: 572ms
# 662:	learn: 256835.7078055	total: 1.12s	remaining: 570ms
# 663:	learn: 256713.8464204	total: 1.12s	remaining: 568ms
# 664:	learn: 256627.8300900	total: 1.12s	remaining: 567ms
# 665:	learn: 256568.0473267	total: 1.13s	remaining: 565ms
# 666:	learn: 256381.6774801	total: 1.13s	remaining: 563ms
# 667:	learn: 256370.2624876	total: 1.13s	remaining: 561ms
# 668:	learn: 256246.0380778	total: 1.13s	remaining: 560ms
# 669:	learn: 256183.1180093	total: 1.13s	remaining: 558ms
# 670:	learn: 255916.4256879	total: 1.13s	remaining: 556ms
# 671:	learn: 255641.0322624	total: 1.14s	remaining: 554ms
# 672:	learn: 255329.5190529	total: 1.14s	remaining: 553ms
# 673:	learn: 255188.8095919	total: 1.14s	remaining: 551ms
# 674:	learn: 254989.0836087	total: 1.14s	remaining: 549ms
# 675:	learn: 254419.8853034	total: 1.14s	remaining: 548ms
# 676:	learn: 254398.6433821	total: 1.14s	remaining: 546ms
# 677:	learn: 254303.2213849	total: 1.15s	remaining: 544ms
# 678:	learn: 254290.3611148	total: 1.15s	remaining: 542ms
# 679:	learn: 254183.9012440	total: 1.15s	remaining: 540ms
# 680:	learn: 253922.9803221	total: 1.15s	remaining: 539ms
# 681:	learn: 253739.5882695	total: 1.15s	remaining: 537ms
# 682:	learn: 253653.8759309	total: 1.15s	remaining: 535ms
# 683:	learn: 253580.6471266	total: 1.15s	remaining: 534ms
# 684:	learn: 253570.0936825	total: 1.16s	remaining: 532ms
# 685:	learn: 253490.5723907	total: 1.16s	remaining: 530ms
# 686:	learn: 253154.4632097	total: 1.16s	remaining: 528ms
# 687:	learn: 253034.3404290	total: 1.16s	remaining: 527ms
# 688:	learn: 252881.8519774	total: 1.16s	remaining: 525ms
# 689:	learn: 252828.8525378	total: 1.16s	remaining: 523ms
# 690:	learn: 252688.4217951	total: 1.17s	remaining: 521ms
# 691:	learn: 252573.5601545	total: 1.17s	remaining: 520ms
# 692:	learn: 252563.3338680	total: 1.17s	remaining: 518ms
# 693:	learn: 252497.2406856	total: 1.17s	remaining: 516ms
# 694:	learn: 251997.1497019	total: 1.17s	remaining: 515ms
# 695:	learn: 251803.2787705	total: 1.17s	remaining: 513ms
# 696:	learn: 251753.9906617	total: 1.18s	remaining: 512ms
# 697:	learn: 251533.8114714	total: 1.18s	remaining: 510ms
# 698:	learn: 251485.0304928	total: 1.18s	remaining: 508ms
# 699:	learn: 251272.4916089	total: 1.18s	remaining: 506ms
# 700:	learn: 251189.2898918	total: 1.18s	remaining: 505ms
# 701:	learn: 251075.7834577	total: 1.18s	remaining: 503ms
# 702:	learn: 251024.1821702	total: 1.19s	remaining: 501ms
# 703:	learn: 250969.5326698	total: 1.19s	remaining: 500ms
# 704:	learn: 250810.8424873	total: 1.19s	remaining: 498ms
# 705:	learn: 250709.9663396	total: 1.19s	remaining: 496ms
# 706:	learn: 250698.0041149	total: 1.19s	remaining: 494ms
# 707:	learn: 250530.0147504	total: 1.19s	remaining: 493ms
# 708:	learn: 250442.6503205	total: 1.2s	remaining: 491ms
# 709:	learn: 250242.4939854	total: 1.2s	remaining: 489ms
# 710:	learn: 249906.1504435	total: 1.2s	remaining: 488ms
# 711:	learn: 249894.6187489	total: 1.2s	remaining: 486ms
# 712:	learn: 249809.1261997	total: 1.2s	remaining: 484ms
# 713:	learn: 249715.9939321	total: 1.2s	remaining: 482ms
# 714:	learn: 249600.6207733	total: 1.21s	remaining: 481ms
# 715:	learn: 249557.6528080	total: 1.21s	remaining: 479ms
# 716:	learn: 249535.3728571	total: 1.21s	remaining: 477ms
# 717:	learn: 249342.0369667	total: 1.21s	remaining: 475ms
# 718:	learn: 249171.7745293	total: 1.21s	remaining: 474ms
# 719:	learn: 249100.0040216	total: 1.21s	remaining: 472ms
# 720:	learn: 249089.5561639	total: 1.22s	remaining: 470ms
# 721:	learn: 249032.1673615	total: 1.22s	remaining: 469ms
# 722:	learn: 248902.9498825	total: 1.22s	remaining: 467ms
# 723:	learn: 248822.5806137	total: 1.22s	remaining: 465ms
# 724:	learn: 248668.7092338	total: 1.22s	remaining: 463ms
# 725:	learn: 248620.7018317	total: 1.22s	remaining: 462ms
# 726:	learn: 248463.5553694	total: 1.22s	remaining: 460ms
# 727:	learn: 248370.0901844	total: 1.23s	remaining: 458ms
# 728:	learn: 248340.3645430	total: 1.23s	remaining: 456ms
# 729:	learn: 248268.6112689	total: 1.23s	remaining: 455ms
# 730:	learn: 248033.2272989	total: 1.23s	remaining: 453ms
# 731:	learn: 247987.6174023	total: 1.23s	remaining: 451ms
# 732:	learn: 247906.9197659	total: 1.23s	remaining: 450ms
# 733:	learn: 247736.0680375	total: 1.24s	remaining: 448ms
# 734:	learn: 247663.6874973	total: 1.24s	remaining: 446ms
# 735:	learn: 247432.1417284	total: 1.24s	remaining: 444ms
# 736:	learn: 247421.3669342	total: 1.24s	remaining: 443ms
# 737:	learn: 247323.3636673	total: 1.24s	remaining: 441ms
# 738:	learn: 247136.5190992	total: 1.24s	remaining: 439ms
# 739:	learn: 246954.7069424	total: 1.25s	remaining: 438ms
# 740:	learn: 246756.3652145	total: 1.25s	remaining: 436ms
# 741:	learn: 246636.6924670	total: 1.25s	remaining: 434ms
# 742:	learn: 246486.8295728	total: 1.25s	remaining: 432ms
# 743:	learn: 246453.8038166	total: 1.25s	remaining: 431ms
# 744:	learn: 246234.5039263	total: 1.25s	remaining: 429ms
# 745:	learn: 246177.3671994	total: 1.25s	remaining: 427ms
# 746:	learn: 245926.4042217	total: 1.26s	remaining: 425ms
# 747:	learn: 245830.5708475	total: 1.26s	remaining: 424ms
# 748:	learn: 245775.1599505	total: 1.26s	remaining: 422ms
# 749:	learn: 245605.4896129	total: 1.26s	remaining: 420ms
# 750:	learn: 245511.5468927	total: 1.26s	remaining: 419ms
# 751:	learn: 245373.7805668	total: 1.26s	remaining: 417ms
# 752:	learn: 245334.5771063	total: 1.26s	remaining: 415ms
# 753:	learn: 245124.1525460	total: 1.27s	remaining: 413ms
# 754:	learn: 245030.5814956	total: 1.27s	remaining: 412ms
# 755:	learn: 244909.9683904	total: 1.27s	remaining: 410ms
# 756:	learn: 244721.0253387	total: 1.27s	remaining: 408ms
# 757:	learn: 244660.7187799	total: 1.27s	remaining: 407ms
# 758:	learn: 244470.7949420	total: 1.27s	remaining: 405ms
# 759:	learn: 244326.0464188	total: 1.28s	remaining: 403ms
# 760:	learn: 244274.9073138	total: 1.28s	remaining: 402ms
# 761:	learn: 244144.4859473	total: 1.28s	remaining: 400ms
# 762:	learn: 243873.2125705	total: 1.28s	remaining: 398ms
# 763:	learn: 243833.2654469	total: 1.28s	remaining: 396ms
# 764:	learn: 243787.3302278	total: 1.28s	remaining: 395ms
# 765:	learn: 243744.7602620	total: 1.29s	remaining: 393ms
# 766:	learn: 243695.1234890	total: 1.29s	remaining: 391ms
# 767:	learn: 243582.1826116	total: 1.29s	remaining: 390ms
# 768:	learn: 243534.2243088	total: 1.29s	remaining: 388ms
# 769:	learn: 243491.3602732	total: 1.29s	remaining: 386ms
# 770:	learn: 243143.3217816	total: 1.29s	remaining: 385ms
# 771:	learn: 242985.0747826	total: 1.3s	remaining: 383ms
# 772:	learn: 242746.6767158	total: 1.3s	remaining: 381ms
# 773:	learn: 242701.7373329	total: 1.3s	remaining: 379ms
# 774:	learn: 242546.6111944	total: 1.3s	remaining: 378ms
# 775:	learn: 242371.0697155	total: 1.3s	remaining: 376ms
# 776:	learn: 242315.3868569	total: 1.3s	remaining: 374ms
# 777:	learn: 242280.3722675	total: 1.3s	remaining: 373ms
# 778:	learn: 242203.0572715	total: 1.31s	remaining: 371ms
# 779:	learn: 242158.2569070	total: 1.31s	remaining: 369ms
# 780:	learn: 242107.5863488	total: 1.31s	remaining: 367ms
# 781:	learn: 241914.0355704	total: 1.31s	remaining: 366ms
# 782:	learn: 241767.7981987	total: 1.31s	remaining: 364ms
# 783:	learn: 241719.4246436	total: 1.31s	remaining: 362ms
# 784:	learn: 241523.2956801	total: 1.32s	remaining: 361ms
# 785:	learn: 241490.0313549	total: 1.32s	remaining: 359ms
# 786:	learn: 241296.8746765	total: 1.32s	remaining: 357ms
# 787:	learn: 241250.0722829	total: 1.32s	remaining: 356ms
# 788:	learn: 241225.2499407	total: 1.32s	remaining: 354ms
# 789:	learn: 241186.5909987	total: 1.32s	remaining: 352ms
# 790:	learn: 241177.0802221	total: 1.33s	remaining: 350ms
# 791:	learn: 241122.7996920	total: 1.33s	remaining: 349ms
# 792:	learn: 240952.8773041	total: 1.33s	remaining: 347ms
# 793:	learn: 240887.5578443	total: 1.33s	remaining: 345ms
# 794:	learn: 240728.3618897	total: 1.33s	remaining: 344ms
# 795:	learn: 240719.5362010	total: 1.33s	remaining: 342ms
# 796:	learn: 240675.4754776	total: 1.33s	remaining: 340ms
# 797:	learn: 240626.3087718	total: 1.34s	remaining: 339ms
# 798:	learn: 240561.0718924	total: 1.34s	remaining: 337ms
# 799:	learn: 240523.1319528	total: 1.34s	remaining: 335ms
# 800:	learn: 240303.6283366	total: 1.34s	remaining: 334ms
# 801:	learn: 240282.4073279	total: 1.34s	remaining: 332ms
# 802:	learn: 240177.6503400	total: 1.35s	remaining: 330ms
# 803:	learn: 240069.1706948	total: 1.35s	remaining: 329ms
# 804:	learn: 239635.0687116	total: 1.35s	remaining: 327ms
# 805:	learn: 239554.7463243	total: 1.35s	remaining: 325ms
# 806:	learn: 239479.3366351	total: 1.35s	remaining: 324ms
# 807:	learn: 239323.1355158	total: 1.35s	remaining: 322ms
# 808:	learn: 239090.4117758	total: 1.36s	remaining: 320ms
# 809:	learn: 239041.0468248	total: 1.36s	remaining: 319ms
# 810:	learn: 238864.7646928	total: 1.36s	remaining: 317ms
# 811:	learn: 238740.0190066	total: 1.36s	remaining: 315ms
# 812:	learn: 238609.5895592	total: 1.36s	remaining: 313ms
# 813:	learn: 238491.7465293	total: 1.36s	remaining: 312ms
# 814:	learn: 238435.3812016	total: 1.37s	remaining: 310ms
# 815:	learn: 238352.3856023	total: 1.37s	remaining: 308ms
# 816:	learn: 238226.9914797	total: 1.37s	remaining: 307ms
# 817:	learn: 238057.8766748	total: 1.37s	remaining: 305ms
# 818:	learn: 238019.4150645	total: 1.37s	remaining: 303ms
# 819:	learn: 237978.3759718	total: 1.37s	remaining: 302ms
# 820:	learn: 237675.2409779	total: 1.38s	remaining: 300ms
# 821:	learn: 237510.2020860	total: 1.38s	remaining: 298ms
# 822:	learn: 237451.1448756	total: 1.38s	remaining: 297ms
# 823:	learn: 237390.6516568	total: 1.38s	remaining: 295ms
# 824:	learn: 237267.7856930	total: 1.38s	remaining: 293ms
# 825:	learn: 237228.9080829	total: 1.38s	remaining: 291ms
# 826:	learn: 237192.0415290	total: 1.39s	remaining: 290ms
# 827:	learn: 237039.6252759	total: 1.39s	remaining: 288ms
# 828:	learn: 236916.3617187	total: 1.39s	remaining: 286ms
# 829:	learn: 236787.5160652	total: 1.39s	remaining: 285ms
# 830:	learn: 236627.5066651	total: 1.39s	remaining: 283ms
# 831:	learn: 236547.1474652	total: 1.39s	remaining: 281ms
# 832:	learn: 236495.7433914	total: 1.4s	remaining: 280ms
# 833:	learn: 236423.2121311	total: 1.4s	remaining: 278ms
# 834:	learn: 236371.0383609	total: 1.4s	remaining: 276ms
# 835:	learn: 236237.7755563	total: 1.4s	remaining: 275ms
# 836:	learn: 236130.5848508	total: 1.4s	remaining: 273ms
# 837:	learn: 236001.0687398	total: 1.4s	remaining: 271ms
# 838:	learn: 235903.7825519	total: 1.4s	remaining: 270ms
# 839:	learn: 235789.6995945	total: 1.41s	remaining: 268ms
# 840:	learn: 235779.4912447	total: 1.41s	remaining: 266ms
# 841:	learn: 235653.8304687	total: 1.41s	remaining: 265ms
# 842:	learn: 235488.3559630	total: 1.41s	remaining: 263ms
# ...
# 720:	learn: 193630.4659429	total: 1.24s	remaining: 478ms
# 721:	learn: 193499.6481691	total: 1.24s	remaining: 477ms
# 722:	learn: 193390.7981077	total: 1.24s	remaining: 475ms
# 723:	learn: 193347.7594405	total: 1.24s	remaining: 474ms
# 724:	learn: 193235.9662208	total: 1.24s	remaining: 472ms
# 725:	learn: 193114.8702283	total: 1.25s	remaining: 470ms
# 726:	learn: 193077.3690432	total: 1.25s	remaining: 469ms
# 727:	learn: 192978.0197515	total: 1.25s	remaining: 467ms
# 728:	learn: 192831.4444333	total: 1.25s	remaining: 465ms
# 729:	learn: 192817.6713882	total: 1.25s	remaining: 464ms
# 730:	learn: 192748.7609082	total: 1.25s	remaining: 462ms
# 731:	learn: 192676.6042198	total: 1.26s	remaining: 460ms
# 732:	learn: 192625.8336375	total: 1.26s	remaining: 458ms
# 733:	learn: 192547.8095448	total: 1.26s	remaining: 457ms
# 734:	learn: 192534.2139340	total: 1.26s	remaining: 455ms
# 735:	learn: 192461.3618001	total: 1.26s	remaining: 453ms
# 736:	learn: 192396.8848765	total: 1.26s	remaining: 452ms
# 737:	learn: 192312.5950425	total: 1.27s	remaining: 450ms
# 738:	learn: 192215.6782880	total: 1.27s	remaining: 448ms
# 739:	learn: 192058.6245763	total: 1.27s	remaining: 446ms
# 740:	learn: 192049.3735457	total: 1.27s	remaining: 445ms
# 741:	learn: 191965.7079084	total: 1.27s	remaining: 443ms
# 742:	learn: 191838.0200907	total: 1.27s	remaining: 441ms
# 743:	learn: 191823.6958653	total: 1.28s	remaining: 439ms
# 744:	learn: 191711.0372848	total: 1.28s	remaining: 438ms
# 745:	learn: 191594.4971382	total: 1.28s	remaining: 436ms
# 746:	learn: 191467.0098253	total: 1.28s	remaining: 434ms
# 747:	learn: 191279.9784991	total: 1.28s	remaining: 433ms
# 748:	learn: 191181.4745952	total: 1.28s	remaining: 431ms
# 749:	learn: 191081.9452093	total: 1.29s	remaining: 429ms
# 750:	learn: 191057.3288323	total: 1.29s	remaining: 427ms
# 751:	learn: 190967.7044437	total: 1.29s	remaining: 426ms
# 752:	learn: 190955.8380770	total: 1.29s	remaining: 424ms
# 753:	learn: 190901.4542428	total: 1.29s	remaining: 422ms
# 754:	learn: 190824.4088721	total: 1.29s	remaining: 420ms
# 755:	learn: 190740.4381134	total: 1.3s	remaining: 419ms
# 756:	learn: 190605.5748637	total: 1.3s	remaining: 417ms
# 757:	learn: 190533.4351640	total: 1.3s	remaining: 415ms
# 758:	learn: 190453.4454911	total: 1.3s	remaining: 413ms
# 759:	learn: 190260.9899158	total: 1.3s	remaining: 412ms
# 760:	learn: 190247.4591788	total: 1.3s	remaining: 410ms
# 761:	learn: 190083.7261379	total: 1.31s	remaining: 408ms
# 762:	learn: 189990.6423704	total: 1.31s	remaining: 407ms
# 763:	learn: 189935.9145201	total: 1.31s	remaining: 405ms
# 764:	learn: 189894.5770045	total: 1.31s	remaining: 403ms
# 765:	learn: 189886.6017624	total: 1.31s	remaining: 401ms
# 766:	learn: 189752.4778325	total: 1.31s	remaining: 400ms
# 767:	learn: 189554.0555143	total: 1.32s	remaining: 398ms
# 768:	learn: 189506.6672675	total: 1.32s	remaining: 396ms
# 769:	learn: 189467.9810658	total: 1.32s	remaining: 394ms
# 770:	learn: 189372.6263030	total: 1.32s	remaining: 393ms
# 771:	learn: 189259.7070235	total: 1.32s	remaining: 391ms
# 772:	learn: 189187.7987441	total: 1.33s	remaining: 389ms
# 773:	learn: 189109.2043931	total: 1.33s	remaining: 388ms
# 774:	learn: 188926.9809024	total: 1.33s	remaining: 386ms
# 775:	learn: 188899.5585259	total: 1.33s	remaining: 384ms
# 776:	learn: 188829.1066850	total: 1.33s	remaining: 382ms
# 777:	learn: 188748.9675362	total: 1.33s	remaining: 381ms
# 778:	learn: 188685.9016626	total: 1.33s	remaining: 379ms
# 779:	learn: 188599.4854839	total: 1.34s	remaining: 377ms
# 780:	learn: 188515.5130939	total: 1.34s	remaining: 376ms
# 781:	learn: 188448.5740483	total: 1.34s	remaining: 374ms
# 782:	learn: 188415.3195360	total: 1.34s	remaining: 372ms
# 783:	learn: 188341.0094882	total: 1.34s	remaining: 370ms
# 784:	learn: 188214.2963551	total: 1.35s	remaining: 369ms
# 785:	learn: 188136.9686489	total: 1.35s	remaining: 367ms
# 786:	learn: 188055.3559393	total: 1.35s	remaining: 365ms
# 787:	learn: 188023.2317098	total: 1.35s	remaining: 363ms
# 788:	learn: 187991.9633468	total: 1.35s	remaining: 362ms
# 789:	learn: 187861.3629811	total: 1.35s	remaining: 360ms
# 790:	learn: 187848.8852730	total: 1.36s	remaining: 358ms
# 791:	learn: 187819.0307392	total: 1.36s	remaining: 357ms
# 792:	learn: 187766.8341443	total: 1.36s	remaining: 355ms
# 793:	learn: 187651.5490121	total: 1.36s	remaining: 353ms
# 794:	learn: 187624.3823796	total: 1.36s	remaining: 351ms
# 795:	learn: 187560.5568851	total: 1.36s	remaining: 350ms
# 796:	learn: 187367.6555906	total: 1.37s	remaining: 348ms
# 797:	learn: 187181.3219715	total: 1.37s	remaining: 346ms
# 798:	learn: 187141.3798158	total: 1.37s	remaining: 345ms
# 799:	learn: 187061.0793309	total: 1.37s	remaining: 343ms
# 800:	learn: 186953.9860401	total: 1.37s	remaining: 341ms
# 801:	learn: 186856.9061893	total: 1.37s	remaining: 339ms
# 802:	learn: 186726.6539008	total: 1.38s	remaining: 338ms
# 803:	learn: 186711.9003617	total: 1.38s	remaining: 336ms
# 804:	learn: 186646.5601431	total: 1.38s	remaining: 334ms
# 805:	learn: 186554.3057262	total: 1.38s	remaining: 332ms
# 806:	learn: 186460.5894210	total: 1.38s	remaining: 331ms
# 807:	learn: 186345.8867653	total: 1.38s	remaining: 329ms
# 808:	learn: 186311.4578061	total: 1.39s	remaining: 327ms
# 809:	learn: 186171.5918020	total: 1.39s	remaining: 326ms
# 810:	learn: 186104.0912906	total: 1.39s	remaining: 324ms
# 811:	learn: 186075.1068244	total: 1.39s	remaining: 322ms
# 812:	learn: 185911.1377593	total: 1.39s	remaining: 321ms
# 813:	learn: 185833.7195477	total: 1.4s	remaining: 319ms
# 814:	learn: 185789.4065237	total: 1.4s	remaining: 317ms
# 815:	learn: 185639.4460312	total: 1.4s	remaining: 316ms
# 816:	learn: 185622.6374567	total: 1.4s	remaining: 314ms
# 817:	learn: 185594.0185902	total: 1.4s	remaining: 312ms
# 818:	learn: 185581.1528663	total: 1.4s	remaining: 310ms
# 819:	learn: 185487.9165072	total: 1.41s	remaining: 309ms
# 820:	learn: 185433.4270120	total: 1.41s	remaining: 307ms
# 821:	learn: 185328.5765832	total: 1.41s	remaining: 305ms
# 822:	learn: 185285.6133379	total: 1.41s	remaining: 304ms
# 823:	learn: 185167.8962231	total: 1.41s	remaining: 302ms
# 824:	learn: 185128.3748049	total: 1.42s	remaining: 300ms
# 825:	learn: 185108.1286658	total: 1.42s	remaining: 298ms
# 826:	learn: 185100.5486002	total: 1.42s	remaining: 297ms
# 827:	learn: 185035.6644867	total: 1.42s	remaining: 295ms
# 828:	learn: 184948.7622109	total: 1.42s	remaining: 293ms
# 829:	learn: 184900.6470841	total: 1.42s	remaining: 292ms
# 830:	learn: 184798.1011759	total: 1.43s	remaining: 290ms
# 831:	learn: 184657.3832228	total: 1.43s	remaining: 288ms
# 832:	learn: 184549.6484699	total: 1.43s	remaining: 286ms
# 833:	learn: 184488.1490460	total: 1.43s	remaining: 285ms
# 834:	learn: 184460.4265681	total: 1.43s	remaining: 283ms
# 835:	learn: 184404.5877051	total: 1.43s	remaining: 281ms
# 836:	learn: 184341.5044210	total: 1.44s	remaining: 280ms
# 837:	learn: 184307.7567461	total: 1.44s	remaining: 278ms
# 838:	learn: 184272.8031198	total: 1.44s	remaining: 276ms
# 839:	learn: 184249.1455852	total: 1.44s	remaining: 274ms
# 840:	learn: 184029.4684545	total: 1.44s	remaining: 273ms
# 841:	learn: 183924.2462075	total: 1.44s	remaining: 271ms
# 842:	learn: 183843.8754048	total: 1.45s	remaining: 269ms
# 843:	learn: 183796.2421442	total: 1.45s	remaining: 267ms
# 844:	learn: 183784.9552945	total: 1.45s	remaining: 266ms
# 845:	learn: 183730.5529513	total: 1.45s	remaining: 264ms
# 846:	learn: 183701.1851226	total: 1.45s	remaining: 262ms
# 847:	learn: 183660.3734375	total: 1.45s	remaining: 261ms
# 848:	learn: 183650.3238337	total: 1.46s	remaining: 259ms
# 849:	learn: 183503.4634935	total: 1.46s	remaining: 257ms
# 850:	learn: 183360.2222233	total: 1.46s	remaining: 255ms
# 851:	learn: 183335.6301776	total: 1.46s	remaining: 254ms
# 852:	learn: 183171.5980457	total: 1.46s	remaining: 252ms
# 853:	learn: 183156.6325688	total: 1.46s	remaining: 250ms
# 854:	learn: 183120.8291942	total: 1.47s	remaining: 248ms
# 855:	learn: 183038.9390430	total: 1.47s	remaining: 247ms
# 856:	learn: 182964.8197848	total: 1.47s	remaining: 245ms
# 857:	learn: 182869.0838458	total: 1.48s	remaining: 244ms
# 858:	learn: 182811.3965288	total: 1.48s	remaining: 243ms
# 859:	learn: 182710.2396656	total: 1.48s	remaining: 241ms
# 860:	learn: 182702.9945515	total: 1.48s	remaining: 239ms
# 861:	learn: 182638.7197355	total: 1.48s	remaining: 237ms
# 862:	learn: 182557.1807564	total: 1.49s	remaining: 236ms
# 863:	learn: 182491.0723681	total: 1.49s	remaining: 234ms
# 864:	learn: 182420.4128948	total: 1.49s	remaining: 232ms
# 865:	learn: 182379.0265073	total: 1.49s	remaining: 231ms
# 866:	learn: 182247.4637922	total: 1.49s	remaining: 229ms
# 867:	learn: 182206.5079850	total: 1.49s	remaining: 227ms
# 868:	learn: 181976.2406285	total: 1.5s	remaining: 225ms
# 869:	learn: 181876.8509040	total: 1.5s	remaining: 224ms
# 870:	learn: 181840.0322918	total: 1.5s	remaining: 222ms
# 871:	learn: 181723.3623115	total: 1.5s	remaining: 220ms
# 872:	learn: 181613.4415199	total: 1.5s	remaining: 219ms
# 873:	learn: 181547.3457523	total: 1.5s	remaining: 217ms
# 874:	learn: 181539.9311900	total: 1.51s	remaining: 215ms
# 875:	learn: 181457.6314552	total: 1.51s	remaining: 213ms
# 876:	learn: 181274.9074885	total: 1.51s	remaining: 212ms
# 877:	learn: 181120.6062180	total: 1.51s	remaining: 210ms
# 878:	learn: 181110.3698407	total: 1.51s	remaining: 208ms
# 879:	learn: 181035.2809055	total: 1.51s	remaining: 206ms
# 880:	learn: 180904.4373978	total: 1.52s	remaining: 205ms
# 881:	learn: 180795.3713291	total: 1.52s	remaining: 203ms
# 882:	learn: 180741.7639528	total: 1.52s	remaining: 201ms
# 883:	learn: 180572.8270910	total: 1.52s	remaining: 200ms
# 884:	learn: 180457.7580059	total: 1.52s	remaining: 198ms
# 885:	learn: 180414.6054854	total: 1.52s	remaining: 196ms
# 886:	learn: 180371.1311227	total: 1.53s	remaining: 194ms
# 887:	learn: 180274.1366173	total: 1.53s	remaining: 193ms
# 888:	learn: 180248.6683563	total: 1.53s	remaining: 191ms
# 889:	learn: 180157.8012529	total: 1.53s	remaining: 189ms
# 890:	learn: 179984.7889116	total: 1.53s	remaining: 188ms
# 891:	learn: 179844.6985991	total: 1.54s	remaining: 186ms
# 892:	learn: 179739.8683404	total: 1.54s	remaining: 184ms
# 893:	learn: 179717.6364912	total: 1.54s	remaining: 183ms
# 894:	learn: 179617.8667744	total: 1.54s	remaining: 181ms
# 895:	learn: 179591.6459352	total: 1.54s	remaining: 179ms
# 896:	learn: 179560.8806306	total: 1.54s	remaining: 177ms
# 897:	learn: 179553.8817067	total: 1.55s	remaining: 176ms
# 898:	learn: 179483.9969783	total: 1.55s	remaining: 174ms
# 899:	learn: 179419.6880356	total: 1.55s	remaining: 172ms
# 900:	learn: 179312.7186562	total: 1.55s	remaining: 171ms
# 901:	learn: 179281.6042083	total: 1.55s	remaining: 169ms
# 902:	learn: 179256.1822810	total: 1.55s	remaining: 167ms
# 903:	learn: 179212.3167662	total: 1.56s	remaining: 165ms
# 904:	learn: 179174.2608201	total: 1.56s	remaining: 164ms
# 905:	learn: 179076.4139531	total: 1.56s	remaining: 162ms
# 906:	learn: 178968.9504433	total: 1.56s	remaining: 160ms
# 907:	learn: 178956.9132339	total: 1.56s	remaining: 158ms
# 908:	learn: 178883.5233976	total: 1.56s	remaining: 157ms
# 909:	learn: 178834.2471298	total: 1.57s	remaining: 155ms
# 910:	learn: 178673.4268936	total: 1.57s	remaining: 153ms
# 911:	learn: 178583.0733100	total: 1.57s	remaining: 152ms
# 912:	learn: 178543.4698947	total: 1.57s	remaining: 150ms
# 913:	learn: 178428.2907486	total: 1.57s	remaining: 148ms
# 914:	learn: 178404.3877697	total: 1.58s	remaining: 147ms
# 915:	learn: 178373.5969157	total: 1.58s	remaining: 145ms
# 916:	learn: 178326.7539951	total: 1.58s	remaining: 143ms
# 917:	learn: 178221.1916381	total: 1.58s	remaining: 141ms
# 918:	learn: 178175.9733501	total: 1.58s	remaining: 140ms
# 919:	learn: 178133.5360057	total: 1.58s	remaining: 138ms
# 920:	learn: 178046.5312312	total: 1.59s	remaining: 136ms
# 921:	learn: 177945.7534570	total: 1.59s	remaining: 134ms
# 922:	learn: 177902.1052760	total: 1.59s	remaining: 133ms
# 923:	learn: 177891.7415329	total: 1.59s	remaining: 131ms
# 924:	learn: 177884.9291309	total: 1.59s	remaining: 129ms
# 925:	learn: 177762.9532051	total: 1.59s	remaining: 128ms
# 926:	learn: 177629.4497007	total: 1.6s	remaining: 126ms
# 927:	learn: 177561.8485932	total: 1.6s	remaining: 124ms
# 928:	learn: 177481.1565950	total: 1.6s	remaining: 122ms
# 929:	learn: 177383.8401339	total: 1.6s	remaining: 121ms
# 930:	learn: 177193.8588333	total: 1.6s	remaining: 119ms
# 931:	learn: 177105.9869045	total: 1.6s	remaining: 117ms
# 932:	learn: 177022.1248261	total: 1.61s	remaining: 115ms
# 933:	learn: 176973.6307645	total: 1.61s	remaining: 114ms
# 934:	learn: 176899.4837854	total: 1.61s	remaining: 112ms
# 935:	learn: 176780.2313457	total: 1.61s	remaining: 110ms
# 936:	learn: 176729.5274364	total: 1.61s	remaining: 109ms
# 937:	learn: 176721.6279543	total: 1.61s	remaining: 107ms
# 938:	learn: 176605.9179604	total: 1.62s	remaining: 105ms
# 939:	learn: 176548.1718481	total: 1.62s	remaining: 103ms
# 940:	learn: 176535.4085227	total: 1.62s	remaining: 102ms
# 941:	learn: 176415.6391682	total: 1.62s	remaining: 99.9ms
# 942:	learn: 176245.2656672	total: 1.62s	remaining: 98.2ms
# 943:	learn: 176235.0525316	total: 1.63s	remaining: 96.5ms
# 944:	learn: 176194.9957247	total: 1.63s	remaining: 94.7ms
# 945:	learn: 176101.9942796	total: 1.63s	remaining: 93ms
# 946:	learn: 176060.1223283	total: 1.63s	remaining: 91.3ms
# 947:	learn: 175989.8274172	total: 1.63s	remaining: 89.6ms
# 948:	learn: 175983.0692215	total: 1.63s	remaining: 87.8ms
# 949:	learn: 175934.8441652	total: 1.64s	remaining: 86.1ms
# 950:	learn: 175868.4300441	total: 1.64s	remaining: 84.4ms
# 951:	learn: 175676.7801789	total: 1.64s	remaining: 82.7ms
# 952:	learn: 175669.2738862	total: 1.64s	remaining: 80.9ms
# 953:	learn: 175586.4719198	total: 1.64s	remaining: 79.2ms
# 954:	learn: 175575.5902481	total: 1.64s	remaining: 77.5ms
# 955:	learn: 175517.4346963	total: 1.65s	remaining: 75.7ms
# 956:	learn: 175503.7681324	total: 1.65s	remaining: 74ms
# 957:	learn: 175345.2113306	total: 1.65s	remaining: 72.3ms
# 958:	learn: 175290.5324371	total: 1.65s	remaining: 70.6ms
# 959:	learn: 175226.8235988	total: 1.65s	remaining: 68.8ms
# 960:	learn: 175064.7006085	total: 1.65s	remaining: 67.1ms
# 961:	learn: 175004.2623779	total: 1.66s	remaining: 65.4ms
# 962:	learn: 174891.6141671	total: 1.66s	remaining: 63.7ms
# 963:	learn: 174838.9348316	total: 1.66s	remaining: 61.9ms
# 964:	learn: 174809.2425921	total: 1.66s	remaining: 60.2ms
# 965:	learn: 174764.3708554	total: 1.66s	remaining: 58.5ms
# 966:	learn: 174701.3385688	total: 1.66s	remaining: 56.8ms
# 967:	learn: 174617.7537976	total: 1.67s	remaining: 55.1ms
# 968:	learn: 174567.9417552	total: 1.67s	remaining: 53.3ms
# 969:	learn: 174543.0524881	total: 1.67s	remaining: 51.6ms
# 970:	learn: 174521.7398719	total: 1.67s	remaining: 49.9ms
# 971:	learn: 174401.0981957	total: 1.67s	remaining: 48.2ms
# 972:	learn: 174309.4955264	total: 1.67s	remaining: 46.4ms
# 973:	learn: 174282.9977493	total: 1.68s	remaining: 44.7ms
# 974:	learn: 174276.7436919	total: 1.68s	remaining: 43ms
# 975:	learn: 174196.1027348	total: 1.68s	remaining: 41.3ms
# 976:	learn: 174108.9670478	total: 1.68s	remaining: 39.6ms
# 977:	learn: 174095.2854059	total: 1.68s	remaining: 37.8ms
# 978:	learn: 174028.6546545	total: 1.68s	remaining: 36.1ms
# 979:	learn: 173884.2882033	total: 1.68s	remaining: 34.4ms
# 980:	learn: 173872.8178128	total: 1.69s	remaining: 32.7ms
# 981:	learn: 173811.2001276	total: 1.69s	remaining: 30.9ms
# 982:	learn: 173805.1762659	total: 1.69s	remaining: 29.2ms
# 983:	learn: 173686.0260258	total: 1.69s	remaining: 27.5ms
# 984:	learn: 173603.5428767	total: 1.69s	remaining: 25.8ms
# 985:	learn: 173561.9233615	total: 1.69s	remaining: 24.1ms
# 986:	learn: 173475.6397098	total: 1.7s	remaining: 22.3ms
# 987:	learn: 173419.7998533	total: 1.7s	remaining: 20.6ms
# 988:	learn: 173400.6316677	total: 1.7s	remaining: 18.9ms
# 989:	learn: 173341.4796305	total: 1.7s	remaining: 17.2ms
# 990:	learn: 173200.9000620	total: 1.7s	remaining: 15.5ms
# 991:	learn: 173194.2259694	total: 1.7s	remaining: 13.7ms
# 992:	learn: 173140.7151897	total: 1.71s	remaining: 12ms
# 993:	learn: 173025.4086829	total: 1.71s	remaining: 10.3ms
# 994:	learn: 172923.4660229	total: 1.71s	remaining: 8.59ms
# 995:	learn: 172917.4698986	total: 1.71s	remaining: 6.87ms
# 996:	learn: 172815.6526902	total: 1.71s	remaining: 5.15ms
# 997:	learn: 172766.1922425	total: 1.71s	remaining: 3.44ms
# 998:	learn: 172671.1165437	total: 1.72s	remaining: 1.72ms
# 999:	learn: 172619.9836137	total: 1.72s	remaining: 0us
# 445848.88166745304

# %% [markdown]
# ## Отбор признаков
# Благодаря созданию новых признаков и их дальнейшей обработке в наборе уже несколько десятков признаков. Наверное уже имеет смысл попробовать отбросить те из них, что неполезны для модели - это вероятно улучшит качество и точно ускорит обучение.
#
# Прибегнем к отбору при помощи Lasso . Обучим эту модель на обогащенном по признакам и оптимизированном по количеству наблюдений наборе данных.

# %%
'''
from sklearn.linear_model import Lasso

selector = Lasso(alpha=0.0001)
selector.fit(X_train,y_train)

Lasso(alpha=0.0001, copy_X=True, fit_intercept=True, max_iter=1000,
      normalize=False, positive=False, precompute=False, random_state=None,
      selection='cyclic', tol=0.0001, warm_start=False)

Теперь получим список наименее полезных с точки зрения модели признков

sorted_by_Lasso = abs(pd.Series(selector.coef_,index = X_train.columns)).sort_values()

unuseful_features_LR = sorted_by_Lasso[sorted_by_Lasso<0.5].index

unuseful_features_LR

sorted_by_Lasso
''';

# %% [markdown]
# ### PCA

# %%
scaler = StandardScaler()

# %%
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.fit_transform(X_test)

# %%
# pca = PCA(n_components = 1)
pca = PCA(0.95)
# XPCAreduced = pca.fit_transform(transpose(X))

# %%
# %%time
X_train_pca = pca.fit_transform(X_train_sc)
X_test_pca = pca.transform(X_test_sc)
# Out:
# Wall time: 130 ms

# %%
pca.n_components_
# Out:
# 172

# %%
validation(X_train_pca, y_train, RandomForestRegressor())
# Out:
# C:\Users\GANSOR-PC\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\GANSOR-PC\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\GANSOR-PC\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 914990.1340453388

# %%
validation(X_train_pca, y_train, GradientBoostingRegressor())
# Out:
# 856840.338493982

# %%
validation(X_train_pca, y_train, AdaBoostRegressor())
# Out:
# 1413691.2935284644

# %% [markdown]
# ## Подбор гиперпараметров

# %%
logspace(-6,-1,6)
# Out:
# array([1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])

# %%
hyperparameters = {
#                    'loss' : ['ls', 'lad', 'huber', 'quantile'], 
                   'learning_rate ': [0.01,0.1]
#                    'n_estimators ': [100, 300, 500], 
#                    'max_depth':  [3,4,5],
#                    'min_samples_split ': [2,3,5],
#                    'min_samples_leaf  ': [1,2,3,5],
#                    'subsample' : [1],
#                    'max_features  ': ['auto', 'sqrt', 'log2']
}

# %%
hyperparameters
# Out:
# {'learning_rate ': [0.01, 0.1]}

# %%
# %%time
n_iter = 2
search = pd.Series()

model = XGBRegressor()
clf = RandomizedSearchCV(model, hyperparameters, n_iter=n_iter, 
                         scoring='neg_mean_absolute_error', cv=3, random_state=RANDOM_SEED)
# Out:
# Wall time: 961 µs

# %%
search = clf.fit(X_train, y_train)
# Out:
# C:\Users\GANSOR-PC\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [18:21:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\GANSOR-PC\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [18:21:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\GANSOR-PC\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [18:21:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\GANSOR-PC\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [18:21:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\GANSOR-PC\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [18:21:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\GANSOR-PC\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [18:21:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\GANSOR-PC\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\GANSOR-PC\Anaconda3\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [18:21:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
search.best_score_
# Out:
# -438209.2355100136

# %% [markdown]
# ## Подсобное

# %% [markdown]
# ## ПОДВАЛ

# %% [markdown]
# RandomForestRegressor
# GradientBoostingRegressor
# AdaBoostRegressor

# %%
pca
# Out:
# PCA(copy=True, iterated_power='auto', n_components=1, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
pca_2
# Out:
# PCA(copy=True, iterated_power='auto', n_components=0.95, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)
