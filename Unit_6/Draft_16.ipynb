# %%
import requests

from pprint import pprint

# %% [markdown]
# ## 9.2 Библиотека requests
# Сначала разберемся, как получить информацию с внешнего сервиса. В стандартной библиотеке есть модуль `urllib2`, который может справиться с этой задачей. Однако большинство разработчиков используют стороннюю библиотеку `requests`, потому что в ней лучше реализованы большинство методов и код получается проще. Перед началом работы библиотеку потребуется установить с помощью вашего пакетного менеджера, например, с помощью следующей команды в консоли.
#
# ```
# python -m pip install requests
# ```
# Далее мы импортируем библиотеку и отправим запрос к сервису с помощью метода `GET` к сервису с курсами валют:

# %%
import requests  
response = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')

# %%
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ### Задание 1 - Первый запрос
# Допустим, вы уже импортировали модуль `requests` в ваш код. Какая команда сделает `GET` запрос к сайту https://www.cbr-xml-daily.ru/daily.xml и положит результат в переменную response?

# %%
response = requests.get('https://www.cbr-xml-daily.ru/daily.xml')

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# ## 9.3 Читаем результат
# Мы сделали запрос и получили ответ. Давайте теперь посмотрим, как считывать текст.
#
# Адрес, по которому мы обращались, возвращает результат в `json` формате. Эти данные уже лежат в атрибуте `text` в полученном ответе response:

# %%
import requests    
response = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')    
print(response.text)
# Out:
# {
#     "Date": "2020-10-23T11:30:00+03:00",
#     "PreviousDate": "2020-10-22T11:30:00+03:00",
#     "PreviousURL": "\/\/www.cbr-xml-daily.ru\/archive\/2020\/10\/22\/daily_json.js",
#     "Timestamp": "2020-10-22T23:00:00+03:00",
#     "Valute": {
#         "AUD": {
#             "ID": "R01010",
#             "NumCode": "036",
#             "CharCode": "AUD",
#             "Nominal": 1,
#             "Name": "Австралийский доллар",
#             "Value": 54.8122,
#             "Previous": 54.5388
#         },
#         "AZN": {
#             "ID": "R01020A",
#             "NumCode": "944",
#             "CharCode": "AZN",
#             "Nominal": 1,
#             "Name": "Азербайджанский манат",
#             "Value": 45.3684,
#             "Previous": 45.3397
#         },
#         "GBP": {
#             "ID": "R01035",
#             "NumCode": "826",
#             "CharCode": "GBP",
#             "Nominal": 1,
#             "Name": "Фунт стерлингов Соединенного королевства",
#             "Value": 101.2226,
#             "Previous": 100.5116
#         },
#         "AMD": {
#             "ID": "R01060",
#             "NumCode": "051",
#             "CharCode": "AMD",
#             "Nominal": 100,
#             "Name": "Армянских драмов",
#             "Value": 15.5917,
#             "Previous": 15.6157
#         },
#         "BYN": {
#             "ID": "R01090B",
#             "NumCode": "933",
#             "CharCode": "BYN",
#             "Nominal": 1,
#             "Name": "Белорусский рубль",
#             "Value": 30.2908,
#             "Previous": 30.2716
#         },
#         "BGN": {
#             "ID": "R01100",
#             "NumCode": "975",
#             "CharCode": "BGN",
#             "Nominal": 1,
#             "Name": "Болгарский лев",
#             "Value": 46.71,
#             "Previous": 46.6947
#         },
#         "BRL": {
#             "ID": "R01115",
#             "NumCode": "986",
#             "CharCode": "BRL",
#             "Nominal": 1,
#             "Name": "Бразильский реал",
#             "Value": 13.7419,
#             "Previous": 13.7418
#         },
#         "HUF": {
#             "ID": "R01135",
#             "NumCode": "348",
#             "CharCode": "HUF",
#             "Nominal": 100,
#             "Name": "Венгерских форинтов",
#             "Value": 25.0527,
#             "Previous": 25.1608
#         },
#         "HKD": {
#             "ID": "R01200",
#             "NumCode": "344",
#             "CharCode": "HKD",
#             "Nominal": 10,
#             "Name": "Гонконгских долларов",
#             "Value": 99.4579,
#             "Previous": 99.3951
#         },
#         "DKK": {
#             "ID": "R01215",
#             "NumCode": "208",
#             "CharCode": "DKK",
#             "Nominal": 1,
#             "Name": "Датская крона",
#             "Value": 12.2756,
#             "Previous": 12.2702
#         },
#         "USD": {
#             "ID": "R01235",
#             "NumCode": "840",
#             "CharCode": "USD",
#             "Nominal": 1,
#             "Name": "Доллар США",
#             "Value": 77.0809,
#             "Previous": 77.0322
#         },
#         "EUR": {
#             "ID": "R01239",
#             "NumCode": "978",
#             "CharCode": "EUR",
#             "Nominal": 1,
#             "Name": "Евро",
#             "Value": 91.3563,
#             "Previous": 91.3448
#         },
#         "INR": {
#             "ID": "R01270",
#             "NumCode": "356",
#             "CharCode": "INR",
#             "Nominal": 10,
#             "Name": "Индийских рупий",
#             "Value": 10.4818,
#             "Previous": 10.471
#         },
#         "KZT": {
#             "ID": "R01335",
#             "NumCode": "398",
#             "CharCode": "KZT",
#             "Nominal": 100,
#             "Name": "Казахстанских тенге",
#             "Value": 17.9869,
#             "Previous": 18.0007
#         },
#         "CAD": {
#             "ID": "R01350",
#             "NumCode": "124",
#             "CharCode": "CAD",
#             "Nominal": 1,
#             "Name": "Канадский доллар",
#             "Value": 58.6702,
#             "Previous": 58.7628
#         },
#         "KGS": {
#             "ID": "R01370",
#             "NumCode": "417",
#             "CharCode": "KGS",
#             "Nominal": 100,
#             "Name": "Киргизских сомов",
#             "Value": 95.3651,
#             "Previous": 94.8296
#         },
#         "CNY": {
#             "ID": "R01375",
#             "NumCode": "156",
#             "CharCode": "CNY",
#             "Nominal": 1,
#             "Name": "Китайский юань",
#             "Value": 11.5577,
#             "Previous": 11.57
#         },
#         "MDL": {
#             "ID": "R01500",
#             "NumCode": "498",
#             "CharCode": "MDL",
#             "Nominal": 10,
#             "Name": "Молдавских леев",
#             "Value": 45.2485,
#             "Previous": 45.1802
#         },
#         "NOK": {
#             "ID": "R01535",
#             "NumCode": "578",
#             "CharCode": "NOK",
#             "Nominal": 10,
#             "Name": "Норвежских крон",
#             "Value": 83.6563,
#             "Previous": 83.6179
#         },
#         "PLN": {
#             "ID": "R01565",
#             "NumCode": "985",
#             "CharCode": "PLN",
#             "Nominal": 1,
#             "Name": "Польский злотый",
#             "Value": 19.95,
#             "Previous": 19.9555
#         },
#         "RON": {
#             "ID": "R01585F",
#             "NumCode": "946",
#             "CharCode": "RON",
#             "Nominal": 1,
#             "Name": "Румынский лей",
#             "Value": 18.7344,
#             "Previous": 18.7362
#         },
#         "XDR": {
#             "ID": "R01589",
#             "NumCode": "960",
#             "CharCode": "XDR",
#             "Nominal": 1,
#             "Name": "СДР (специальные права заимствования)",
#             "Value": 109.4703,
#             "Previous": 109.0676
#         },
#         "SGD": {
#             "ID": "R01625",
#             "NumCode": "702",
#             "CharCode": "SGD",
#             "Nominal": 1,
#             "Name": "Сингапурский доллар",
#             "Value": 56.8569,
#             "Previous": 56.8503
#         },
#         "TJS": {
#             "ID": "R01670",
#             "NumCode": "972",
#             "CharCode": "TJS",
#             "Nominal": 10,
#             "Name": "Таджикских сомони",
#             "Value": 74.5824,
#             "Previous": 74.6436
#         },
#         "TRY": {
#             "ID": "R01700J",
#             "NumCode": "949",
#             "CharCode": "TRY",
#             "Nominal": 10,
#             "Name": "Турецких лир",
#             "Value": 98.6964,
#             "Previous": 98.3369
#         },
#         "TMT": {
#             "ID": "R01710A",
#             "NumCode": "934",
#             "CharCode": "TMT",
#             "Nominal": 1,
#             "Name": "Новый туркменский манат",
#             "Value": 22.0546,
#             "Previous": 22.0407
#         },
#         "UZS": {
#             "ID": "R01717",
#             "NumCode": "860",
#             "CharCode": "UZS",
#             "Nominal": 10000,
#             "Name": "Узбекских сумов",
#             "Value": 74.3181,
#             "Previous": 74.3411
#         },
#         "UAH": {
#             "ID": "R01720",
#             "NumCode": "980",
#             "CharCode": "UAH",
#             "Nominal": 10,
#             "Name": "Украинских гривен",
#             "Value": 27.2793,
#             "Previous": 27.2699
#         },
#         "CZK": {
#             "ID": "R01760",
#             "NumCode": "203",
#             "CharCode": "CZK",
#             "Nominal": 10,
#             "Name": "Чешских крон",
#             "Value": 33.5076,
#             "Previous": 33.5725
#         },
#         "SEK": {
#             "ID": "R01770",
#             "NumCode": "752",
#             "CharCode": "SEK",
#             "Nominal": 10,
#             "Name": "Шведских крон",
#             "Value": 88.1106,
#             "Previous": 88.2334
#         },
#         "CHF": {
#             "ID": "R01775",
#             "NumCode": "756",
#             "CharCode": "CHF",
#             "Nominal": 1,
#             "Name": "Швейцарский франк",
#             "Value": 85.022,
#             "Previous": 85.1749
#         },
#         "ZAR": {
#             "ID": "R01810",
#             "NumCode": "710",
#             "CharCode": "ZAR",
#             "Nominal": 10,
#             "Name": "Южноафриканских рэндов",
#             "Value": 47.3647,
#             "Previous": 46.9042
#         },
#         "KRW": {
#             "ID": "R01815",
#             "NumCode": "410",
#             "CharCode": "KRW",
#             "Nominal": 1000,
#             "Name": "Вон Республики Корея",
#             "Value": 68.0251,
#             "Previous": 67.9707
#         },
#         "JPY": {
#             "ID": "R01820",
#             "NumCode": "392",
#             "CharCode": "JPY",
#             "Nominal": 100,
#             "Name": "Японских иен",
#             "Value": 73.6946,
#             "Previous": 73.4269
#         }
#     }
# }

# %% [markdown]
# Вы можете посмотреть на полный текст, повторив запрос или [на этой странице](https://www.cbr-xml-daily.ru/daily_json.js) в вашем браузере.
#
# Сейчас текст хранится просто в строковой переменной. Далее мы можем превратить эту строку в словарь. Сделать это можно с помощью `JSON`-парсера `python`, либо воспользовавшись методом `json`, который уже встроен в объект ответа `response`:

# %%
currencies = response.json()  
pprint(currencies)
# Out:
# {'Date': '2020-10-23T11:30:00+03:00',
#  'PreviousDate': '2020-10-22T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2020/10/22/daily_json.js',
#  'Timestamp': '2020-10-22T23:00:00+03:00',
#  'Valute': {'AMD': {'CharCode': 'AMD',
#                     'ID': 'R01060',
#                     'Name': 'Армянских драмов',
#                     'Nominal': 100,
#                     'NumCode': '051',
#                     'Previous': 15.6157,
#                     'Value': 15.5917},
#             'AUD': {'CharCode': 'AUD',
#                     'ID': 'R01010',
#                     'Name': 'Австралийский доллар',
#                     'Nominal': 1,
#                     'NumCode': '036',
#                     'Previous': 54.5388,
#                     'Value': 54.8122},
#             'AZN': {'CharCode': 'AZN',
#                     'ID': 'R01020A',
#                     'Name': 'Азербайджанский манат',
#                     'Nominal': 1,
#                     'NumCode': '944',
#                     'Previous': 45.3397,
#                     'Value': 45.3684},
#             'BGN': {'CharCode': 'BGN',
#                     'ID': 'R01100',
#                     'Name': 'Болгарский лев',
#                     'Nominal': 1,
#                     'NumCode': '975',
#                     'Previous': 46.6947,
#                     'Value': 46.71},
#             'BRL': {'CharCode': 'BRL',
#                     'ID': 'R01115',
#                     'Name': 'Бразильский реал',
#                     'Nominal': 1,
#                     'NumCode': '986',
#                     'Previous': 13.7418,
#                     'Value': 13.7419},
#             'BYN': {'CharCode': 'BYN',
#                     'ID': 'R01090B',
#                     'Name': 'Белорусский рубль',
#                     'Nominal': 1,
#                     'NumCode': '933',
#                     'Previous': 30.2716,
#                     'Value': 30.2908},
#             'CAD': {'CharCode': 'CAD',
#                     'ID': 'R01350',
#                     'Name': 'Канадский доллар',
#                     'Nominal': 1,
#                     'NumCode': '124',
#                     'Previous': 58.7628,
#                     'Value': 58.6702},
#             'CHF': {'CharCode': 'CHF',
#                     'ID': 'R01775',
#                     'Name': 'Швейцарский франк',
#                     'Nominal': 1,
#                     'NumCode': '756',
#                     'Previous': 85.1749,
#                     'Value': 85.022},
#             'CNY': {'CharCode': 'CNY',
#                     'ID': 'R01375',
#                     'Name': 'Китайский юань',
#                     'Nominal': 1,
#                     'NumCode': '156',
#                     'Previous': 11.57,
#                     'Value': 11.5577},
#             'CZK': {'CharCode': 'CZK',
#                     'ID': 'R01760',
#                     'Name': 'Чешских крон',
#                     'Nominal': 10,
#                     'NumCode': '203',
#                     'Previous': 33.5725,
#                     'Value': 33.5076},
#             'DKK': {'CharCode': 'DKK',
#                     'ID': 'R01215',
#                     'Name': 'Датская крона',
#                     'Nominal': 1,
#                     'NumCode': '208',
#                     'Previous': 12.2702,
#                     'Value': 12.2756},
#             'EUR': {'CharCode': 'EUR',
#                     'ID': 'R01239',
#                     'Name': 'Евро',
#                     'Nominal': 1,
#                     'NumCode': '978',
#                     'Previous': 91.3448,
#                     'Value': 91.3563},
#             'GBP': {'CharCode': 'GBP',
#                     'ID': 'R01035',
#                     'Name': 'Фунт стерлингов Соединенного королевства',
#                     'Nominal': 1,
#                     'NumCode': '826',
#                     'Previous': 100.5116,
#                     'Value': 101.2226},
#             'HKD': {'CharCode': 'HKD',
#                     'ID': 'R01200',
#                     'Name': 'Гонконгских долларов',
#                     'Nominal': 10,
#                     'NumCode': '344',
#                     'Previous': 99.3951,
#                     'Value': 99.4579},
#             'HUF': {'CharCode': 'HUF',
#                     'ID': 'R01135',
#                     'Name': 'Венгерских форинтов',
#                     'Nominal': 100,
#                     'NumCode': '348',
#                     'Previous': 25.1608,
#                     'Value': 25.0527},
#             'INR': {'CharCode': 'INR',
#                     'ID': 'R01270',
#                     'Name': 'Индийских рупий',
#                     'Nominal': 10,
#                     'NumCode': '356',
#                     'Previous': 10.471,
#                     'Value': 10.4818},
#             'JPY': {'CharCode': 'JPY',
#                     'ID': 'R01820',
#                     'Name': 'Японских иен',
#                     'Nominal': 100,
#                     'NumCode': '392',
#                     'Previous': 73.4269,
#                     'Value': 73.6946},
#             'KGS': {'CharCode': 'KGS',
#                     'ID': 'R01370',
#                     'Name': 'Киргизских сомов',
#                     'Nominal': 100,
#                     'NumCode': '417',
#                     'Previous': 94.8296,
#                     'Value': 95.3651},
#             'KRW': {'CharCode': 'KRW',
#                     'ID': 'R01815',
#                     'Name': 'Вон Республики Корея',
#                     'Nominal': 1000,
#                     'NumCode': '410',
#                     'Previous': 67.9707,
#                     'Value': 68.0251},
#             'KZT': {'CharCode': 'KZT',
#                     'ID': 'R01335',
#                     'Name': 'Казахстанских тенге',
#                     'Nominal': 100,
#                     'NumCode': '398',
#                     'Previous': 18.0007,
#                     'Value': 17.9869},
#             'MDL': {'CharCode': 'MDL',
#                     'ID': 'R01500',
#                     'Name': 'Молдавских леев',
#                     'Nominal': 10,
#                     'NumCode': '498',
#                     'Previous': 45.1802,
#                     'Value': 45.2485},
#             'NOK': {'CharCode': 'NOK',
#                     'ID': 'R01535',
#                     'Name': 'Норвежских крон',
#                     'Nominal': 10,
#                     'NumCode': '578',
#                     'Previous': 83.6179,
#                     'Value': 83.6563},
#             'PLN': {'CharCode': 'PLN',
#                     'ID': 'R01565',
#                     'Name': 'Польский злотый',
#                     'Nominal': 1,
#                     'NumCode': '985',
#                     'Previous': 19.9555,
#                     'Value': 19.95},
#             'RON': {'CharCode': 'RON',
#                     'ID': 'R01585F',
#                     'Name': 'Румынский лей',
#                     'Nominal': 1,
#                     'NumCode': '946',
#                     'Previous': 18.7362,
#                     'Value': 18.7344},
#             'SEK': {'CharCode': 'SEK',
#                     'ID': 'R01770',
#                     'Name': 'Шведских крон',
#                     'Nominal': 10,
#                     'NumCode': '752',
#                     'Previous': 88.2334,
#                     'Value': 88.1106},
#             'SGD': {'CharCode': 'SGD',
#                     'ID': 'R01625',
#                     'Name': 'Сингапурский доллар',
#                     'Nominal': 1,
#                     'NumCode': '702',
#                     'Previous': 56.8503,
#                     'Value': 56.8569},
#             'TJS': {'CharCode': 'TJS',
#                     'ID': 'R01670',
#                     'Name': 'Таджикских сомони',
#                     'Nominal': 10,
#                     'NumCode': '972',
#                     'Previous': 74.6436,
#                     'Value': 74.5824},
#             'TMT': {'CharCode': 'TMT',
#                     'ID': 'R01710A',
#                     'Name': 'Новый туркменский манат',
#                     'Nominal': 1,
#                     'NumCode': '934',
#                     'Previous': 22.0407,
#                     'Value': 22.0546},
#             'TRY': {'CharCode': 'TRY',
#                     'ID': 'R01700J',
#                     'Name': 'Турецких лир',
#                     'Nominal': 10,
#                     'NumCode': '949',
#                     'Previous': 98.3369,
#                     'Value': 98.6964},
#             'UAH': {'CharCode': 'UAH',
#                     'ID': 'R01720',
#                     'Name': 'Украинских гривен',
#                     'Nominal': 10,
#                     'NumCode': '980',
#                     'Previous': 27.2699,
#                     'Value': 27.2793},
#             'USD': {'CharCode': 'USD',
#                     'ID': 'R01235',
#                     'Name': 'Доллар США',
#                     'Nominal': 1,
#                     'NumCode': '840',
#                     'Previous': 77.0322,
#                     'Value': 77.0809},
#             'UZS': {'CharCode': 'UZS',
#                     'ID': 'R01717',
#                     'Name': 'Узбекских сумов',
#                     'Nominal': 10000,
#                     'NumCode': '860',
#                     'Previous': 74.3411,
#                     'Value': 74.3181},
#             'XDR': {'CharCode': 'XDR',
#                     'ID': 'R01589',
#                     'Name': 'СДР (специальные права заимствования)',
#                     'Nominal': 1,
#                     'NumCode': '960',
#                     'Previous': 109.0676,
#                     'Value': 109.4703},
#             'ZAR': {'CharCode': 'ZAR',
#                     'ID': 'R01810',
#                     'Name': 'Южноафриканских рэндов',
#                     'Nominal': 10,
#                     'NumCode': '710',
#                     'Previous': 46.9042,
#                     'Value': 47.3647}}}

# %%
Теперь данные лежат в словаре, и мы можем легко получать необходимые нам значения:

# %%
currencies['Valute']['UAH']
# Out:
# {'ID': 'R01720',
#  'NumCode': '980',
#  'CharCode': 'UAH',
#  'Nominal': 10,
#  'Name': 'Украинских гривен',
#  'Value': 27.2793,
#  'Previous': 27.2699}

# %% [markdown]
# ### Задание 1
# Повторите запросы, описанные в этой части, на своём компьютере. Что выведет на экран следующий код?
# ```python
# print(currencies['Valute']['CZK']['Name'])
# ```

# %%
print(currencies['Valute']['CZK']['Name'])
# Out:
# Чешских крон

# %% [markdown]
# ## 9.4 Оформляем функцию
# В завершение давайте оформим наши вычисления в отдельную функцию, которой будет удобно пользоваться. На вход она должна принимать два параметра:
#
# 1. Название валюты `currency`. Например, ***'EUR'*** или ***'USD'***.
#
# 2. Формат ответа `format`. При значении ***'full'*** будем отдавать все, что знаем о валюте. Например, для currency = 'USD':
#
# >{'CharCode': 'USD',
# >   'ID': 'R01235',
# >   'Name': 'Доллар США',
# >   'Nominal': 1,
# >   'NumCode': '840',
# >   'Previous': 68.2505,
# >   'Value': 69.0286}
#
# А при значении format = ***'value'*** только значение ключа `'Value'`, т. е. курс: ***69.0286***.
#
# Оформим наши требования в коде:

# %%
def exchange_rates(currency, format='full'):    
    url = 'https://www.cbr-xml-daily.ru/daily_json.js'  
    response = requests.get(url).json()['Valute']    
    data = response[currency]     
    if format == 'full':    
        return data      
    elif format == 'value':    
        return data['Value']

# %% [markdown]
# ### Задание 1
# Напишите функцию `currency_name`, которая по ***ID*** валюты возвращает ее название на русском языке.

# %%
def currency_name(currency_id):
    url = 'https://www.cbr-xml-daily.ru/daily_json.js'
    response = requests.get(url).json()['Valute']
    
    for currency in response:
        if response[currency]['ID'] == currency_id:
            return response[currency]['Name']

# %%
currency_name('R01700J')
# Out:
# 'Турецких лир'

# %% [markdown]
# ## 9.5 HTML-страницы
# ### Постановка задачи
# Довольно часто приходится добывать информацию не из удобно форматированного json-файла, а прямо с HTML-страниц. Получить содержимое страницы в большинстве случаев несложно, труднее извлечь из HTML-кода нужную информацию. В качестве примера мы рассмотрим страницу новости, из которой будем доставать полезную информацию:
#  1. заголовок страницы;
#  2. дату публикации;
#  3. текст публикации;
#  4. ссылки на странице.
#
# ### Получаем данные
# Получить `html` страницу можно так же, как мы получали до этого `json`: используем библиотеку `requests` и метод `GET`:
#
# ```python
# import requests
#
# url = 'https://nplus1.ru/news/2019/06/04/slothbot'
#
# response = requests.get(url)
#
# # Убедимся, что мы успешно получили ответ
# print(response.status_code)
# # => 200
#
# # Выведем полученные данные
# print(response.text)
# ```

# %%
url = 'https://nplus1.ru/news/2019/06/04/slothbot'   

response = requests.get(url)  

# Убедимся, что мы успешно получили ответ     
print(response.status_code)
# Out:
# 200

# %%
# Выведем полученные данные    
print(response.text)
# Out:
# <!doctype html>
# <html class="no-js bg-fixed _no-bg" style="background-image:url(https://nplus1.ru/images/2019/06/04/b32b62189fb87cce895e229e1d6d27b4.jpeg)" lang="">
# <head>
#
#     <meta charset="utf-8">
#     <meta http-equiv="x-ua-compatible" content="ie=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#         <meta name="apple-mobile-web-app-capable" content="yes">
#     <meta name="apple-mobile-web-app-status-bar-style" content="black">
#
#     <link rel="canonical" href="https://nplus1.ru/news/2019/06/04/slothbot" />
#
#         <title>Робота-ленивца научили лазать по паутине из тросов</title>
#
#     	    <meta itemprop="datePublished" content="2019-06-04"/>
#
# 	    <meta name="mediator_author" content="Григорий Копиев"/>
#
#         <!-- amp page -->
#     <link rel="amphtml" href="https://nplus1.ru/news/2019/06/04/slothbot/amp">
#
#
#         <!-- for Google -->
#         <meta name="description" content="Он сам добывает энергию с помощью солнечных панелей" />
#
#         <meta name="author" content="Григорий Копиев" />
#         <meta name="copyright" content="" />
#
#         <!-- for Facebook -->
#         <meta property="og:title" content="Робота-ленивца научили лазать по паутине из тросов" />
#                 <meta property="og:image" content="https://nplus1.ru/images/2019/06/04/000d995dad5ab0988b764af18abf6da5.jpeg" />
#         <meta property="og:url" content="https://nplus1.ru/news/2019/06/04/slothbot" />
#         <meta property="og:description" content="Он сам добывает энергию с помощью солнечных панелей" />
#         <!-- for Twitter -->
#         <meta name="twitter:card" content="summary_large_image">
#         <meta name="twitter:site" content="@nplusodin" />
#         <meta name="twitter:title" content="Робота-ленивца научили лазать по паутине из тросов" />
#         <meta name="twitter:description" content="Он сам добывает энергию с помощью солнечных панелей" />
#         <meta name="twitter:image" content="https://nplus1.ru/images/2019/06/04/000d995dad5ab0988b764af18abf6da5.jpeg" />
#
#         <meta name="yandex-verification" content="8c90b02c84ac3b72" />
#
#
#         <link rel='alternate' type='application/rss+xml' title='RSS' href='https://nplus1.ru/rss'>
#
#     <link rel="stylesheet" href="/css/font-awesome.min.css">
#     <link rel="stylesheet" href="/css/main.min.css?v=1602906933">
#     <link rel="stylesheet" href="/css/desktop.min.css?v=1452887696">
#     <link rel="stylesheet" href="/css/tablet.min.css?v=1499281342">
#     <link rel="stylesheet" href="/css/mobile.min.css?v=1603187018">
#
#     <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
#
#     <script src="//cdnjs.cloudflare.com/ajax/libs/modernizr/2.8.3/modernizr.min.js"></script>
#
#             <script type="text/javascript" src="/js/lib/adfox.asyn.code.ver3.js"> </script>
# 		<script type="text/javascript" src="/js/lib/adfox.asyn.code.scroll.js"> </script>
# 	    <script src="https://yastatic.net/pcode/adfox/loader.js" crossorigin="anonymous"></script>
#         <script async id="__lxGc__rtr" type="text/javascript" src="//s.clickiocdn.com/t/195458/360.js"></script>
#         <script async type="text/javascript" src="//s.luxupcdnc.com/t/common_402.js"></script>
#
# 		<!--  ad -->
# 		<script type="text/javascript">
# 		    var __colAdLoaded = false;
# 		    var __topAdLoaded = false;
#
# 		    var __id = "";
#
# 		    function detectAd(id){
# 		        var _ad = document.getElementById("AdFox_banner_"+id);
# 		    	    console.debug(_ad);
#
# 		        __id = id;
# 		        if(_ad != null && _ad.innerHTML == ""){
# 		            $(".col-ad").remove();
# 		        }
# 		        __colAdLoaded = true;
# 		    }
# 		    function detectAdTop(id){
# 		        __topAdLoaded = true;
# 		    }
# 		</script>
# 		<!-- /ad -->
#
#
#
#
#
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"NewsArticle","mainEntityOfPage":{"@type":"WebPage","@id":"https://nplus1.ru/news/2019/06/04/slothbot"},"headline":"Робота-ленивца научили лазать по паутине из тросов","description":"Он сам добывает энергию с помощью солнечных панелей","image":"https://nplus1.ru/images/2019/06/04/000d995dad5ab0988b764af18abf6da5.jpeg","author":{"@type":"Person","name":"Григорий Копиев"},"publisher":{"@type":"Organization","name":"N+1","logo":{"@type":"ImageObject","url":"https://nplus1.ru/i/logo-alt.png"}},"datePublished":"2019-06-04"}</script>
# </head>
# <body style="background-image:url(https://nplus1.ru/images/2019/06/04/b32b62189fb87cce895e229e1d6d27b4.jpeg)" class="_inner  ">
#
# <link property='' rel='stylesheet' href='//s.luxupcdnc.com/cp/all/cookies_policy.css' />
# <script type='text/javascript'>_cookies_policy = {dark:0,bottom:1,text:'Этот сайт использует cookies для улучшения качества работы',link:'Подробнее',href:'https://nplus1.ru/cookies-policy',button:'Закрыть'};</script>
# <script async type='text/javascript' src='//s.luxupcdnc.com/cp/all/cookies_policy.js'></script>
#
#
#
#
#
#
# <div class="thx-rospechat">Функционирует при финансовой поддержке Федерального агентства по печати и массовым коммуникациям (Роспечать)</div>
#
#     <div id="viewport">
# 	<div id="shadow"></div>
#         <div class="ad ad-top">
#
#
#
#
#
#                         	    <!-- bh1 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: Верхняя перетяжка 100%-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_15000335664353901"></div>
# <script>
#     window.Ya.adfoxCode.create({
#         ownerId: 248569,
#         containerId: 'adfox_15000335664353901',
#         params: {
#             pp: 'g',
#             ps: 'cggm',
#             p2: 'fqtd',
#             puid1: ''
#         }
#     });
# </script>
#
#         </div>
#         <header id="header-mobile">
#
#             <div class="container">
#                 <a href="#" class="action-menu pull-left"><i class="icon icon-navicon"></i></a>
#                 <a href="/" class="link-logo"><img src="/i/logo-mobile.png"/></a>
#                 <a href="#" class="action-search pull-right"><i class="icon icon-search"></i></a>
#                 <form action="/search" method="get" class="form-search">
#                     <div class="control">
#                         <input type="text" name="q" placeholder="Найти" value=""/>
#                     </div>
#                     <a href="#" class="action-search-close">×</a>
#                 </form>
#             </div>
#             <nav class="nav-rubrics">
#     <ul>
#                 <li>
#             <a href="/rubric/astronomy" class="">Астрономия</a>
#         </li>
#                 <li>
#             <a href="/rubric/physics" class="">Физика</a>
#         </li>
#                 <li>
#             <a href="/rubric/biology" class="">Биология</a>
#         </li>
#                 <li>
#             <a href="/rubric/robots-drones" class="">Роботы и дроны</a>
#         </li>
#
#                                     <li>
#                     <a href="/theme/explainatorium" class="">Давайте разберемся</a>
#                 </li>
#                             <li>
#                     <a href="/theme/bookshelf" class="">Книжная полка</a>
#                 </li>
#                             <li>
#                     <a href="/theme/nobelprize" class="">Нобелевская премия</a>
#                 </li>
#                             <li>
#                     <a href="/theme/Courses" class="">Курсы</a>
#                 </li>
#                             <li>
#                     <a href="/theme/coronavirus-history" class="">Коронавирусные хроники</a>
#                 </li>
#
#             </ul>
# </nav>
#
#         </header>
#
#
#         <div id="layout" class="js-mediator-container">
#             <!-- header -->
#                         <header id="header" class="_middle">
#     <div class="row">
#
#         <div class="col col-logo">
#             <a href="/" class="link-logo"></a>
#         </div>
#         <div class="col col-nav-main">
#             <form action="/search" method="get" class="form-search">
#                 <div class="control">
#                     <input type="text" name="q" placeholder="Найти" value=""/>
#                 </div>
#                 <a href="#" class="action-search-close">×</a>
#             </form>
#
#             <nav class="nav-rubrics">
#     <ul>
#                 <li>
#             <a href="/rubric/astronomy" class="">Астрономия</a>
#         </li>
#                 <li>
#             <a href="/rubric/physics" class="">Физика</a>
#         </li>
#                 <li>
#             <a href="/rubric/biology" class="">Биология</a>
#         </li>
#                 <li>
#             <a href="/rubric/robots-drones" class="">Роботы и дроны</a>
#         </li>
#
#
#                 <li>
#             <a href="#" class="action-search"><i class="icon icon-search"></i></a>
#         </li>
#             </ul>
# </nav>            <nav class="nav-themes">
#     <ul>
#                 <li data-name="explainatorium">
#             <a href="/theme/explainatorium" class="">Давайте разберемся</a>
#         </li>
#                 <li data-name="bookshelf">
#             <a href="/theme/bookshelf" class="">Книжная полка</a>
#         </li>
#                 <li data-name="nobelprize">
#             <a href="/theme/nobelprize" class="">Нобелевская премия</a>
#         </li>
#                 <li data-name="Courses">
#             <a href="/theme/Courses" class="">Курсы</a>
#         </li>
#                 <li data-name="coronavirus-history">
#             <a href="/theme/coronavirus-history" class="">Коронавирусные хроники</a>
#         </li>
#             </ul>
# </nav>
#         </div>
#     </div>
#         <div class="container line-up">
#         <div class="line line-second">
#                                             <a href="https://nplus1.ru/blog/2020/10/20/carbon-and-the-evolution-of-almost-everything" class="action-line-toggle">
#                     <div class="heading"><span></span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/10/20/carbon-and-the-evolution-of-almost-everything" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Роберт Хейзен &laquo;Симфония № 6. Углерод и эволюция почти всего&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/10/19/this-is-your-brain-on-birth-control" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Сара Хилл &laquo;Вы и ваши гормоны. Наука о женском здоровье и гормональной контрацепции&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/10/15/falling-felines-and-fundamental-physics" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Грегори Гбур &laquo;Загадка падающей кошки и фундаментальная физика&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/10/13/the-diet-myth" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Тим Спектор &laquo;Мифы о диетах. Наука о том, что мы едим&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/10/12/darwins-dangerous-idea" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Дэниел Деннет &laquo;Опасная идея Дарвина: эволюция и смысл жизни&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/10/09/marriage-and-extramarital-life" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Олег Ивик &laquo;О брачной и внебрачной жизни&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/10/08/the-science-of-staying-well" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Дженна Маччиоки &laquo;Иммунитет. Наука о том, как быть здоровым&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/10/07/fight-for-freedom-in-the-don-region" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Амиран Урушадзе &laquo;Вольная вода. Истории борьбы за свободу на Дону&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/10/01/october-2020-observations" class="container-link">
#                     <div class="heading"><span>Астрокалендарь</span></div>
#                     <div class="link"><span>Что наблюдать в октябре: противостояние Марса и метеорные потоки</span></div>
#                 </a>
#                                                 		           	<a href="https://nplus1.ru/blog/2020/10/22/homo-mutabilis" class="container-link active">
#         	        	<div class="heading"><span>Книжная полка</span></div>
#             	    	<div class="link"><span>Настя Травкина &laquo;Homo Mutabilis&raquo;</span></div>
# 		            </a>
# 	                                </div>
#
#     </div>
#     </header>                        <!-- /header -->
#             <!--  hero -->
#                             <!-- /hero -->
#             <!-- main section -->
#             <section id="main">
#
#
#     <div class="container _middle">
#         <div class="row" data-adaptive="1" data-tablet-class="row-wrap" data-mobile-class="row-wrap">
#             <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#
#                 <article class="content" id="article" data-id="20774" data-visit="1" data-type="0">
#                                         <div class="meta">
#     <div class="tables">
#         <p class="table">
#                         <a data-rubric="robots-drones" href="/rubric/robots-drones">Роботы и дроны</a>
#                                             </p>
#         <p class="table">
#             <a href="/news/2019/06/04">
#                 <time itemprop="datePublished" content="2019-06-04" data-unix="1559662033">
#                     <span>18:27</span>
#                     <span>04 Июнь 2019</span>
#                 </time>
#             </a>
#         </p>
#         <p class="table">
#             <a href="/difficult/2.2">
#                 <span>Сложность</span>
#                 <span class="difficult-value">2.2</span>
#             </a>
#         </p>
#     </div>
# </div>
# <script type="text/javascript">
#     var _dlData = {custom_rubric: []};
#         _dlData.custom_author = 'Григорий Копиев';
#         _dlData.custom_difficult = '2.2';
#         _dlData.custom_rubric.push('Роботы и дроны');
#
#     window.dataLayer = window.dataLayer || [];
#     window.dataLayer.push(_dlData);
# </script>
#                                         <div class="share-mobile">
#                         <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#                     </div>
#
#                     <header class="hero hero-lite">
#                         <div>
#                             <h1>Робота-ленивца научили лазать по паутине из тросов</h1>
#                         </div>
#                     </header>
#                                         <div class="body js-mediator-article">
#                                                                                                                             <div class="article-image">
#                             <figure>
#                                 <img src="https://nplus1.ru/images/2019/06/04/b32b62189fb87cce895e229e1d6d27b4.jpeg"/>
#                                                                 <figcaption>
#                                     <p class="title"></p>
#                                     <p class="credits">Allison Carter, Georgia Tech</p>
#                                 </figcaption>
#                                                             </figure>
#                         </div>
#
#                                                     <!-- -->
#                                                         <!-- -->
#
#                                                                                             <p>Американские инженеры разработали робота-ленивца, способного лазать по&nbsp;тросам и&nbsp;перемещаться с&nbsp;одного троса на&nbsp;другой. Благодаря относительно малому потреблению энергии и&nbsp;использованию солнечных панелей подобного робота можно практически неограниченное время использовать для наблюдений на деревьях в лесу, рассказывают авторы <a href="https://ieeexplore.ieee.org/document/8642808" target="_blank" rel="nofollow">статьи</a>, представленной на&nbsp;конференции ICRA 2019.</p>
# <p>Создание роботов, способных лазать по&nbsp;тросам&nbsp;— важная технологическая задача, наработки из&nbsp;которой потенциально применимы во&nbsp;многих областях. К&nbsp;примеру, в&nbsp;2016 году в&nbsp;России <a href="https://nplus1.ru/news/2016/09/28/robot" target="_blank">создали</a> робота для проверки высоковольтных линий электропередачи. Дрон спускает такого робота на&nbsp;грозозащитный трос, после чего тот самостоятельно перемещается вдоль основных проводов и&nbsp;осматривает&nbsp;их. Кроме того, потенциально таких роботов можно применять для исследований в&nbsp;густых лесах, в&nbsp;которых ветки соседних деревьев соприкасаются.</p>
# <p>Инженеры из&nbsp;Технологического института Джорджии под руководством Магнуса Эгерштедта (Magnus Egerstedt) вдохновились ленивцами и&nbsp;решили создать энергоэффективного робота, на&nbsp;основе которого можно было&nbsp;бы создать робота, способного лазать по&nbsp;веткам. Робот состоит из&nbsp;двух частей и передвигается благодаря колесу в&nbsp;каждой части, соприкасающемуся с&nbsp;тросом.<br></p>
# <p><iframe frameborder="0" src="//www.youtube.com/embed/Sx-WL6BIK3s" width="620" height="349" allowfullscreen="true" class="embed-responsive-item"></iframe><br></p>
# <p>Кроме того, в&nbsp;каждой части робота есть две полноценные шестерни и&nbsp;две связанные с&nbsp;ними, но&nbsp;с&nbsp;вырезанным сектором. Внутрь такой шестерни продет
# трос. При движении вперед шестерня расположена таким образом, чтобы трос не&nbsp;мог выйти за&nbsp;ее&nbsp;пределы. Если&nbsp;же роботу необходимо перейти на&nbsp;смежный трос, шестерня поворачивается так, чтобы вырез располагался горизонтально. Перемещаться между смежными тросами роботу помогает еще один двигатель в&nbsp;петле, соединяющей две части.<br></p>
# <p><div class="incut incut-gallery " data-id="20774">
#     <div class="swiper-container">
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <figure>
#                     <div class="img">
#                         <img src="https://nplus1.ru/images/2019/06/04/e5fbb06230c74d541b319677af5ccd79.jpg"/>
#                     </div>
#                     <figcaption>
#                     <p class="title">Компоненты одной из двух частей робота</p>
#
#                                             	    <p class="credits">Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019</p>
#
#                     </figcaption>
#                 </figure>
#                 <div class="share-incut">
# <div class="title"><i class="fa fa-share"></i><span>Поделиться</span></div>
# <nav class="nav-share">
#     <ul class="social-likes" data-title="Робота-ленивца научили лазать по паутине из тросов">
# 		<li class="facebook" data-service='facebook' data-image='https://nplus1.ru/images/2019/06/04/e5fbb06230c74d541b319677af5ccd79.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="twitter" data-service='twitter' data-image='https://nplus1.ru/images/2019/06/04/e5fbb06230c74d541b319677af5ccd79.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="vkontakte" data-service='vkontakte' data-image='https://nplus1.ru/images/2019/06/04/e5fbb06230c74d541b319677af5ccd79.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="odnoklassniki" data-service='odnoklassniki' data-image='https://nplus1.ru/images/2019/06/04/e5fbb06230c74d541b319677af5ccd79.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
#             </ul>
# </nav>
# </div>
#             </div>
#                     </div>
#         <div class="pagination">
#             <div class="swiper-button-prev"></div>
#             <div class="swiper-counter"></div>
#             <div class="swiper-button-next"></div>
#         </div>
#     </div>
# </div>Для питания робот использует аккумулятор емкостью 1000 миллиампер-часов, а&nbsp;также две солнечные панели, располагающиеся по&nbsp;бокам одной из&nbsp;частей. Разработчики отмечают, что благодаря применению колес для движения по&nbsp;тросам, а&nbsp;также пассивному механизму удержания, робот имеет большую энергоэффективность, чем другие роботы, предназначенные для перемещения по&nbsp;тросам.<br></p>
# <p><div class="incut incut-gallery " data-id="20774">
#     <div class="swiper-container">
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <figure>
#                     <div class="img">
#                         <img src="https://nplus1.ru/images/2019/06/04/54a85341c9518ba141a7bbbf5e4566e4.jpg"/>
#                     </div>
#                     <figcaption>
#                     <p class="title">Механизм блокировки троса</p>
#
#                                             	    <p class="credits">Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019</p>
#
#                     </figcaption>
#                 </figure>
#                 <div class="share-incut">
# <div class="title"><i class="fa fa-share"></i><span>Поделиться</span></div>
# <nav class="nav-share">
#     <ul class="social-likes" data-title="Робота-ленивца научили лазать по паутине из тросов">
# 		<li class="facebook" data-service='facebook' data-image='https://nplus1.ru/images/2019/06/04/54a85341c9518ba141a7bbbf5e4566e4.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="twitter" data-service='twitter' data-image='https://nplus1.ru/images/2019/06/04/54a85341c9518ba141a7bbbf5e4566e4.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="vkontakte" data-service='vkontakte' data-image='https://nplus1.ru/images/2019/06/04/54a85341c9518ba141a7bbbf5e4566e4.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="odnoklassniki" data-service='odnoklassniki' data-image='https://nplus1.ru/images/2019/06/04/54a85341c9518ba141a7bbbf5e4566e4.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
#             </ul>
# </nav>
# </div>
#             </div>
#                     </div>
#         <div class="pagination">
#             <div class="swiper-button-prev"></div>
#             <div class="swiper-counter"></div>
#             <div class="swiper-button-next"></div>
#         </div>
#     </div>
# </div>Кроме создания аппаратной платформы инженеры также написали для робота программное обеспечение, позволяющее ему самому прокладывать путь по&nbsp;тросам. Пользователь может указать точку, за&nbsp;которой необходимо наблюдать, после чего робот, имея карту системы тросов, самостоятельно рассчитает путь до&nbsp;наиболее близкой к заданной точке наблюдательной позиции.</p>
# <p>Ранее инженеры из&nbsp;Технологического института Джорджии <a href="https://nplus1.ru/news/2017/04/13/tarzan" target="_blank" title="Link: https://nplus1.ru/news/2017/04/13/tarzan">создали</a> другого робота-ленивца для работы на&nbsp;тросе. Он&nbsp;так&nbsp;же состоит из&nbsp;двух частей, но&nbsp;имеет совершенно другую конструкцию и&nbsp;принцип работы. Он&nbsp;способен зацепляться концом одной части за&nbsp;трос и&nbsp;раскачивать другую, чтобы затем зацепиться&nbsp;ей. После этого он&nbsp;может отпустить первую часть и&nbsp;снова начать раскачиваться для того, чтобы двигаться дальше.<br></p>
# <p><i>Григорий Копиев</i></p>
#
#
#
#
#                                             </div>
#                 </article>
#
#
# 				    <!-- ba1 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: мобильный-->
# <div id="adfox_155980540701252236"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 248569,
#         containerId: 'adfox_155980540701252236',
#         params: {
#             pp: 'ssg',
#             ps: 'cggm',
#             p2: 'fpum',
#             puid1: ''
#         }
#     }, ['phone'], {
#         tabletWidth: 1024,
#         phoneWidth: 767,
#         isAutoReloads: false
#     });
# </script>
#
# 		                <meter class="bottom"></meter>
#             </div>
#             <div class="col col-1 sidebar" data-adaptive="1" data-tablet-class="col-full">
#                                 <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#
#                 <meter class="top"></meter>
#                                         <div id="latest" data-adaptive="1" data-tablet-class="fixed" data-mobile-class="fixed">
#
#                 <div class="ad">
#                                                                 	                            	<!-- ba2 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_153934342663011746"></div>
# <script>
#     (function(w, n) {
#     w[n] = w[n] || [];
#     w[n].push({
#         ownerId: 248569,
#         containerId: 'adfox_153934342663011746',
#         params: {
#             pp: 'g',
#             ps: 'cggm',
#             p2: 'fpum',
#             puid1: ''
#         }
#     });})(window, 'adfoxAsyncParams');
# </script>
#
#
#                     	                                                                </div>
#
#
#                         <h2 class="_tablet-hidden _mobile-hidden">Свежее</h2>
#                         <div class="latest-container">
#                         <article class="item item-news item-news-latest-first  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/10/23/prosub" data-id="26927" >
#         <div class="caption">
#                                                                     	                		<img src="https://nplus1.ru/images/2020/10/23/3a7f75f5eccde679bca6a7dd7803889d.jpg"/>
#
#
#
#                                     <div>
#                         <div class="date">
#                             <span class="name" title="2020-10-23">12:32</span>
#                         </div>
#                         <h3>Бразильцы приступили к сборке первого реактора для атомной подлодки</h3>
#                     </div>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                                                <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/10/23/armor-beetle" data-id="26914" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2020-10-23">11:49</span>
#                 </div>
#
#                                     <h3>Гибкий панцирь позволил броненосному жуку пережить наезд автомобиля</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/10/23/madagascar-mascarenes-megafauna-extinction" data-id="26913" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2020-10-23">10:30</span>
#                 </div>
#
#                                     <h3>Людей вновь обвинили в вымирании мегафауны Мадагаскара и Маскаренских островов</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/10/23/sub-ambient-radiative-cooling" data-id="26909" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2020-10-23">10:15</span>
#                 </div>
#
#                                     <h3>Слой белой краски с карбонатом кальция охладил поверхность на 10 градусов</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/10/23/voltaero" data-id="26924" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2020-10-23">09:17</span>
#                 </div>
#
#                                     <h3>Французы испытали демонстратор гибридного самолета Cassio</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                </div>
#
#
#
#
#
#
#                     </div>
#
#
#
#                 </div>
#
#                 <footer class="article-footer">
#                     <div class="row">
#                         <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#                             <p>Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.</p>
#                         </div>
#                         <div class="col col-1 _mobile-hidden _tablet-hidden">
#                             <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#                         </div>
#                     </div>
#                 </footer>
#
#                 <div class="ad ad-footer">
#                     			                                                                                        </div>
#
#
#             </div>
#
#
#             <div class="row row-wrap">
#                             </div>
#             <div class="row row-wrap">
#                 <div class="col col-full" data-adaptive="1"  data-mobile-class="col-1">
#
#                                     </div>
#             </div>
#             <div class="row" data-adaptive="1" data-tablet-class="row-wrap" data-mobile-class="row-wrap" data-type="also">
#                 <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#
#                                         <section id="also">
#                                                 <h4 class="pull-left">Читайте также</h4>
#                         <div class="col col-also">
#                                                             <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/10/22/hsv1-neuropat" data-id="26921" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2020/10/22/af88e6094ceac95fe84e5b2d90e968fe.gif)" class="ill"></div>
#
#
#
#                                     <h3>Вирус простого герпеса нарушил процесс развития нервной ткани</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                            <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/10/22/doctor-patient-fmri" data-id="26906" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2020/10/22/c25d55a097e8e2efb08ed21351d2a793.jpg)" class="ill"></div>
#
#
#
#                                     <h3>Синхронизированная активность мозга и мимикрия помогли врачам облегчить боль пациентов</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                            <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/10/21/deers-eating-plastic" data-id="26899" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2020/10/21/f71642d55bd7caea97c342536c1c175c.jpg)" class="ill"></div>
#
#
#
#                                     <h3>Японцы покормят оленей съедобными пакетами</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                    </div>
#
#                     </section>
#                                     </div>
#                 <div class="col col-1" data-adaptive="1" data-tablet-class="col-full _indent-bottom">
#                     <section id="next">
#                         <div class="col col-1" data-adaptive="1" data-tablet-class="col-2">
#                                                         <article class="item item-article item-article-secondary  _exist-image" data-relevance="" data-image="https://nplus1.ru/images/2020/10/20/be0c76153bf018c39b027ad0d66018d8.gif" style=background-image:url(https://nplus1.ru/images/2020/10/20/65a9dfa47a566597cc4a1f132fef824b.gif)>
#
#     <a href="/material/2020/10/20/on-time-travel" data-id="26865" >
#         <div class="caption">
#                                                                                     <h3>Убить дедушку и выжить</h3>
#                     <p class="subtitle">Что позволяет физика путешественникам во времени</p>
#                                     </div>
#     </a>
#         <nav class="nav-rubricator">
#         <ul>
#
#                         <li>
#                 <a class="link-rubric" href="/rubric/physics">Физика</a>
#             </li>
#                                 </ul>
#     </nav>
#     </article>                                                    </div>
#                     </section>
#                 </div>
#             </div>
#         </div>
#     <!--/div-->
#
#     <div id="_mistake">
#         <input type="hidden" name="_token" value="90Dmb8uhwXXDOI3KlVvLjIRumByq3BtfCDi6HGoR">
#         <input type="hidden" name="id_news" value="20774">
#         <input type="hidden" name="id_author" value="102">
#         <input type="hidden" name="id_editor" value="0">
#     </div>
#     <div id="_post">
#         <input type="hidden" name="_token" value="90Dmb8uhwXXDOI3KlVvLjIRumByq3BtfCDi6HGoR">
#         <input type="hidden" name="id_news" value="20774">
#     </div>
#             </section>
#             <!-- / main section -->
#
#
#             <div id="wrapper-footer">
#             <section id="difficult" class="_middle">
#     <!-- Slider main container -->
#     <div class="swiper-container">
#         <!-- Additional required wrapper -->
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">8.1</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/material/2020/10/20/on-time-travel">Убить дедушку и выжить</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.2</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/10/12/top-quark-nucleus-nucleus">На Большом адронном коллайдере увидели следы топ-кварка в столкновениях ядер</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.8</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/material/2020/10/12/sm2">Системных дел мастер</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.7</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/10/19/zeptoseconds">Физики поставили рекорд по измерению самого короткого промежутка времени</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.2</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/10/16/inverted-magnetic-umbrella">Физики обнаружили в нитрате кобальта вывернутые закрученные магнитные зонтики</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.9</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/10/12/memristorspectra">Оптическая спектроскопия помогла детально изучить мемристор</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.8</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/10/15/musical-training-and-the-brain">Занятия музыкой улучшили память и внимательность детей</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.8</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/10/15/dark-matter-pendulums">Темную материю предложили детектировать с помощью маятников</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.5</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/10/19/unorthodox-voices">Ртом и не только</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.4</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/10/14/UVultrafastphotography">Сверхбыстрая камера засняла ультрафиолетовое излучение</a></h3>
#             </div>
#
#         </div>
#         <!-- If we need pagination -->
#         <div class="swiper-pagination"></div>
#         <div class="swiper-button-prev"></div>
#         <div class="swiper-button-next"></div>
#     </div>
#     <h6>Самое сложное</h6>
# </section>
#
#
#             <div class="ad ad-col border">
#                     	    </div>
#
#             <!-- footer -->
#             <footer id="footer">
#     <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-tablet-class="row-wrap" data-mobile-class="row-wrap">
#         <div class="col col-logo">
#             <a href="/" class="link-logo"><img src="/i/logo-alt.png"/></a>
#         </div>
#         <div class="col col-footer-desc">
#             <nav class="nav-pages">
#                 <ul>
#                     <li>
#                         <a href="/about">О нас</a>
#                     </li>
#                     <li>
#                         <a href="/adv">Рекламодателям</a>
#                     </li>
#                     <li>
#                         <a href="/rules">Наши материалы</a>
#                     </li>
#                     <li>
#                         <a href="/vacancy">Вакансии</a>
#                     </li>
#                     <li>
#                         <a href="/difficult">Сложность</a>
#                     </li>
#                 </ul>
#             </nav>
#             <div class="desc">
#                 <p>&copy; 2020 N+1 Интернет-издание &nbsp; Свидетельство о регистрации СМИ Эл № ФС77-67614</p>
#
#                     <p>Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на N+1.
#                         Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются
#                         только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения
#                         и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru</p>
#                     <p>Материалы, опубликованные в разделе «Блоги», отражают позиции их авторов, которые могут не совпадать с мнением редакции.</p>
#                     <p>Сайт может содержать контент, не предназначенный для лиц младше 18 лет.</p>
#                     <p>
#                         <a href="https://nplus1.ru/personal-data-policy" class="pd">Политика обработки персональных данных пользователей сайта</a>
#                     </p>
#                     <p>
#                         <script async type="text/javascript" src="//s.luxupcdnc.com/t/consent_195458.js"></script>
#                         <a href="#" onclick="if(window.__lxG__consent__ !== undefined) {window.__lxG__consent__.showConsent()} else {alert('This function works only for users from the European Economic Area (EEA).')}; return false">Change privacy settings</a>
#                     </p>
#
#                 <p>
#                                     </p>
#             </div>
#         </div>
#         <div class="col col-1 pull-right">
#             <nav class="nav-social">
#                 <ul>
#                     <li>
#                         <a href="https://t.me/nplusone"><i class="fa fa-telegram"></i></a>
#                     </li>
#                     <li>
#                         <a href="http://vk.com/nplusone"><i class="fa fa-vk"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://www.facebook.com/nplusone"><i class="fa fa-facebook"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://twitter.com/nplusodin"><i class="fa fa-twitter"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://ok.ru/nplus1"><i class="fa fa-odnoklassniki"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://soundcloud.com/nplus_1"><i class="fa fa-soundcloud"></i></a>
#                     </li>
#                     <li>
#                         <a href="/rss"><i class="fa fa-rss"></i></a>
#                     </li>
#                 </ul>
#             </nav>
#             <div class="partners">
#
#
#                 <!-- Rating@Mail.ru counter -->
# <script type="text/javascript">
# var _tmr = window._tmr || (window._tmr = []);
# _tmr.push({id: "3084572", type: "pageView", start: (new Date()).getTime()});
# (function (d, w, id) {
#   if (d.getElementById(id)) return;
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window, "topmailru-code");
# </script><noscript><div>
# <img src="https://top-fwz1.mail.ru/counter?id=3084572;js=na" style="border:0;position:absolute;left:-9999px;" alt="Top.Mail.Ru" />
# </div></noscript>
# <!-- //Rating@Mail.ru counter -->
#
#
#
#             </div>
#         </div>
#     </div>
# </footer>            <!-- / footer -->
#             </div>
#         </div>
#
#     </div>
#
#
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MNJC58');</script>
# <!-- End Google Tag Manager -->
#
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MNJC58"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#
#
#     <noscript><div><img src="//mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;" alt="" /></div></noscript>
#
#
# 	</div>
#
#
#
# <script src="/js/lib/js.cookie.js"></script>
# <script src="/js/lib/jquery.swap.js"></script>
# <script src="/js/lib/swiper.jquery.min.js"></script>
# <script src="/js/lib/svg.js"></script>
# <script src="/js/lib/jquery.mobile-events.min.js"></script>
# <script src="/js/lib/social-likes.min.js"></script>
# <script src="/js/lib/jquery.sticky.js"></script>
#
#
# <script src="/js/lib/ts.js"></script>
# <script src="/js/lib/js.cookie.js"></script>
# <script type="text/javascript" async src="https://relap.io/api/v6/head.js?token=sTVMyshMYp9i7-rv"></script>
#
#
# <script async src="https://cdn.onthe.io/io.js/QCyUUwp6IVuR"></script>
# <script>
# window._io_config = window._io_config || {};
# window._io_config["0.2.0"] = window._io_config["0.2.0"] || [];
# window._io_config["0.2.0"].push({
#     page_url: document.location.toString(),
#     page_url_canonical: document.querySelector('link[rel="canonical"]').href,
#     page_title: document.querySelector('title').innerHTML,
#     page_type: "article",
#     page_language: "ru",
#     article_authors: [document.querySelector('meta[name="author"]').content || ''],
#     article_publication_date: (new Date(document.querySelector('meta[itemprop="datePublished"]').content).toUTCString()).toString()
# });
# </script>
#
# <!--   project scripts -->
# <script src="/js/main.min.js?v=1592278962"></script>
# <!-- / project scripts -->
#
#
#
#
# <!-- Quantcast Tag -->
# <script type="text/javascript">
# var _qevents = _qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
#
# _qevents.push({
# qacct:"p-s3ftDEFzEW5x7"
# });
# </script>
#
# <noscript>
# <div style="display:none;">
# <img src="//pixel.quantserve.com/pixel/p-s3ftDEFzEW5x7.gif" border="0" height="1" width="1" alt="Quantcast"/>
# </div>
# </noscript>
# <!-- End Quantcast tag -->
# </body>
# </html>

# %% [markdown]
# Мы получили большую строку с текстом в формате `html`, который используется для визуальной разметки. Это позволяет делать информацию более наглядной для людей, но в отличие от `json`, мы не можем просто преобразовать его напрямую в словарь. Далее мы посмотрим, как извлекать информацию из подобных страниц

# %% [markdown]
# ## 9.6 Основы HTML
# Прежде чем перейти к поиску информации в `html`, давайте вспомним, что он из себя представляет.
#
# `HTML` – формат разметки страниц, созданный специально для интернета. Он позволяет разбивать страницу на блоки: мы размечаем, что окажется в боковой колонке, а что – посередине  и т.д.  Также он используется для описания стилей отображения: например, что будет отображаться как заголовок с большим текстом, а что – как обычный текст.
#
# `HTML` является близким родственником `XML`. Разметка делается с помощью так называемых тэгов, которые помещаются в угловые скобки, и сами, в свою очередь, являются как бы скобками для текста внутри.
#
# ```html
# <h2> Это заголовок </h2>
# <div> А это обычный текст </div>
# ```
# У корректной `html` страницы есть заголовок `(head)` и тело страницы `(body)`. В заголовке заключается техническая информация, подключаются скрипты и стили. В теле находится текст и данные, которые непосредственно  отображаются на странице в браузере.
#
# Разметка небольшой страницы выглядит примерно так:
# ```html
# <!DOCTYPE html>
# <html lang="ru">
#     <header>
#         <title>Название страницы</title>
#         <meta charset="UTF-8">
#     </header>
#
#     <body>
#         <h1>Заголовок страницы</h1>
#         <p>Какой-то текст</p>
#     </body>
# </html>
# ```
# Вы можете сохранить это в текстовый файл с расширением .html и открыть в браузере.
#
# Тут стоит заметить, что тэги образуют иерархическую структуру, т.е. одни тэги расположены внутри других. В примере выше тэг `<p>` находится внутри тэга `<body>`
#
# Кроме того, у тэгов могут быть атрибуты, они пишутся внутри открывающегося тэга. Самые популярные атрибуты – это `class` и `id`.
# ```html
# <h1 id="big-title">Заголовок страницы</h1>
# <p class="red-back">Какой-то текст</p>
# ```
# Полное описание возможностей `html` находиться вне рамок этого курса. Вы можете подробнее почитать о нём [здесь](http://htmlbook.ru/html).
#
# К счастью, нам и не нужно как-то подробно знать `html`, чтобы забирать информацию. Достаточно понимать, что:
#
# - есть тэги с разными именами;
# - у тэгов бывают атрибуты, вроде class и id;
# - тэги образуют иерархическую структуру, то есть одни тэги вложены в другие.

# %% [markdown]
# ###= 9.7 Библиотека BeautifulSoup
# Для поиска данных на странице воспользуемся библиотекой `BeautifulSoup`. Она позволяет по названию тэгов и их атрибутов получать содержащийся в них текст.
#
# Она не является частью стандартной библиотеки, поэтому для начала её нужно установить с помощью пакетного менеджера, например, введя в консоли:
#
# ```
# pip install beautifulsoup4
# ```
# Теперь мы можем получать данные из страницы. Давайте получим `title` (это строка, отображающая в браузерах на закладках)
#
# ```python
# # Импортируем наши библиотеки
# from bs4 import BeautifulSoup
# import requests
#
# # Получаем данные, как и ранее
# url = 'https://nplus1.ru/news/2019/06/04/slothbot'
# response = requests.get(url)
#
# # Теперь создадим объект BeautifulSoup, указывая html парсер
# page = BeautifulSoup(response.text, 'html.parser')
#
# # Всё готово, чтобы получать данные из страницы
# # Для начала получим title, отображающийся на закладках браузера
# print(page.title)
# # => <title>Робота-ленивца научили лазать по паутине из тросов</title>
#
# # Мы получили тэг. Чтобы достать из него текст, вызовем атрибут text
# page.title.text
# # => 'Робота-ленивца научили лазать по паутине из тросов'
# ```

# %%
# Импортируем наши библиотеки    
from bs4 import BeautifulSoup    
import requests    

# Получаем данные, как и ранее    
url = 'https://nplus1.ru/news/2019/06/04/slothbot'   
response = requests.get(url)    

# Теперь создадим объект BeautifulSoup, указывая html парсер    
page = BeautifulSoup(response.text, 'html.parser')    

# Всё готово, чтобы получать данные из страницы    
# Для начала получим title, отображающийся на закладках браузера    
print(page.title)  
# => <title>Робота-ленивца научили лазать по паутине из тросов</title>  

# Мы получили тэг. Чтобы достать из него текст, вызовем атрибут text    
page.title.text
# Out:
# <title>Робота-ленивца научили лазать по паутине из тросов</title>
# 'Робота-ленивца научили лазать по паутине из тросов'

# %% [markdown]
# ## 9.8 Данные со страницы
# ### Читаем заголовок
#
# Мы получили данные из `title`, но как нам забрать текст с самой страницы? Мы можем сделать это, запросив содержимое определённых тэгов.
#
# Пусть мы знаем, что заголовок статьи находится в тэге `h1`. Тогда мы можем получить его текст с помощью метода `find`
# ```python
# print(page.find('h1').text)
# # => Робота-ленивца научили лазать по паутине из тросов
# ```
# Как узнать, какой именно тэг нужен? Проще всего это сделать с помощью "инструментов разработчика", которые есть во всех современных браузерах. Открыть их можно двумя способами:
# 1. Можно нажать на желаемый элемент правой кнопкой мыши и выбрать `"Inspect"` из выпадающего списка. Откроется панель, где мы можем понять, что это за элемент
#
# 2.  Нажать горячие клавиши (`ctrl-shift-i` в chrome или `ctrl-shift-c` в firefox), которые откроют эту же панель и дальше найти элемент.
#
# Воспользовавшись этим подходом, давайте получим время написания статьи. Смотрим, в каком она тэге
#
# Видим, что это тэг time. Получим данные.
#
# ```python
# print(page.find('time').text)
# ```

# %%
print(page.find('time').text)
# Out:
# 18:27
# 04 Июнь 2019

# %% [markdown]
# ### Задание 2 - Автоматический сбор заголовков
# Напишите функцию `wiki_header`, которая по адресу страницы возвращает заголовок для статей на википедии
# ```python
# wiki_header('https://en.wikipedia.org/wiki/Operating_system')
# ```
# ```
# # => 'Operating system'
# ```

# %%
def wiki_header(page_url):
    response = requests.get(page_url)
    page = BeautifulSoup(response.text, 'html.parser')
    return page.find('h1').text

# %%
wiki_header('https://en.wikipedia.org/wiki/Operating_system')
# Out:
# 'Operating system'

# %% [markdown]
# ## 9.9 Больше данных
# Мы рассмотрели базовый поиск конкретного элемента. Могут встречаться другие вариации:
#
# - когда нам нужно получить много похожих элементов;
# - когда тэг атрибута неуникальный, тогда нам нужно использовать атрибуты (id, class), либо использовать вложенность.
#
# Посмотрим на практике, что делать в случае, когда тэг элемента неуникальный. Пусть мы хотим получить сам текст статьи. Мы видим, что он находится в тэге `div`.
# Тэги `div` очень распространённые, их много на странице. Если мы просто используем `find`, то получим первый попавшийся, но это не то, что нам надо.

# %%
print(page.find('div').text)
# Out:
# Функционирует при финансовой поддержке Федерального агентства по печати и массовым коммуникациям (Роспечать)

# %% [markdown]
# Тут мы можем заметить, что у искомого текста есть свой класс `GeneralMaterial-body`. Воспользуемся этим:  в метод `find` можно передать аргумент `class_`

# %%
print(page.find('div', class_='body js-mediator-article').text)
# Out:
# Allison Carter, Georgia Tech
#
#
#
#
#
# Американские инженеры разработали робота-ленивца, способного лазать по тросам и перемещаться с одного троса на другой. Благодаря относительно малому потреблению энергии и использованию солнечных панелей подобного робота можно практически неограниченное время использовать для наблюдений на деревьях в лесу, рассказывают авторы статьи, представленной на конференции ICRA 2019.
# Создание роботов, способных лазать по тросам — важная технологическая задача, наработки из которой потенциально применимы во многих областях. К примеру, в 2016 году в России создали робота для проверки высоковольтных линий электропередачи. Дрон спускает такого робота на грозозащитный трос, после чего тот самостоятельно перемещается вдоль основных проводов и осматривает их. Кроме того, потенциально таких роботов можно применять для исследований в густых лесах, в которых ветки соседних деревьев соприкасаются.
# Инженеры из Технологического института Джорджии под руководством Магнуса Эгерштедта (Magnus Egerstedt) вдохновились ленивцами и решили создать энергоэффективного робота, на основе которого можно было бы создать робота, способного лазать по веткам. Робот состоит из двух частей и передвигается благодаря колесу в каждой части, соприкасающемуся с тросом.
#
# Кроме того, в каждой части робота есть две полноценные шестерни и две связанные с ними, но с вырезанным сектором. Внутрь такой шестерни продет
# трос. При движении вперед шестерня расположена таким образом, чтобы трос не мог выйти за ее пределы. Если же роботу необходимо перейти на смежный трос, шестерня поворачивается так, чтобы вырез располагался горизонтально. Перемещаться между смежными тросами роботу помогает еще один двигатель в петле, соединяющей две части.
#
#
#
#
#
#
#
#
#
# Компоненты одной из двух частей робота
# Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019
#
#
#
# Поделиться
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Для питания робот использует аккумулятор емкостью 1000 миллиампер-часов, а также две солнечные панели, располагающиеся по бокам одной из частей. Разработчики отмечают, что благодаря применению колес для движения по тросам, а также пассивному механизму удержания, робот имеет большую энергоэффективность, чем другие роботы, предназначенные для перемещения по тросам.
#
#
#
#
#
#
#
#
#
# Механизм блокировки троса
# Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019
#
#
#
# Поделиться
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Кроме создания аппаратной платформы инженеры также написали для робота программное обеспечение, позволяющее ему самому прокладывать путь по тросам. Пользователь может указать точку, за которой необходимо наблюдать, после чего робот, имея карту системы тросов, самостоятельно рассчитает путь до наиболее близкой к заданной точке наблюдательной позиции.
# Ранее инженеры из Технологического института Джорджии создали другого робота-ленивца для работы на тросе. Он так же состоит из двух частей, но имеет совершенно другую конструкцию и принцип работы. Он способен зацепляться концом одной части за трос и раскачивать другую, чтобы затем зацепиться ей. После этого он может отпустить первую часть и снова начать раскачиваться для того, чтобы двигаться дальше.
# Григорий Копиев

# %% [markdown]
# Отлично, сработало. Аналогично работает и с id, мы могли бы написать что-то вроде `page.find('div', id='maincontent')`

# %% [markdown]
# ### Задание 1. Поиск элемента
# У вас есть переменная `page`, в которой хранится содержимое html-страницы. На странице есть элемент в тэге `span`, у которого атрибут `id` равен `'target'`. Напишите строчку кода, которая присвоит текст этого элемента переменной `value`.
#
# Запишите ваш код в одну строку без пробелов. Используйте апострофы для передачи параметров, содержащих значение тэга и его `id`.

# %%
value=page.find('span',id='target').text

# %% [markdown]
# ## 9.10 Сбор нескольких элементов
# ### Собираем все ссылки на странице
# Рассмотрим случай, когда нам нужно сразу много элементов. Пусть мы хотим получить название всех ссылок на странице в википедии про языки программирования.
#
# Для ссылок существует тэг `<a></a>`.  Давайте попробуем использовать `find`
# ```python
# url = 'https://en.wikipedia.org/wiki/List_of_programming_languages'
#
# response = requests.get(url)
# page = BeautifulSoup(response.text, 'html.parser')
# page.find('a')
# ```

# %%
url = 'https://en.wikipedia.org/wiki/List_of_programming_languages'  

response = requests.get(url)  
page = BeautifulSoup(response.text, 'html.parser')  
page.find('a')
# Out:
# <a id="top"></a>

# %% [markdown]
# Что-то пошло не так, и мы получили только одну ссылку, хотя на странице их явно больше. Это происходит, потому что метод `find` возвращает только первый подходящий элемент. Если нам надо их больше, нужно воспользоваться методом `find_all`

# %%
links = page.find_all('a')  
# Посмотрим, сколько всего мы получили  
print(len(links))
# Out:
# 926

# %%
# Посмотрим на некоторые из ссылок  
print([link.text for link in links[500:510]])
# Out:
# ['Oxygene', 'Oz', 'edit', 'P', 'P4', 'P′′', 'ParaSail (programming language)', 'PARI/GP', 'Pascal', 'Pascal Script']

# %% [markdown]
# **Ещё одна полезная вещь:**  последовательный поиск, т.е. мы можем найти сначала один элемент, а потом сделать внутри него второй поиск. Давайте выведем названия всех ссылок для языков программирования, которые начинаются на литеру "A".

# %%
# Получаем все элементы с тегом 'div' и классом 'div-col'  
all_blocks = page.find_all('div', class_='div-col')  
  
# Выбираем первый по счету блок  
first_block = all_blocks[0]  
# Берём оттуда ссылки (ограничимся первыми десятью)
links = first_block.find_all('a')
print([link.text for link in links[:10]])
# Out:
# ['A.NET', 'A-0 System', 'A+', 'ABAP', 'ABC', 'ABC ALGOL', 'ACC', 'Accent', 'Ace DASL (Distributed Application Specification Language)', 'Action!']

# %% [markdown]
# В заключение заметим, что `BeautifulSoup` – достаточно мощная библиотека. Мы рассмотрели базовые возможности, но полный список гораздо шире. С ним можно ознакомиться в [официальной документации](https://www.crummy.com/software/BeautifulSoup/bs4/doc/).

# %% [markdown]
# ### Задание 1 - Актёры
# Напишите функцию `get_actors`, которая по ссылке на страницу фильма на кинопоиске возвращает список актёров из колонки справа
#
# ### NB: Если делать запросы слишком часто, Кинопоиск начинает выдавать капчу, поэтому старайтесь при отладке не делать больше одного запроса в секунду.
#
# ## <span style="color:red">ВНИМАНИЕ! В настоящий момент времени на сайте Кинопоиска изменилась стукртура контента и применяется более интеллектуальная капча. Задание находится на стадии доработки и не обязательно для выполнения.</span>

# %% [markdown]
# ## 9.11 HTML-таблицы
# ### Постановка задачи
# При работе с web-страницами было бы здорово получать содержимое  таблиц в виде датафрейма. Рассмотрим страницу Центрального банка РФ cbr.ru. Наша задача будет состоять в том, чтобы получить одну из таблиц виджетов в виде датафрейма. Например, таблицу цен на драгоценные металлы.

# %% [markdown]
# Метод `read_html` из pandas умеет автоматически находить на HTML-странице таблицы и возвращать их списком из датафреймов:

# %%
import pandas as pd  
url = 'https://www.cbr.ru/key-indicators/'  
# Таблица с драгметаллами оказалась второй по счёту  
pd.read_html(url)[1]
# Out:
#                  0           1
# 0  рублей за грамм  24.10.2020
# 1       Золото  Au    4 697,13
# 2      Серебро  Ag        6087
# 3      Платина  Pt    2 192,95
# 4     Палладий  Pd    5 853,59

# %% [markdown]
# Если этого не происходит, но вы уверены в том, что порядок таблиц на странице неизменен, то можно вручную найти нужную таблицу на странице. Этому случаю посвящены следующие шаги.

# %% [markdown]
# ### Задание 1 - Курсы валют через read_html
# Попробуйте запустить pandas для заданного выше url. Какая строчка вернёт таблицу с курсами валют?

# %%
pd.read_html(url)[0]
# Out:
#                  0           1           2
# 0           валюта  23.10.2020  24.10.2020
# 1  Доллар США  USD      770809      764667
# 2        Евро  EUR      913563      904142

# %% [markdown]
# ## Поиск таблицы с помощью BeautifulSoup
# Более надёжным решением является сначала получить только текст таблицы и передавать в `pandas` только её. Так же, как и в предыдущем разделе, используем `requests` и `BeautifulSoup`, чтобы получить данные со страницы.
#
# А теперь — внимание! В случае работы с сайтом Центробанка нам нужно будет учесть ещё один нюанс. С недавнего времени администраторы стали блокировать обращения к сайту, поступающие не от «живых» пользователей, а от компьютерных программ (в том числе от той, которую мы собираемся написать прямо сейчас). Есть ли шанс в таких условиях всё-таки получить данные, не открывая страницу в браузере?
#
# Безусловно, это возможно. Безвыходных положений вообще не бывает, особенно в программировании! Один из способов справиться с ситуацией — «притвориться» браузером :).
#
# Каждый запрос, отправляемый с помощью команды get, имеет заголовок. Если заголовок не задан явно, то он создаётся автоматически, и туда добавляется информация в том числе о том, кто является субъектом (или источником) запроса — человек или программа. Чтобы «притвориться» браузером, нам просто нужно вручную дописать нужные сведения в этот заголовок. Подробнее о таком подходе можно почитать в [этой статье](https://habr.com/ru/company/ods/blog/346632/).
#
# Итоговый вариант кода после добавления заголовка должен выглядеть так:
# ```python
# from bs4 import BeautifulSoup
# import pandas as pd
# import requests
#
# url = 'https://www.cbr.ru/key-indicators/'
# soup = BeautifulSoup(requests.get(url, headers={'User-Agent': 'Mozilla/5.0'}).text, 'html.parser')
# ```

# %%
from bs4 import BeautifulSoup  
import pandas as pd  
import requests  

url = 'https://www.cbr.ru/key-indicators/'
soup = BeautifulSoup(requests.get(url, headers={'User-Agent': 'Mozilla/5.0'}).text, 'html.parser')

# %% [markdown]
# Далее нажимаем 'Исследовать элемент' в меню браузера на виджете с драгоценными металлами:
#
# ![](https://lms.skillfactory.ru/assets/courseware/v1/a2e35fa184cf7d6bbf2aac9a70f5fa71/asset-v1:Skillfactory+DST-12+11MAR2020+type@asset+block/metals_2.png)
#
# Видим, что виджету соответствует следующая разметка:
#
# ![](https://lms.skillfactory.ru/assets/courseware/v1/1ed8cdbe78a85aa99b12651bf3044a89/asset-v1:Skillfactory+DST-12+11MAR2020+type@asset+block/metals_3.png)
#
# Нам необходимо добраться до кода таблицы, который начинается с тэга <table>. Таблиц на странице много, поэтому указываем путь к таблице виджета драгоценных металлов применяя знания полученные ранее:

# %%
all_blocks = soup.find_all('div', class_='key-indicator_content offset-md-2')
# Данные таблицы с драгметаллами находятся во втором блоке
data = all_blocks[1].find('table')

# %%
pd.read_html(str(data))[0]
# Out:
#                  0           1
# 0  рублей за грамм  24.10.2020
# 1        Золото Au    4 697,13
# 2       Серебро Ag        6087
# 3       Платина Pt    2 192,95
# 4      Палладий Pd    5 853,59

# %% [markdown]
# ### Задание 2 - Рейтинг банков
# Напишите программу, которая забирает данные из таблицы рейтинга банков с https://www.banki.ru/banks/ratings/, делает из него датафрейм и сохраняет его в переменую df.

# %%
url = 'https://www.banki.ru/banks/ratings/'

# %%
# response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'}).text
# page = BeautifulSoup(response, 'html.parser')

# page

# %%
df = pd.read_html('https://www.banki.ru/banks/ratings/')[0]

# %% [markdown]
# ## 9.12 Введение в API
# В предыдущих разделах мы собирали полезную информацию с различных сайтов с выделением правильных тэгов – это довольно трудоёмкая задача. Кроме того, подобные программы могут ломаться в случаях, когда меняется дизайн сайта, его разметка, или владельцы сайтов защищаются от ботов капчей.
#
# К счастью, многие крупные сайты предоставляют доступ к так называемым API (application programming interface, программный интерфейс приложения). Это специальные разделы сайта, где информацию можно получать без разметки, формат запросов – ответов зафиксирован, и они созданы специально, чтобы облегчить жизнь сторонним разработчикам.
#
# Мы уже видели, как https://www.cbr-xml-daily.ru возвращает данные о валютах в json-формате, и это может считаться API. В этом разделе мы на примере ВКонтакте посмотрим особенности API, характерные для более крупных сайтов.

# %% [markdown]
# ### Сервисный токен
# Для того чтобы начать работать с API ВКонтакте, необходимо получить сервисный токен (ключ) авторизации.
#
# Авторизация применяется практически во всех API, чтобы отдавать данные только их владельцу или контролировать количество запросов в единицу времени. Сервисный токен для нашей задачи создается вместе с новым приложением. Приложение мы делать, конечно, не будем. Оно нужно только для получения токена, чтобы сделать необходимые выгрузки.
#
# Зайдите на страницу https://vk.com/editapp?act=create, чтобы создать приложение (вы должны быть авторизованы ВКонтакте). Дайте приложению любое название и оставьте значение платформы "Standalone-приложение":
#
# После подтверждения создания приложения в приложении ВК или по СМС зайдите в настройки:

# %% [markdown]
# ### Задание 1 - Создание токена
# Создайте свой токен для доступа к API вконтакте. Для ответа в этом задании введите первые его 10 символов.

# %%
token = '63fbecbb63fbecbb63fbecbb33638f7e1d663fb63fbecbb3c6f9fb9664c2428f44fef5e'
token[:10]
# Out:
# '63fbecbb63'

# %% [markdown]
# ## 9.13 Запрос к API
# Для примера работы с API мы будем получать данные для статистических отчетов произвольной группы, например:
#
# - соотношение мужчин и женщин в группе;
# - статистика географии пользователей;
# - другие данные для аналитики групп конкурентов.
# Сначала рассмотрим работу API на простом примере, на основе которого работают многие системы.
#
# Перейдите по следующей ссылке в браузере, подставив вместо слова "TOKEN" сервисный токен из прошлого шага:
#
# https://api.vk.com/method/users.get?user_id=1&v=5.95&access_token=TOKEN
#
# Результат:
#
# [запрос 1](https://api.vk.com/method/users.get?user_id=1&v=5.95&access_token=63fbecbb63fbecbb63fbecbb33638f7e1d663fb63fbecbb3c6f9fb9664c2428f44fef5e)
#
# {"response":[{"id":1,"first_name":"Павел","last_name":"Дуров","is_closed":false,"can_access_closed":true}]}

# %% [markdown]
# Сейчас мы сделали GET-запрос к API ВКонтакте, который состоит из следующих частей:
#
# - `https://api.vk.com/method` — домен и URL запроса API: обычно не меняется;
# - `users.get` — название метода, который отдает определенный отчет; нашем случае это метод для получения информации о пользователе;
# - `user_id` и `v` — параметры запроса: идентификатор пользователя, о котором хотим получить информацию, и номер версии API;
# - `token`, который выдается только пользователям, имеющим право просматривать определенные данные, например, показания счетчиков Яндекс, метрики вашего проекта: на все остальные запросы без корректного токена система отвечает отказом.
#
# Если мы посмотрим [документацию метода users.get](https://vk.com/dev/users.get), то увидим, что в ней описано множество других параметров, которые можно получить о пользователе: дата рождения, пол, родной город и другие.
#
# Словом, всё то, что мы видим на странице пользователя в интерфейсе или приложении ВКонтакте (конечно, если пользователь их указал). Добавим к запросу дату рождения и пол (согласно документации, эти параметры надо перечислять в поле fields):
#
# `https://api.vk.com/method/users.get?user_id=1&v=5.95&fields=sex,bdate&access_token=TOKEN`
# Результат:
#
# [запрос 2](https://api.vk.com/method/users.get?user_id=1&v=5.95&fields=sex,bdate&access_token=63fbecbb63fbecbb63fbecbb33638f7e1d663fb63fbecbb3c6f9fb9664c2428f44fef5e)
#
# {"response":[{"id":1,"first_name":"Павел","last_name":"Дуров","is_closed":false,"can_access_closed":true,"sex":2,"bdate":"10.10.1984"}]}

# %% [markdown]
# ### Задание 1 - ID страны
# Какое значение ID у страны, указанной в профиле Павла Дурова (ID отдается вместе с названием страны)? Укажите ответ в виде целого числа.

# %% [markdown]
# [запрос 3](https://api.vk.com/method/users.get?user_id=1&v=5.95&fields=country&access_token=63fbecbb63fbecbb63fbecbb33638f7e1d663fb63fbecbb3c6f9fb9664c2428f44fef5e)

# %% [markdown]
# {"response":[{"id":1,"first_name":"Павел","last_name":"Дуров","is_closed":false,"can_access_closed":true,"country":{"id":1,"title":"Россия"}}]}

# %% [markdown]
# ## 9.14 Запрос к API из кода
# ### Запрос из кода
# Мы делали запрос в браузере, теперь давайте сделаем запрос из кода. Будем пользоваться всё той же библиотекой requests.
# ```python
# import requests
#
# url = 'https://api.vk.com/method/users.get'
# params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'}
#
# # Мы можем выставить параметры запроса через аргумент params
# response = requests.get(url, params=params)
# response.text
# ```

# %%
import requests  

url = 'https://api.vk.com/method/users.get'   
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'}  

# Мы можем выставить параметры запроса через аргумент params  
response = requests.get(url, params=params)  
response.text
# Out:
# '{"response":[{"id":1,"first_name":"Павел","last_name":"Дуров","is_closed":false,"can_access_closed":true,"sex":2,"bdate":"10.10.1984"}]}'

# %% [markdown]
# Мы получили строку в формате JSON. Как мы помним по первому разделу, её можно преобразовать в словарь методом json и после этого обращаться к различным полям. Кроме того, такие большие вложенные словари нагляднее выводить с помощью функции pprint (~pretty print, красивый вывод), которым мы и воспользуемся
#
# ```python
# from pprint import pprint
#
# pprint(response.json())
# ```

# %%
from pprint import pprint  

pprint(response.json())
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}

# %%
user = response.json()['response'][0]  
  
# Выведем дату рождения  
print(user['bdate'])
# Out:
# 10.10.1984

# %%
# Выведем имя  
print(user['first_name'])
# Out:
# Павел

# %% [markdown]
# Данный метод позволяет запрашивать сразу много пользователей (до 1000).  Для этого нужно использовать параметр user_ids и передавать id через запятую в строковом формате, например: '1,2,3'.
# ```python
# ids = ",".join(map(str, range(1, 4)))
# print(ids)
# ```

# %%
ids = ",".join(map(str, range(1, 4)))  
print(ids)
# Out:
# 1,2,3

# %%
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bday', 'access_token': token, 'lang': 'ru'} 
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bday', 'access_token': token} 

# params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex', 'access_token': token, 'lang': 'ru'} 
pprint(requests.get(url, params=params).json())
# Out:
# {'response': [{'can_access_closed': True,
#                'first_name': 'Pavel',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Durov'},
#               {'can_access_closed': False,
#                'first_name': 'Alexandra',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Vladimirova'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'last_name': ''}]}

# %% [markdown]
# ### Задание 1 - Гендерный баланс
# Используя API, определите долю женщин(sex=1) среди пользователей с id от 1 до 500. Иногда вам будут попадать пользователи, у которых пол не указан (sex=0), их не нужно учитывать в общем числе.
#
# В ответе укажите число, округлив до двух знаков после запятой, например, 0.55
#
# Пример: если у нас будет 300 пользователей sex=1, 100 пользователей с sex=2 и 100 пользователей с sex=0, то в ответе должно быть 0.75

# %%
ids = ",".join(map(str, range(1, 501)))
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex', 'access_token': token} 

response = requests.get(url, params=params).json()

# %%
users_data = response['response']

from collections import Counter
counter = Counter()

for user in users_data:
    counter[(user['sex'])] += 1

round(counter[1]/(counter[1]+counter[2]),2)
# Out:
# 0.48

# %% [markdown]
# ## 9.15 Ограничения API
# В прошлом блоке мы собрали информацию о небольшом наборе пользователей. Теперь перейдем к более реальной задаче — сбору данных о пользователях группы ВКонтакте.
#
# Стоит отметить, что есть много сервисов, которые выгружают похожую статистику из соцсетей. Однако им свойственны недостатки универсальных решений:
#
# - не могут учитывать всех особенностей вашего проекта;
# - считают фиксированный набор метрик, дополнительную обработку данных приходится делать вам;
# - не всегда бесплатны и вряд ли позволят работать с большими объемами данных.
#
# ### В этом разделе мы научимся считать произвольные метрики групп, собирая данные из API.
#
# В текущем шаге мы научимся работать с двумя ограничениями, которые свойственны практически всем системам:
#
# - ограничение на количество вызовов в единицу времени;
# - ограничение на количество выгружаемых строк за один запрос.
#
# Ограничение на количество запросов в секунду сделано для того, чтобы избежать чрезмерной нагрузки на серверы системы. В ряде случаев небольшое количество отчетов можно выгрузить, уложившись в этот лимит (например, как мы получили информацию о 500 пользователях в прошлом упражнении). Однако второе ограничение не удастся «обойти» в случае выгрузки больших отчетов. Например, чтобы получить список всех пользователей очень популярной группы, серверу, возможно, придется отправить вам разом лист из миллионов записей.

# %% [markdown]
# ***Давайте рассмотрим, как работать с этими ограничениями на примере выгрузки списка пользователей группы*** https://vk.com/mountelbrus.
#
# Посмотрим в документации, [какие методы нам доступны для групп](https://vk.com/dev/groups). Для получения списка пользователей группы видим метод [groups.getMembers](https://vk.com/dev/groups.getMembers).
#
# Согласно документации, обязательным параметром является ID или короткое имя группы. В нашем случае это `mountelbrus: https://vk.com/mountelbrus`. Тестируем, как работает метод в самом простом случае:
# ```python
# import requests
# url = 'https://api.vk.com/method/groups.getMembers'
# params = {
#     'group_id': 'mountelbrus',
#     'v': 5.95,
#     'access_token': token
# }
# response = requests.get(url, params = params)
# data = response.json()
# print(data)
# ```

# %%
import requests  
url = 'https://api.vk.com/method/groups.getMembers'  
params = {  
    'group_id': 'mountelbrus',  
    'v': 5.95,  
    'access_token': token  
}  
response = requests.get(url, params = params)  
data = response.json()  
print(data)
# Out:
# {'response': {'count': 67379, 'items': [161, 273, 710, 1157, 1364, 1858, 2306, 3516, 3857, 4316, 4592, 4646, 4765, 4901, 4969, 4992, 5118, 5121, 5438, 5678, 5818, 5970, 6172, 6528, 6706, 7224, 7303, 7638, 8212, 8376, 8422, 9006, 9322, 9640, 9808, 10133, 10361, 10531, 11246, 12541, 12757, 12915, 12976, 12990, 13188, 13549, 13695, 14033, 14644, 14742, 15018, 15140, 15421, 16328, 16608, 17522, 17656, 17670, 18226, 18248, 18423, 18958, 19072, 19232, 19405, 19483, 19568, 19691, 19720, 20417, 20598, 20866, 20934, 20980, 21179, 21386, 21760, 22123, 22135, 22726, 23011, 23217, 23256, 23360, 23932, 24275, 24985, 25018, 25096, 25166, 25310, 25394, 25814, 25930, 25975, 26034, 26205, 26543, 26828, 27023, 27513, 27536, 27659, 27670, 28879, 29132, 29166, 29450, 29677, 29805, 30168, 30518, 30760, 31012, 31926, 32019, 32528, 33259, 33299, 33795, 34777, 34811, 35170, 35244, 35300, 35868, 36811, 37082, 37311, 37455, 37496, 38193, 38258, 39030, 39286, 39538, 39702, 39737, 39738, 40089, 40933, 40984, 41195, 41300, 41682, 42180, 42282, 42385, 42464, 42931, 43095, 43100, 43471, 43653, 43881, 44094, 44261, 44585, 45239, 45710, 46284, 46964, 47480, 47999, 48081, 48399, 49048, 49681, 50120, 50623, 52170, 53359, 53485, 53518, 54620, 54849, 54872, 54948, 55616, 55761, 55979, 56741, 56799, 56812, 58017, 58185, 58660, 60233, 60452, 60621, 61574, 61601, 63200, 63389, 63534, 63587, 63914, 63957, 64478, 64794, 65307, 65906, 65938, 66068, 66097, 66111, 66381, 66423, 67109, 67141, 67522, 67594, 68263, 68323, 68374, 68869, 69409, 69605, 69705, 69787, 69872, 70088, 70339, 70553, 70817, 71231, 71621, 71627, 71722, 71873, 72208, 72654, 72657, 73229, 73349, 73838, 73932, 74005, 74356, 74613, 74769, 75018, 75555, 75685, 76497, 76528, 76964, 77261, 77294, 77367, 77491, 77777, 77818, 77892, 78330, 78372, 78557, 79098, 79286, 79448, 79464, 80367, 80923, 81121, 81520, 81771, 82055, 82121, 82172, 82849, 82880, 82899, 83458, 83593, 84193, 84300, 85170, 85293, 85414, 87135, 87232, 87840, 88595, 88853, 90107, 90121, 90706, 91235, 91498, 91529, 92506, 92796, 92920, 93545, 93746, 94155, 94164, 94242, 95105, 95579, 95780, 96377, 96731, 96880, 97051, 97328, 97503, 98806, 100103, 100589, 100870, 100947, 100971, 101064, 101467, 102026, 102061, 102502, 102607, 102609, 102811, 103073, 103953, 104138, 104291, 104316, 104472, 104792, 105003, 105213, 105482, 105598, 106335, 106587, 106784, 106922, 107009, 107137, 107242, 107267, 107309, 107341, 107489, 107740, 108255, 108420, 108956, 109311, 109978, 110368, 110541, 111023, 111526, 111542, 111819, 113305, 113693, 113791, 113994, 114129, 115692, 116136, 117385, 117734, 118077, 118207, 118389, 118413, 118964, 119007, 119335, 119423, 119500, 120298, 121050, 121896, 122483, 122556, 123072, 123610, 124511, 124925, 125168, 126210, 126641, 126810, 126940, 128657, 129061, 129474, 130669, 130752, 131998, 132144, 132587, 133374, 133504, 133938, 134384, 134984, 135072, 135401, 136030, 136463, 136668, 137288, 138142, 139418, 139624, 140089, 140499, 140924, 141263, 141935, 142026, 142260, 143686, 144303, 145244, 145248, 145502, 145621, 146767, 146819, 146841, 146918, 146995, 147718, 148603, 148618, 148833, 149125, 149240, 150772, 151687, 151846, 151987, 152355, 154408, 154520, 154938, 156085, 156799, 156907, 156935, 157117, 157412, 157661, 157696, 158061, 158313, 159338, 160805, 160925, 161214, 161275, 161299, 161312, 161337, 161501, 161677, 161921, 161977, 163441, 164579, 165031, 165317, 165583, 165724, 166333, 166510, 166881, 167031, 167085, 168179, 169621, 170994, 171186, 171952, 172259, 173211, 173245, 173657, 173952, 174349, 174494, 174600, 174683, 174927, 174995, 175219, 175419, 175469, 175960, 177505, 178092, 178298, 179874, 180665, 180687, 180697, 181090, 181559, 181607, 181664, 181952, 182322, 182436, 182624, 183093, 183740, 184032, 184418, 185366, 185441, 185890, 186233, 186584, 186610, 186705, 186761, 186826, 186839, 186914, 187146, 187306, 188950, 189119, 189390, 189913, 190835, 191113, 191499, 191688, 192041, 192252, 192414, 192484, 19 ...

# %%
len(data['response']['items'])
# Out:
# 1000

# %% [markdown]
# ### Получаем всех пользователей
# Мы видим, что всего пользователей в группе больше 65 000, а получили мы только первую тысячу пользователей группы. Судя по описанию параметра count в документации, это максимум, который может отдать API за один раз.
#
# Для получения следующей тысячи пользователей воспользуемся параметрами `count` и `offset`: будем в цикле выгружать по 1000 пользователей (`count` будет всегда равен 1000), а в каждом следующем шаге цикла увеличим смещение `offset` на величину count.
#
# Сначала напишем цикл выгрузки первых 20 пользователей со значением `count` = 5. Т.е. цикл будет выгружать за 1 запрос по 5 пользователей, пока не выгрузит первые 20. Это позволит нам проверить корректность работы цикла перед тем, как делать большие и долгие выгрузки.
#
# Давайте выведем на экран первые 20 пользователей из нашей первой попытки с 1000 пользователей, чтобы было с чем сверить результат выгрузки из 20 пользователей:
# ```python
# users_for_checking = data['response']['items'][:20]
# print(users_for_checking)
# ```

# %%
users_for_checking = data['response']['items'][:20]  
print(users_for_checking)
# Out:
# [161, 273, 710, 1157, 1364, 1858, 2306, 3516, 3857, 4316, 4592, 4646, 4765, 4901, 4969, 4992, 5118, 5121, 5438, 5678]

# %% [markdown]
# Теперь используем `count` и `offset`, чтобы получить те же id по 5 за раз
# ```python
# count = 5
# offset = 0
# user_ids = []
# max_count = 20
# while offset < max_count:
#     print('Выгружаю {} пользователей с offset = {}'.format(count, offset))
#     params = {
#         'group_id': 'mountelbrus',
#         'v': 5.95,
#         'count': count,
#         'offset': offset,
#         'access_token': token
#     }
#     # такой же запрос как в прошлый раз
#     r = requests.get(url, params = params)
#     data = r.json()
#     user_ids += data['response']['items']
#
#     # увеличиваем смещение на количество строк выгрузки
#     offset += count
# ```

# %%
count = 5  
offset = 0  
user_ids = []
max_count = 20  
while offset < max_count:  
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))     
    params = {  
        'group_id': 'mountelbrus',  
        'v': 5.95,  
        'count': count,  
        'offset': offset,  
        'access_token': token  
    }     
    # такой же запрос как в прошлый раз  
    r = requests.get(url, params = params)  
    data = r.json()     
    user_ids += data['response']['items']   

    # увеличиваем смещение на количество строк выгрузки  
    offset += count
# Out:
# Выгружаю 5 пользователей с offset = 0
# Выгружаю 5 пользователей с offset = 5
# Выгружаю 5 пользователей с offset = 10
# Выгружаю 5 пользователей с offset = 15

# %%
print(user_ids)  
user_ids == users_for_checking
# Out:
# [161, 273, 710, 1157, 1364, 1858, 2306, 3516, 3857, 4316, 4592, 4646, 4765, 4901, 4969, 4992, 5118, 5121, 5438, 5678]
# True

# %% [markdown]
# Видим, что подход корректно работает. Теперь мы можем получить всех пользователей, выставив `count = 1000` и `max_count = data['response']['count']`.

# %% [markdown]
# ### Задание 1 - Юбилейный пользователь
# Используя API, определите id пятидесятитысячного пользователя в группе `mountelbrus` . Т.е. если бы у нас не было ограничения на размер запроса, то мы бы запросили `data['response']['items'][49999]` .

# %%
    params = {  
        'group_id': 'mountelbrus',  
        'v': 5.95,  
        'count': 1,  
        'offset': 49999,  
        'access_token': token}

# %%
response = requests.get(url, params = params)  
anniv_user_data = response.json()

# %%
anniv_user_id = anniv_user_data['response']['items'][0]
anniv_user_id
# Out:
# 218755957

# %% [markdown]
# ### 9.16 Ограничение по частоте запросов
# В API частот добавляют ограничение по частоте запросов, чтобы отдельно взятые пользователи слишком сильно не перегружали  сервер. Подобное ограничение есть и у ВКонтакте, в документации которой указано, что можно делать не более 3-х запросов в секунду.
#
# Чтобы не следить за частотой отправки запросов с секундомером в руках, мы можем после каждого запроса делать паузу. В этом случае, даже если код будет выполняться на самом быстром компьютере, мы не нарушим установленное ограничение, т.к. периодичность отправки запросов будет искусственно замедлена. Воспользуемся библиотекой `time` и методом `sleep` (пауза в 0.5 секунды добавлена в конце цикла):
# ```python
# import time
#
# count = 1000
# offset = 0
# user_ids = []
# while offset < 10000:
#     print('Выгружаю {} пользователей с offset = {}'.format(count, offset))
#     params = {
#         'group_id': 'mountelbrus',
#         'v': 5.95,
#         'count': count,
#         'offset': offset,
#         'access_token': token
#     }
#     # такой же запрос, как в прошлый раз
#     r = requests.get(url, params = params)
#     data = r.json()
#     user_ids += data['response']['items']
#
#     # увеличиваем смещение на количество строк выгрузки
#     offset += count
#
#     print('Ожидаю 0.5 секунды...')
#     time.sleep(0.5)
# ```

# %%
import time  

count = 1000  
offset = 0  
user_ids = []  
while offset < 10000:  
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))     
    params = {  
        'group_id': 'mountelbrus',  
        'v': 5.95,  
        'count': count,  
        'offset': offset,  
        'access_token': token  
    }    
    # такой же запрос, как в прошлый раз  
    r = requests.get(url, params = params)  
    data = r.json()     
    user_ids += data['response']['items']    

    # увеличиваем смещение на количество строк выгрузки  
    offset += count  

    print('Ожидаю 0.5 секунды...')  
    time.sleep(0.5)
# Out:
# Выгружаю 1000 пользователей с offset = 0
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 1000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 2000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 3000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 4000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 5000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 6000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 7000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 8000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 9000
# Ожидаю 0.5 секунды...

# %%
len(user_ids)
# Out:
# 10000

# %% [markdown]
# ### 9.17 Лайки, репосты и комментарии
# Лайки, репосты и комментарии
# Ещё одна полезная вещь, которую можно получить,  —  это количество взаимодействий с постами через **API новостной ленты**. На данном этапе будем использовать самый простой вариант: берем последние 10 постов группы. Мы продолжаем работать с группой `https://vk.com/mountelbrus`.
#
# Начнем с  формирования запроса к **API ВКонтакте** методом `wall.get()`:
# ```python
# import requests
# from pprint import pprint
#
# url = 'https://api.vk.com/method/wall.get'
# params = {
#     'domain': 'mountelbrus',
#     'filter': 'owner',
#     'count': 10,
#     'offset': 0,
#     'access_token': token,
#     'v': 5.95
# }
# response = requests.get(url, params = params)
# response.json()
# ```

# %%
import requests  
from pprint import pprint  

url = 'https://api.vk.com/method/wall.get'  
params = {  
    'domain': 'mountelbrus',  
    'filter': 'owner',  
    'count': 10,  
    'offset': 0,  
    'access_token': token,  
    'v': 5.95  
}  
response = requests.get(url, params = params)  
response.json()
# Out:
# {'response': {'count': 718,
#   'items': [{'id': 13830,
#     'from_id': -9690799,
#     'owner_id': -9690799,
#     'date': 1602330529,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'ТУРЫ НА ЭЛЬБРУС, КАЗБЕК, ДЫХТАУ 2021\n(три Российских пятитысячника)\n\n1. Программы 2021:\nЭльбрус с юга (треккинг)\nЭльбрус с юга (комфорт)\nЗимний Эльбрус\nЭльбрус с востока \nЭльбрус с севера (короткий стандартный)\nЭльбрус с севера (треккинг)\nЭльбрус с запада\nЭльбрус с кислородом за 1 день\nКазбек с севера\nКазбек с юга\nДыхтау\n\n2. Гиды - инструкторы альпинизма, чемпионы России по альпинизму, КМС и Мастера Спорта.\n\n3. Офис в Пятигорске и собственный прокат всего снаряжения и одежды.\n\n4. Самый полный набор средств и мер безопасности, включая спутниковую связь и кислородное оборудование для экстренных случаев (для случаев острой горной болезни)\n\n5. Поддержка и помощь на всех этапах: выбор маршрута, физическая подготовка, выбор снаряжения - наши менеджеры всегда на связи с вами.\n\n6. Распродажа при раннем бронировании. Цены на туры в 2021 году стартуют от 10 000 руб при покупке до пятницы включительно.\n\n7. Расписание туров 2021 и бронирование здесь: https://strahu-net.com/',
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://strahu-net.com/',
#        'title': 'РАСПРОДАЖА ТУРОВ НА ЭЛЬБРУС, КАЗБЕК, ДЫХТАУ 2021',
#        'caption': 'strahu-net.com',
#        'description': 'Восхождения на Эльбрус с 4х сторон Света, 10 маршрутов от 1 до 14 дней, разной сложности, протяженности и уровня комфорта.',
#        'photo': {'album_id': -27,
#         'date': 1602353841,
#         'id': 457316006,
#         'owner_id': 2000046232,
#         'has_tags': False,
#         'sizes': [{'height': 90,
#           'url': 'https://sun9-58.userapi.com/RYLpy1XqFZL0tVXill9e3FCJO_DZWHtVdgz55Q/HRwPkIl3jds.jpg',
#           'type': 'a',
#           'width': 200},
#          {'height': 179,
#           'url': 'https://sun9-20.userapi.com/paj5NQm_4wnNncJnGD5hnBBzmE3A9SQqqx_F6Q/uVWKCpFrBug.jpg',
#           'type': 'b',
#           'width': 400},
#          {'height': 200,
#           'url': 'https://sun9-35.userapi.com/4Wtio0d9wmNtdwTExeoUi75g6zAltz2omJzuGg/7dfuuuCcXJg.jpg',
#           'type': 'c',
#           'width': 200},
#          {'height': 100,
#           'url': 'https://sun9-68.userapi.com/ytwLxss0lGBlFsH0lX_-BIua77kygOaji5-H7g/JuFP1MHXcD0.jpg',
#           'type': 'd',
#           'width': 100},
#          {'height': 50,
#           'url': 'https://sun9-11.userapi.com/5P7k7zNXDMeRAh1MHsiJhcQfi6a6OgHRETWPig/RV3p7p0YjC8.jpg',
#           'type': 'e',
#           'width': 50},
#          {'height': 480,
#           'url': 'https://sun9-10.userapi.com/_Bnc7KBh6K3-vLKB4z1NpwBc3oXuQVC-WkAx8w/YYYR8Geo3H0.jpg',
#           'type': 'k',
#           'width': 1072},
#          {'height': 240,
#           'url': 'https://sun9-50.userapi.com/dvXIYi8oAghg6hhG1fdInNj0lOw2zazIheNrNw/cgUG3zHwWok.jpg',
#           'type': 'l',
#           'width': 537},
#          {'height': 840,
#           'url': 'https://sun9-67.userapi.com/kZVbFiJ-U_egS6wC55s-tIV37g4kgpR_Y4zr6g/tVIDZ2gTf3k.jpg',
#           'type': 'o',
#           'width': 1876}],
#         'text': '',
#         'user_id': 100}}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 11, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 116, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 7, 'user_reposted': 0},
#     'views': {'count': 59280},
#     'edited': 1602353841},
#    {'id': 13824,
#     'from_id': -9690799,
#     'owner_id': -9690799,
#     'date': 1602159033,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'ЗИМНЕЕ ВОСХОЖДЕНИЕ НА ЭЛЬБРУС. ПРЕИМУЩЕСТВА И НЕДОСТАТКИ.\n\nНачнем с недостатков, они более очевидные и их два. Первый - низкая температура, вам потребуется более теплая чем летом одежда. Второй - существует вероятность того, что склон будет покрыт льдом. И в этом случае восхождение приобретет техническую сложность. Потребуется провешивать веревки. (Это будут делать ваши гиды).\n\nПреимущества зимнего Эльбруса, вероятно, менее очевидны... Первое - именно зимой самый прозрачный воздух и горы с вершины просматриваются на более дальнее расстояние. Второе - зимой на южном склоне почти нет других восходителей. В принципе, другие восходители это не плохо, но все же летом на южном склоне их слишком много. Таким образом, зимой есть возможность совершать восхождение в комфортных условиях (приют с отоплением, канатка) и в то же время один на один с природой.\n\nПрименительно к нашим зимним турам, есть еще два важных преимущества. Первое - зимние группы сопровождают сразу два лучших российских альпиниста - Сергей Тарасов и Алексей Сикилинда. Оба - Чемпиона России по альпинизму. Второе - на одного гида приходится не более 4 участников (летом 6). \n\nЦены на зимние туры при раннем бронировании начинаются от 30 000 руб. Первый зимний тур стартует уже 1 ноября, сейчас в этой группе уже 5 человек. Один из зимних туров - новогодний и там в группе уже 7 человек. К этим и другим турам вы можете присоединиться. Расписание и бронирование - на этой странице: \nhttps://strahu-net.com/raspisanie/?year=2021',
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://strahu-net.com/raspisanie/?year=2021',
#        'title': 'Зимние туры на Эльбрус. Распродажа.',
#        'caption': 'strahu-net.com',
#        'description': 'Восхождения на Эльбрус с 4х сторон Света, 10 маршрутов от 1 до 14 дней, разной сложности, протяженности и уровня комфорта.',
#        'photo': {'album_id': -28,
#         'date': 1602159274,
#         'id': 457314439,
#         'owner_id': 2000045314,
#         'has_tags': False,
#         'sizes': [{'height': 90,
#           'url': 'https://sun9-32.userapi.com/tDUMmW_kcZNKbgn_rYa2ZbOmP31bxcJgyyQ3wA/dD4vDRahlMY.jpg',
#           'type': 'a',
#           'width': 200},
#          {'height': 179,
#           'url': 'https://sun9-67.userapi.com/y4m5nI_4kzQZ7ybr6zLOb7vJ0S5V_c_cA_AcwA/Q5et8xywUoE.jpg',
#           'type': 'b',
#           'width': 400},
#          {'height': 200,
#           'url': 'https://sun9-57.userapi.com/TFUd6LQioxXc0Bk1rqH0HdprohFjCaWhlYJ7qQ/aXnBPeFYiqA.jpg',
#           'type': 'c',
#           'width': 200},
#          {'height': 100,
#           'url': 'https://sun9-61.userapi.com/Glx4E7w3bE5_XM7QPPCEYemkT702K-5cjwUInQ/syxLKoRP-1I.jpg',
#           'type': 'd',
#           'width': 100},
#          {'height': 50,
#           'url': 'https://sun9-60.userapi.com/ZPzCg0c65fKiZy5Afyh6GGJeV9KsvuCoW6g3wg/REnCl-3OPJQ.jpg',
#           'type': 'e',
#           'width': 50},
#          {'height': 480,
#           'url': 'https://sun9-73.userapi.com/R7fDMaxKYanDRKoYckjfICQy2VAY9guW7IWiTQ/AuQT_nYE67U.jpg',
#           'type': 'k',
#           'width': 1072},
#          {'height': 240,
#           'url': 'https://sun9-5.userapi.com/MbBwh9hZqYxTDt-LDA2oQdyR9sylXIOB-mSkhg/GddchXTY0lU.jpg',
#           'type': 'l',
#           'width': 537},
#          {'height': 840,
#           'url': 'https://sun9-6.userapi.com/S5V7D_eagpJdxS8wsPlBGrm3-d8VPrYr9n4F8g/mzVZXEGO-fE.jpg',
#           'type': 'o',
#           'width': 1876}],
#         'text': '',
#         'user_id': 100}}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 1, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 406, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 11, 'user_reposted': 0},
#     'views': {'count': 96060},
#     'edited': 1602159274},
#    {'id': 13802,
#     'from_id': -9690799,
#     'owner_id': -9690799,
#     'date': 1601977706,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Свежие фотографии из нашего похода на Эльбрус по восточному маршруту в сентябре 2020.\n\nВосточный маршрут - самый красивый среди маршрутов, доступных обычному человеку без специальной подготовки. Для участия необходимо иметь среднюю физическую форму. На практике это означает, что вы способны пробежать 10-12 км без остановки. Маршрут абсолютно дикий. Если вы хотите увидеть природу Кавказа без канаток, отелей, ратраков и толп туристов, то выбирайте только этот маршрут.\n\nВ 2021 году планируем 6 походов на Эльбрус с востока. Группы ведут лучшие российские альпинисты - Сергей Тарасов, Валерий Шамало, Алексей Сикилинда, Алексей Гергель.\n\nНа данный момент действует распродажа, и тур можно купить со скидкой более 50%. Цены со скидками начинаются от 21 000 руб. Поспешите, цены обновляются еженедельно по мере заполнения групп.\n\nРасписание туров на Эльбрус с востока и бронирование здесь: \nhttps://strahu-net.com/raspisanie/?year=2021&ROUTE=East\n\nВсе вопросы можно задать нам в чат группы или по телефону 8 800 7777 0 44',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1601977705,
#        'id': 457242744,
#        'owner_id': -9690799,
#        'has_tags': False,
#        'access_key': '40d3eed124a049e1d3',
#        'sizes': [{'height': 97,
#          'url': 'https://sun9-72.userapi.com/ZwOTamRn6qwV1Nc3R2YRyEoNHrwaEn5aEimp_g/TD3Q4PIcMK8.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 98,
#          'url': 'https://sun9-60.userapi.com/gFnicZmBLqJ9_LFqldPL5ynpal6QveZsEIvMHA/Nd4vBx6uGTc.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 150,
#          'url': 'https://sun9-40.userapi.com/b6vF2P4XdhsSfjkOc3bgkSi8kw61r2MqkhIk_Q/o73COsoFV6Q.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 240,
#          'url': 'https://sun9-46.userapi.com/z04KDYAmo9EcxwUU7PE5TGg294_iaznt3qifeQ/2m7iO5h6Fxs.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 383,
#          'url': 'https://sun9-44.userapi.com/LPIjs8vvSdv7iv0PtN5QEMdsVAOl2HBRfEEzXA/f6vyyp43BkY.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 56,
#          'url': 'https://sun9-2.userapi.com/KgFNTdi7f6eFYB1XfstSv1qGNSp0eJeM55VAHA/IbKo66m233o.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 1920,
#          'url': 'https://sun9-48.userapi.com/gTcaWP7ksI_QKmLX7dP2n0N02QvDCPBqf1HMvg/qDPUqIN77aw.jpg',
#          'type': 'w',
#          'width': 2560},
#         {'height': 453,
#          'url': 'https://sun9-63.userapi.com/NayZcj0MTx35gvd4FxtYseuw50LpzGU2rTvVSg/EsIMtjuBxZY.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 605,
#          'url': 'https://sun9-17.userapi.com/Lv51K6G-GdkLN73ZZQgUreZ3OegLhYmKPc8TMA/AgpFKq_e8AI.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 960,
#          'url': 'https://sun9-26.userapi.com/EEygYH7rZIrKSpu24A_metpJCDPZbvwFGf7kDQ/gwTtleniErE.jpg',
#          'type': 'z',
#          'width': 1280}],
#        'text': '',
#        'user_id': 100}},
#      {'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1601977705,
#        'id': 457242745,
#        'owner_id': -9690799,
#        'has_tags': False,
#        'access_key': 'f0a7203379e781e7f7',
#        'sizes': [{'height': 97,
#          'url': 'https://sun9-76.userapi.com/vykv9zraqEsT2-cNLvYlyjVAkXOK_LXeqcoTJg/rtByOYcSQdw.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 98,
#          'url': 'https://sun9-64.userapi.com/KYOFCiBbKEFF905u1kLroKwczdJe_lHesikuSw/eijCpvx6WkY.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 150,
#          'url': 'https://sun9-8.userapi.com/sVU0AGnnILCcTZC0bKGkWJ0DtMkX5L3i-WnMYg/qbXZD3gmnoo.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 240,
#          'url': 'https://sun9-23.userapi.com/-saY9OzrVHEGSc0ldrhNTW5CEmR1gywYuNXONQ/is6fYhg4_ik.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 383,
#          'url': 'https://sun9-41.userapi.com/5RJIOUnfsLnZkM9KbBwfTTVeilYxaWSOGqmlqg/k66Whb4rv00.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 56,
#          'url': 'https://sun9-30.userapi.com/4uPJYu6EiCwpZHqXPSuF7H7MVioGd3T_VYWknQ/Wnn0wY_pHz0.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 1920,
#          'url': 'https://sun9-45.userapi.com/92QYc9uzGc45M9QVkGTlwOaCXVIKTfjU2I3E-Q/FO86H1YqWfk.jpg',
#          'type': 'w',
#          'width': 2560},
#         {'height': 453,
#          'url': 'https://sun9-60.userapi.com/iQh_PfKERxujjOch53GWedX-hFneqghNgjDYMg/Shc_BDFY03g.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 605,
#          'url': 'https://sun9-50.userapi.com/kOJEgTwz-CGRfU1ietMSF3uN8Rvg0sXrkjkKdg/fwHhby02-Zk.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 960,
#          'url': 'https://sun9-74.userapi.com/NvNVBB0hBB3WW129LViz_nwqaLv8cY1QlywNTw/JbyYmWlhuBM.jpg',
#          'type': 'z',
#          'width': 1280}],
#        'text': '',
#        'user_id': 100}},
#      {'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1601977705,
#        'id': 457242746,
#        'owner_id': -9690799,
#        'has_tags': False,
#        'access_key': '73756b8eb6214107fb',
#        'sizes': [{'height': 97,
#          'url': 'https://sun9-50.userapi.com/Wd_xsf30Ev7IdSykWUuU_8x1tG6hoq3q_AHPDw/KpaGvi0AS8w.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 98,
#          'url': 'https://sun9-61.userapi.com/IqcwxsiHdGRcNkAFc0x-AOYJWejyLLTdjje5Yw/_0H2SW0QMNs.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 150,
#          'url': 'https://sun9-9.userapi.com/B_ttZ3Xi7qUgsTO105tFQaHIIP4xbGGwdkuqSQ/jjR0UW4fY1o.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 240,
#          'url': 'https://sun9-52.userapi.com/zlUd0kM9DieDdhMJOeCTtSC_CP32kSg6JBBAYg/IHZmn7_mAhk.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 383,
#          'url': 'https://sun9-75.userapi.com/Maq_3lKEtKq_le05Au0AB6K2Aq113A94PFbnGA/VpKzjVDRMA0.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 56,
#          'url': 'https://sun9-66.userapi.com/S3m3xlXyLIoHPu5QGY9pUUKrYzP33RM8Lqce9w/qkGuL4CtAY8.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 1920,
#          'url': 'https://sun9-31.userapi.com/Leb1t0YzTnk9lPnb17j4S8RFEtClekoMzDDOKg/-tqUlmqYZIs.jpg',
#          'type': 'w',
#          'width': 2560},
#         {'height': 453,
#          'url': 'https://sun9-37.userapi.com/NhOvuu0RLytFQSrUVq96hqi4jFSXz_BdUlxibQ/JAOPJKJyPa8.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 605,
#          'url': 'https://sun9-14.userapi.com/UYM8snxR6JVkBRRubNYDqTN-iAxZt8gTCaWnog/VNQRE4CN52g.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 960,
#          'url': 'https://sun9-23.userapi.com/uQMAzv-K25vDZQT1rvQVuUbDamJBlpvDmuhXjw/OIp6ZC8zA4g.jpg',
#          'type': 'z',
#          'width': 1280}],
#        'text': '',
#        'user_id': 100}},
#      {'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1601977705,
#        'id': 457242747,
#        'owner_id': -9690799,
#        'has_tags': False,
#        'access_key': '140acda7c181404393',
#        'sizes': [{'height': 97,
#          'url': 'https://sun9-65.userapi.com/Ci6mm8pHcjV07oT2wnO_RbOX9MHboevolkLOCQ/eJuKQZKnU7s.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 98,
#          'url': 'https://sun9-22.userapi.com/5xJy7lIyY-I-D7QHySiLKy8qfzca4gjUKmmuug/dqgfkhrYFEs.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 150,
#          'url': 'https://sun9-41.userapi.com/9MoU00I7ODSihPkJ42J3fwuKkcPaxFpiSKPqBQ/TaVZANB01xY.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 240,
#          'url': 'https://sun9-56.userapi.com/S2vJ31LVx8HR70H7cAv1AY3vPNDtKRoLr8EWGA/Inb1tBm-vxU.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 383,
#          'url': 'https://sun9-18.userapi.com/0jZiIItnYQ6Defsq3jL2N29HjjL97-cSp9BwoA/5wWg4ynqgCE.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 56,
#          'url': 'https://sun9-16.userapi.com/ePQwurB3k9EmdahUd6d26HMtLvmsAtNCTQAZCg/KB8D0YMIm-s.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 1920,
#          'url': 'https://sun9-44.userapi.com/D2DbLg5izu48gJwPfR92Yb_UzwI4xzLI5w5Hig/v_8dShB6XY4.jpg',
#          'type': 'w',
#          'width': 2560},
#         {'height': 453,
#          'url': 'https://sun9-76.userapi.com/SmPr9IZFb8Y3GsU1WbaCMlRNsAyw6lV0oJ2Msw/kUutO9M3sd0.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 605,
#          'url': 'https://sun9-74.userapi.com/q6IUYsSjZ7vbHjpnzv2-Com-Tr1oShlqqfUqsg/sjgkStoJY2I.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 960,
#          'url': 'https://sun9-31.userapi.com/ockqQicw4eRM1D_dQ5F28MC5gvTj8WqwPZJBIw/1Y93xQyulmA.jpg',
#          'type': 'z',
#          'width': 1280}],
#        'text': '',
#        'user_id': 100}},
#      {'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1601977705,
#        'id': 457242750,
#        'owner_id': -9690799,
#        'has_tags': False,
#        'access_key': '14dbef9c7aac0741e1',
#        'sizes': [{'height': 97,
#          'url': 'https://sun9-30.userapi.com/zpBSqorFdZgoF9Xps3n46ZgquyqOFxRa3KJCmw/xsDjNUNHR9I.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 98,
#          'url': 'https://sun9-60.userapi.com/W8rpFNXdAMr6T5gmEG_oxNy8mSyhaK7-qIIMlA/Jdb2XWRF3kQ.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 150,
#          'url': 'https://sun9-7.userapi.com/sYEb43Te_Dx9ng-VesJYyQk_Zi2OOh4hMWBGMw/bDrAataF1Ns.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 240,
#          'url': 'https://sun9-31.userapi.com/IPNO1QOvtJipnTRcEhiphr1ITSWcV8dttxa2Cw/RCoeC0gXQV0.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 383,
#          'url': 'https://sun9-28.userapi.com/_n48nQNwLVryc1LLYFasYAvIXl2CSeRU0GIrGw/J-CCHgtZXH8.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 56,
#          'url': 'https://sun9-68.userapi.com/4cfkXlxMViYV83UnsWPEdJXl_xK2LOIaNPVVBg/Igv_NkKnnl4.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 1920,
#          'url': 'https://sun9-58.userapi.com/OUWBGdItOET06HODSgGWsQH_F7nmrQepP3VOYg/JeuzNIl8tq0.jpg',
#          'type': 'w',
#          'width': 2560},
#         {'height': 453,
#          'url': 'https://sun9-9.userapi.com/W30WqsTymEaPdstjkE0EAhh7g5CYmnxw2p1Nww/ru1BjduG8jw.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 605,
#          'url': 'https://sun9-54.userapi.com/WHSeLe7LjdXgunvlqm058cJP8vWMI2m5Ru5DHw/y1DM1ob9LLM.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 960,
#          'url': 'https://sun9-13.userapi.com/mc6eG_-L00MDFMJXFJ50puK7aWtc9UXETKKluA/zNh-8PbDs9M.jpg',
#          'type': 'z',
#          'width': 1280}],
#        'text': '',
#        'user_id': 100}},
#      {'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1601977705,
#        'id': 457242748,
#        'owner_id': -9690799,
#        'has_tags': False,
#        'access_key': 'b82779a1dc23387d95',
#        'sizes': [{'height': 97,
#          'url': 'https://sun9-22.userapi.com/rCw5zgnHzkhnc9wTXt8C08pzw5MZxUX3y9E6bw/YFr3r20tN-A.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 98,
#          'url': 'https://sun9-54.userapi.com/ZWKuWUrvlpmA5Dv3Qb7eJayxWbqpq-ncR5nE2g/7sTQApP-02k.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 150,
#          'url': 'https://sun9-33.userapi.com/9O9_5L-Lo4aYYGPEGAnzfWmV4nQ8iZhUXJDihQ/vInTf3H3uGs.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 240,
#          'url': 'https://sun9-42.userapi.com/RMvIztrUR8JKQ0zMD1lSLWApRD-M4qULpjBwQQ/KMqa9W7xI34.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 383,
#          'url': 'https://sun9-59.userapi.com/S0dsM5bBBnEAHGtxUVonCMgIKq1Y0CDFPlHT5A/ImYbHmcPlrI.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 56,
#          'url': 'https://sun9-42.userapi.com/kNJynq3h_0PxvdgpPRCUul17DulpQvPeX_1uGQ/aZJMTXahkwM.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 1920,
#          'url': 'https://sun9-23.userapi.com/ncn1I7ghASpeQdCRwTcyYXmuTW00aTrBYGORoQ/2PEqym2K1sc.jpg',
#          'type': 'w',
#          'width': 2560},
#         {'height': 453,
#          'url': 'https://sun9-18.userapi.com/KmXMG9NaWk2ro1AYPn6cueFNXfKybtsrf1Gc_g/KeRw1LY0USs.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 605,
#          'url': 'https://sun9-5.userapi.com/NFPAOzXw6TBfxu0s9YZOfAvFE3R2GPU8FYTj0w/TBsHMkWrv_w.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 960,
#          'url': 'https://sun9-33.userapi.com/xTKOCz4dpmbij6O8doIa9QHyD7Yu8MiEkl59Og/l1GOYhdetPw.jpg',
#          'type': 'z',
#          'width': 1280}],
#        'text': '',
#        'user_id': 100}},
#      {'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1601977705,
#        'id': 457242751,
#        'owner_id': -9690799,
#        'has_tags': False,
#        'access_key': 'd24457e169835273b5',
#        'sizes': [{'height': 97,
#          'url': 'https://sun9-54.userapi.com/4AiQSx6V5VPpW_T6PcQazI6DvWIEqHpoFB9dXg/gUAMEOPvfFQ.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 98,
#          'url': 'https://sun9-40.userapi.com/cfpuvWcRf2jAYLiBq9cjp_rB67ttkyGOGWyi0w/lQaoTCCQeEY.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 150,
#          'url': 'https://sun9-39.userapi.com/cY_r_3JNttvb7xJj5SMu2AaoktLp-Myihjx0hQ/KdgQIF9i63k.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 240,
#          'url': 'https://sun9-37.userapi.com/vcSuchIHr93y1vFyVfRkUl-Lu75ugtIrupdHmw/jMEsjM5o6kk.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 383,
#          'url': 'https://sun9-60.userapi.com/xvMN9qaX5N0GVSs9VRY1CdBh5DI-oPHwY1_EyA/iRdoAcIdFUQ.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 56,
#          'url': 'https://sun9-67.userapi.com/OYIYoNVpOL7n9z7bhNxO-hru89QfVChiCyN-Pw/Nx-JRUlCemc.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 1920,
#          'url': 'https://sun9-13.userapi.com/yfREZNzDv2QBgLAuvuYLhOlylXO9Jdv_Lmn_9g/z9L84lHT3RE.jpg',
#          'type': 'w',
#          'width': 2560},
#         {'height': 453,
#          'url': 'https://sun9-50.userapi.com/9Y49V6_1uaAdV74sD_bT3nO_hkoh1sk3L4eTTg/xiHFJ5sECm0.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 605,
#          'url': 'https://sun9-50.userapi.com/GHnnAC9KytJEKa2bW4baJDAUVeUaeFH0u_Izgw/XpDumVw0hxY.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 960,
#          'url': 'https://sun9-32.userapi.com/q-vXOpnMxVcvZa7asnfP_ch2ig_gku5nAG_Sxw/ET4FQt_T1vo.jpg',
#          'type': 'z',
#          'width': 1280}],
#        'text': '',
#        'user_id': 100}},
#      {'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1601977705,
#        'id': 457242752,
#        'owner_id': -9690799,
#        'has_tags': False,
#        'access_key': 'f5d1b82fa46c3a5b4a',
#        'sizes': [{'height': 97,
#          'url': 'https://sun9-4.userapi.com/6aL0D-DC4Fxt6TVXntWzlASgBs4VjbpV5IfZYA/x8wu-BuPeOs.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 98,
#          'url': 'https://sun9-11.userapi.com/T-ulrHPpjg8LEwidQoKI1irl2DDgLC8bm_HxIg/Cs_Vo52AgrA.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 150,
#          'url': 'https://sun9-68.userapi.com/Pdmgon1nK3DixzW_ocRygm4FbVpo_8deNslgjg/hsrYFyIA_Sk.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 240,
#          'url': 'https://sun9-60.userapi.com/R6i41V81m8dPENgbnyrDbPQtMU8QtNnjQl2v2w/APNWplVfwsk.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 383,
#          'url': 'https://sun9-3.userapi.com/4ja2sRDa401O0DUQ49dDZPyLQcXm1vYFRPCNIA/Xt2hrjLLgJQ.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 56,
#          'url': 'https://sun9-6.userapi.com/STT61jZ_qKBhQSb1RvszX7NRBvpsXVt9iF0mEw/yJiIPeiyqjM.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 1920,
#          'url': 'https://sun9-11.userapi.com/0UwaFa4AVe9lkG1tYaXZ-o0lHgksr7PPDQ27rQ/01wgDIX1hLo.jpg',
#          'type': 'w',
#          'width': 2560},
#         {'height': 453,
#          'url': 'https://sun9-69.userapi.com/MFBQGJPa6wtm80GA7IWFugRclsB-oJjyNmrcbA/mwPTL-Bcdkk.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 605,
#          'url': 'https://sun9-43.userapi.com/aecBQS2Epdb44W-DQCt4JHuW1teOsuV14m91zA/xdpYV9ue_dI.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 960,
#          'url': 'https://sun9-53.userapi.com/eAEdCSCpI6RIwnj4nVdOFQEs6epRmXUv2WyWlA/q7EFbAUJpv4.jpg',
#          'type': 'z',
#          'width': 1280}],
#        'text': '',
#        'user_id': 100}},
#      {'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1601977705,
#        'id': 457242749,
#        'owner_id': -9690799,
#        'has_tags': False,
#        'access_key': '78dfe5a51404b2998d',
#        'sizes': [{'height': 97,
#          'url': 'https://sun9-21.userapi.com/WMOlFYHDOnN4XHV1Pe-qyIuSZo1sH4w-smzF0w/7Z9lPMgXuvc.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 98,
#          'url': 'https://sun9-20.userapi.com/ehtIgVEWDoi41VUlD1YCUMCvCAz6fJL3QAb44Q/BIrjJ4Fz6z8.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 150,
#          'url': 'https://sun9-47.userapi.com/b71gu2upisHiNq8I2NbI3TVuYtoICDfVKALByA/smaEDU32Y5Q.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 240,
#          'url': 'https://sun9-9.userapi.com/84rES-z2zP3UUAJS_IvGWqEK3KyNH8TWNmSooQ/bcp86287aDM.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 383,
#          'url': 'https://sun9-49.userapi.com/DnxUSGjN_EmE9sxLVKtham6OeVJBUyOftGLK3g/luxO0nrY8ts.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 56,
#          'url': 'https://sun9-45.userapi.com/Woa-TgOUTOqOsDfU-TfawXjlQeDySK9dcCwiJw/7l2Ou47P0fA.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 1920,
#          'url': 'https://sun9-11.userapi.com/miBP4lqRxp5WdQJfVXXXjYzwT2-Rw_RCmgVftw/u-7b4oN-AkQ.jpg',
#          'type': 'w',
#          'width': 2560},
#         {'height': 453,
#          'url': 'https://sun9-68.userapi.com/kzveyFWoTOz0L00aHmJZ4xcdAYi0uMDDD8HDnA/xZp1uDava14.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 605,
#          'url': 'https://sun9-59.userapi.com/_f-GYtTBi2hD1uP5xtg9pi4w8vgAPdn5SXuf0w/4JlYXIuzWA0.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 960,
#          'url': 'https://sun9-63.userapi.com/e7W-TZf7IOyF8yxL38H2QIlfOy6IJJfMAq7reg/YJ-YhLkNAZg.jpg',
#          'type': 'z',
#          'width': 1280}],
#        'text': '',
#        'user_id': 100}},
#      {'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1601977705,
#        'id': 457242753,
#        'owner_id': -9690799,
#        'has_tags': False,
#        'access_key': 'e71e3afb1c6b8a2b54',
#        'sizes': [{'height': 98,
#          'url': 'https://sun9-57.userapi.com/3wG4fjULnsEG9C6_193ReLynW7OAqrS-PglcsQ/nybYRlllX0w.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 98,
#          'url': 'https://sun9-57.userapi.com/3wG4fjULnsEG9C6_193ReLynW7OAqrS-PglcsQ/nybYRlllX0w.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 150,
#          'url': 'https://sun9-16.userapi.com/CBJr8JwTtp0uPmROEC-l4ySDjTVrJDkDhHupLg/UT3GMBFsYmE.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 241,
#          'url': 'https://sun9-64.userapi.com/TUUnJm5rv57E68Colxwo-Drz_7yBO1sZOQ2g-Q/mFpjd9b4UdA.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 384,
#          'url': 'https://sun9-70.userapi.com/OGTX2lCsUMFrKynX29o4F6VFsx0C1C1kYOqbyw/vjyf_eZwC8M.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 57,
#          'url': 'https://sun9-50.userapi.com/AB4goTZeYKivem04qLbmUu8dFboxl4s1mz5X2A/RMYEP5KlQR4.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 1528,
#          'url': 'https://sun9-17.userapi.com/xq5_Ah5SKBEBbLvjEsuICvhHj_HvuhJCmb-Bcg/gC2ybmX5HMQ.jpg',
#          'type': 'w',
#          'width': 2030},
#         {'height': 454,
#          'url': 'https://sun9-72.userapi.com/GDDbAu0TRhDcB6ibrT37ZllI5zZooka8kxuAwg/ccaWMdlgj_0.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 607,
#          'url': 'https://sun9-55.userapi.com/pqPAsk7DYIv3r0Sk19-tM5q6_4mm0dILwtq4dw/jldG-oKxZfc.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 963,
#          'url': 'https://sun9-76.userapi.com/uOqJQTd33ccbTnd-0NNGk3uCVopYrjQ5CMZulw/-BwEUaPvWF0.jpg',
#          'type': 'z',
#          'width': 1280}],
#        'text': '',
#        'user_id': 100}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 13, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 288, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 4, 'user_reposted': 0},
#     'views': {'count': 28070},
#     'edited': 1601977741},
#    {'id': 13772,
#     'from_id': -9690799,
#     'owner_id': -9690799,
#     'date': 1601661543,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'ВОСХОЖДЕНИЕ НА ДЫХТАУ 2021\nПредставляем вам новый маршрут!\n\nГора Дыхтау расположена у нас, в Кабардино-Балкарии, на границе с Грузией. Высота горы 5205 м., что делает ее второй по высоте вершиной Кавказа и России - выше неё только Эльбрус, 5642 м. Мы будем подниматься на вершину по северному гребню, сложность маршрута 4Б, то есть она значительно сложнее Эльбруса, несмотря на меньшую высоту. Для восхождения требуется физическая подготовка выше средней. Под этим подразумевается способность пробежать полумарафон (21 км.). Обязателен опыт не менее двух восхождений на вершины свыше 5000 м. Вам потребуются минимальные навыки работы на скалодроме. То есть если у вас этих навыков нет, то в течение нескольких месяцев перед восхождением вам необходимо походить на тренировки на скалодром. Кроме того, весьма полезно было бы незадолго до восхождения на Дыхтау подняться на какую-то другую вершину свыше 5000 м. Например, Эльбрус или Казбек.\n\nДата начала восхождения: 14 августа 2021\n\nРуководит восхождением Сергей Тарасов, один из лучших альпинистов России, Мастер Спорта Международного Класса, чемпион России и СССР.\n\nЦена на данный момент со скидкой - от 38 500 руб.\n\nПолное описание и бронирование - на этой странице: https://strahu-net.com/raspisanie/tur/?ELEMENT_ID=34499',
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://strahu-net.com/raspisanie/tur/?ELEMENT_ID=34499',
#        'title': 'Восхождение на Дыхтау, 5205 м. - 14.08.2021',
#        'caption': 'strahu-net.com',
#        'description': 'Восхождения на Эльбрус с 4х сторон Света, 10 маршрутов от 1 до 14 дней, разной сложности, протяженности и уровня комфорта.',
#        'photo': {'album_id': -26,
#         'date': 1601661542,
#         'id': 457303787,
#         'owner_id': 2000043043,
#         'has_tags': False,
#         'sizes': [{'height': 89,
#           'url': 'https://sun9-27.userapi.com/UiupMj0ywrLxpdq3zD3oGovq1j6LCDfT5VdRYg/LC1ppBS7H9c.jpg',
#           'type': 'a',
#           'width': 200},
#          {'height': 178,
#           'url': 'https://sun9-44.userapi.com/aV6zpSnFR7q8Ru3x80TEWwL8qM6bGErXxAVt9g/aZExCxGGcrI.jpg',
#           'type': 'b',
#           'width': 400},
#          {'height': 200,
#           'url': 'https://sun9-5.userapi.com/8y0_vwscEtImFwL2M-Wdxm6Llon-ly_Zs4tEBw/5We5O9d7A5E.jpg',
#           'type': 'c',
#           'width': 200},
#          {'height': 100,
#           'url': 'https://sun9-45.userapi.com/K1loH4MxGRbb6etQHOg0abKu6JHqQS2UifPqFQ/mMpmJ12h3CM.jpg',
#           'type': 'd',
#           'width': 100},
#          {'height': 50,
#           'url': 'https://sun9-30.userapi.com/g5YefjyMzu4X8VGf4jBdn5w6UEzMvext70DOkA/ABPMSRKQF4g.jpg',
#           'type': 'e',
#           'width': 50},
#          {'height': 479,
#           'url': 'https://sun9-43.userapi.com/yxtILiSWvenLcoCgJAD62R-jkE_00S6D1owwIA/4SMmy7E2FFU.jpg',
#           'type': 'k',
#           'width': 1074},
#          {'height': 240,
#           'url': 'https://sun9-7.userapi.com/hAALQUYIk5vMEQQ0sH6-QK46IHHgvJs4Kf4lGw/U45bug3tAHk.jpg',
#           'type': 'l',
#           'width': 537},
#          {'height': 508,
#           'url': 'https://sun9-10.userapi.com/0HzM15roTehtEXois0v_qkxqoZB10g9SkMBpbg/115VDbNHrWI.jpg',
#           'type': 'o',
#           'width': 1140}],
#         'text': '',
#         'user_id': 100}}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 12, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 86, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 4, 'user_reposted': 0},
#     'views': {'count': 10470},
#     'edited': 1601721438},
#    {'id': 13762,
#     'from_id': -9690799,
#     'owner_id': -9690799,
#     'date': 1601543773,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Восхождение на Эльбрус с востока - самый непопулярный маршрут в сравнении с южным и северным, но он же и самый красивый. В отличие от других маршрутов здесь нет никаких следов цивилизации: ни канаток, ни ресторанов, ни отелей, ни даже дорог. И если вы хотите увидеть первозданную природу Кавказа, то вам сюда.\n\nВ то же время этот маршрут более сложный физически и подойдет не всем. Вам необходимо иметь по крайней мере среднюю физическую форму. Какая-либо техническая подготовка или опыт восхождений не требуются.\n\nЧто вы увидите на маршруте:\n1. как прямо из земли в горах течет нарзан \n2. песчаные останцы\n3. водопад\n4. ущелье Ирикчат от начала до конца, от соснового леса и до ледника\n5. панорамный вид на 360 градусов с вершины Пик Потона: вид на Эльбрус, лавовый поток, Главный Кавказский Хребет и окружающие вершины\n6. боковой кратер Эльбруса\n7. прекрасный восход солнца во время восхождения на вершину (поскольку это восточная сторона горы)\n8. самое звездное небо, какое можно видеть только в высоких горах\n\nРасписание туров на Эльбрус с востока на 2021 год - по ссылке ниже, в данный момент действуют скидки:\n\nhttps://strahu-net.com/raspisanie/?year=2021&ROUTE=East',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1601543773,
#        'id': 457242743,
#        'owner_id': -9690799,
#        'has_tags': False,
#        'access_key': 'f1e6aaa2beea91b12a',
#        'post_id': 13762,
#        'sizes': [{'height': 97,
#          'url': 'https://sun9-20.userapi.com/AOVcZgRb72QptxLQaeCImkE9sEaYnMCe12K4gg/6QhMAnwx2oM.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 98,
#          'url': 'https://sun9-27.userapi.com/epdtzhAb-t0eQyWMS-ImItnDnPLeui9NPjC4WA/9_gTVb0g1Mg.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 150,
#          'url': 'https://sun9-58.userapi.com/Q1lQSP3QvsmxRSCbNH6TSwuvy_juPeRKKyQHAg/1y3Z6QrWAoY.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 240,
#          'url': 'https://sun9-7.userapi.com/k8_W2dW-uBd2XkW1div6iJsV1ItQubR02q1eZg/mUeO_V29-D4.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 382,
#          'url': 'https://sun9-62.userapi.com/xijftzSbttxb_Y96n5grV-_4dhemWAt1SDV47A/GsPygIEPHD8.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 56,
#          'url': 'https://sun9-48.userapi.com/XAv1phhAkyaolDYefvnWZ5kFwdcjAnfvN8vmng/IQG4DFNd9IA.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 453,
#          'url': 'https://sun9-7.userapi.com/_HTGse7f_C2G6Gi6ZwH6JVo7vc3EhoFGiPTV8A/m8esW7VWb_k.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 605,
#          'url': 'https://sun9-73.userapi.com/I73B6_m8-_GVXeaSwHjs179PSeotzoD7WRLH6w/ou9QBuevl1A.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 956,
#          'url': 'https://sun9-54.userapi.com/qzDVpWmLcuDO4i9VUa75Ku1y3JqQJ1FAMxVBdg/PUzCqrwY_Lc.jpg',
#          'type': 'z',
#          'width': 1276}],
#        'text': '',
#        'user_id': 100}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 18, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 1081, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 27, 'user_reposted': 0},
#     'views': {'count': 92162}},
#    {'id': 13754,
#     'from_id': -9690799,
#     'owner_id': -9690799,
#     'date': 1601190530,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Прямой эфир 27.09.2020 \nИннструктор Сергей Тарасов Мастер Спорта Международного класса по альпинизму, проводит брифинг перед началом восхождения на Эльбрус с юга.',
#     'attachments': [{'type': 'video',
#       'video': {'access_key': '538093e0e461ed0099',
#        'can_comment': 0,
#        'can_like': 1,
#        'can_repost': 1,
#        'can_subscribe': 1,
#        'can_add_to_faves': 1,
#        'can_add': 1,
#        'comments': 5,
#        'date': 1601190533,
#        'description': '',
#        'duration': 1777,
#        'photo_130': 'https://sun9-23.userapi.com/t-NGh4AjpeC6JLoPQDL_Hvza3SjUBGz7ECYDAA/zHHufUo80-U.jpg',
#        'photo_320': 'https://sun9-40.userapi.com/3JF29aJbJHP-TSxVYgdqk0-ZQxkevZ9KBK330A/xgzuY-XMJLA.jpg',
#        'photo_800': 'https://sun9-63.userapi.com/rdHWE_mlkn3CEZ3tAXDuE70pTEdWTl8EpP9yZg/MptaonK3hho.jpg',
#        'photo_1280': 'https://sun9-73.userapi.com/F06sHVjj6VZu_KLsfcFpRcoK4iLoAFnTDAHIOQ/73e-NS2XEzo.jpg',
#        'first_frame_130': 'https://sun9-11.userapi.com/QwGAie0tysSK-oEaSfv0c5Xi6B0atJX8GnyLiw/OxCTRo-SZ2E.jpg',
#        'first_frame_160': 'https://sun9-37.userapi.com/Lf_zoHxfKK-R7_nG5QEk328GihytwYNuiet7ug/7oUTBkUU3Aw.jpg',
#        'first_frame_320': 'https://sun9-28.userapi.com/7JhlWlu7DwVaYJ1XvEDprYyNp_qXAe01khyKrA/0HMUCvC76W4.jpg',
#        'first_frame_800': 'https://sun9-55.userapi.com/lrRCpSy2y6XeBOcmLVrrp2GxKGXKnHDN3mug6g/D_8BSqzjkDo.jpg',
#        'first_frame_1280': 'https://sun9-48.userapi.com/5Wi2me109pUzcStHiSZKvusnmoua1D2kd2Qgcg/esiff6FZmQU.jpg',
#        'width': 1920,
#        'height': 1080,
#        'id': 456239101,
#        'owner_id': -9690799,
#        'title': 'Live: Восхождение на Эльбрус | Elbrus Climbing',
#        'track_code': 'video_178fef06krFD65e-uwvKq3Ayu35EuoR8lhVz5sCTtOs9tewSJ8apmjHjkrC-CPOSLwaOSHaJvU2mJHc',
#        'views': 11731}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 5, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 43, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 2, 'user_reposted': 0},
#     'views': {'count': 7810},
#     'edited': 1601192544},
#    {'id': 13714,
#     'from_id': -9690799,
#     'owner_id': -9690799,
#     'date': 1600677360,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Восхождение на Эльбрус - это "перезагрузка", это возможность "остановиться" и какое-то время никуда не бежать. Это такой отдых для мозга, какой при нашем бешеном ритме жизни в обычных условиях просто невозможен. А еще это опыт, несравнимый ни с чем и абсолютно незабываемый. Присоединяйтесь к нашим группам в 2021 году!',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1600636333,
#        'id': 457242720,
#        'owner_id': -9690799,
#        'has_tags': False,
#        'access_key': 'abf01968eab668a370',
#        'post_id': 13714,
#        'sizes': [{'height': 97,
#          'url': 'https://sun9-28.userapi.com/rOCaKMXLiLhuf9PkmMoqoNRbf_N3n_ExwPbDng/DtjbteKE36c.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 98,
#          'url': 'https://sun9-34.userapi.com/xKwneX4i256f2k8TcFJSMdHHsnXLnov8Kw6HvQ/e1ONsnHV5WA.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 150,
#          'url': 'https://sun9-21.userapi.com/-q-ocMl2Gjg-3KHAkDs42OlZw0sw5w4vjqWoJg/-98Ru45cLNQ.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 240,
#          'url': 'https://sun9-40.userapi.com/iw2NrNuAKyRKe-ugP0ja2eWEVQ8axoWULtvimg/bOt9Bln2ujU.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 383,
#          'url': 'https://sun9-45.userapi.com/z8DNoeIJz99ajiNXppGPNXn_eaRnnJq3Qomcfg/1zC5p3DP-08.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 56,
#          'url': 'https://sun9-14.userapi.com/I-lXfuVkSoTDKef_UYMO5RgwNSStk0qKt_7FMA/Dr26WwUMBoM.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 453,
#          'url': 'https://sun9-14.userapi.com/zXQaS1EPIOUqNxIpZZ3LQahN31rRPGUnnASxxQ/v_wWgaHlGlo.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 605,
#          'url': 'https://sun9-31.userapi.com/HAtgQraCkbEIdmgcwWXPIgUZpCdjZoA6TiJN0g/d6tPSNaK_tQ.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 855,
#          'url': 'https://sun9-40.userapi.com/iQMSqTDo3_NVfkI-PqVyVCoEVR7DYEWr5sS6Cg/GZIA_kggUXg.jpg',
#          'type': 'z',
#          'width': 1140}],
#        'text': '',
#        'user_id': 100}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 22, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 450, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 11, 'user_reposted': 0},
#     'views': {'count': 61527}},
#    {'id': 13692,
#     'from_id': -9690799,
#     'owner_id': -9690799,
#     'date': 1600629516,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'За первые несколько дней экотура на Эльбрусе собрали 725 кг. мусора. Все это - мусор из района Ледовой Базы. Красивое, но очень замусоренное место. Этой осенью у нас четыре экотура, и мы поставили себе цель очистить это место от мусора по возможности полностью. Так что эти 725 кг. - только начало. И кстати, в предстоящих трех группах еще есть несколько мест. Туры некоммерческие, взнос 5000 руб. Расписание/регистрация здесь: https://strahu-net.com/raspisanie-turov-na-elbrus/?year=2020&ROUTE=Ecological_tour\n\nPS. Спасибо Национальному Парку Приэльбрусье за помощь - они бесплатно предоставили машину, которая спустила весь собранный мусор с Обсерватории.',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1600629516,
#        'id': 457242719,
#        'owner_id': -9690799,
#        'has_tags': False,
#        'access_key': 'd84cdaa14504315eb7',
#        'post_id': 13692,
#        'sizes': [{'height': 97,
#          'url': 'https://sun9-42.userapi.com/bzl5vuxiqiB9BUybs1YS1z6pkExM2QVzP3sTww/RQjwCNlLFUU.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 98,
#          'url': 'https://sun9-39.userapi.com/i89cKiSpZ_UujCNQvZBlbkPA8PK3otPYYOJUAw/u0Bxdc-StLI.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 150,
#          'url': 'https://sun9-23.userapi.com/6Q5JVDJwwlDYSfT9v2xZH_IfM-UxbuuC1XlYgA/WLmiZPjZfH8.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 240,
#          'url': 'https://sun9-61.userapi.com/ImG4sJDk9URu3T7TBYnE1ru9-sSNWp8jfa6dsg/BSpU7p5TCRg.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 383,
#          'url': 'https://sun9-31.userapi.com/c5TjLVZIAxl57nWEJouOhfPNl6kJZvO_910PaA/O5uNwu4K4z4.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 56,
#          'url': 'https://sun9-34.userapi.com/OQl5V-uXV69dzX2ERkxCrVu58FCqedURvTMuqA/9Qu7aWNdYqk.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 1920,
#          'url': 'https://sun9-51.userapi.com/a633S6yDQKzQwO6dPTNS5krGEsrgp6UcU1JOIQ/tme0So2NZqI.jpg',
#          'type': 'w',
#          'width': 2560},
#         {'height': 453,
#          'url': 'https://sun9-34.userapi.com/5_1o7WtUdQ_kkuawI5opgzn9BefrShEznp-8cw/P5XJo0VGeZs.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 605,
#          'url': 'https://sun9-51.userapi.com/NT6QTZPzKIW9eCey9duU6UjvPO1GrJ3e8BzyOQ/cvsCGMZzp8k.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 960,
#          'url': 'https://sun9-46.userapi.com/8TB1eNHZwzdV7z1LflaoCEXsJvPuCUTUZLvPKg/iBmnnQr6Krs.jpg',
#          'type': 'z',
#          'width': 1280}],
#        'text': '',
#        'user_id': 100}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 31, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 492, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 13, 'user_reposted': 0},
#     'views': {'count': 26393}},
#    {'id': 13620,
#     'from_id': -9690799,
#     'owner_id': -9690799,
#     'date': 1600166973,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'ТУРЫ НА ЭЛЬБРУС 2021\nНабираем группы на Эльбрус на зимний период и на весь летний сезон 2021 года. Помимо традиционных туров с юга, севера и востока планируется один единственный тур с запада. Есть программы для любого уровня физической подготовки. Чтобы подобрать программу, соответствующую вашим желаниям и физическим возможностям, свяжитесь с [id184965800|Игорем Курсом], и он вам все расскажет, покажет, на вопросы ответит и, если надо, сам заявку сформирует. Ему также можно написать или позвонить в Whatsapp или Telegram:  +79054994293\nАбсолютно всю информацию вы также сможете найти на нашем сайте: elbrus.vip\nДа, и самое главное.. Как и обычно - при бронировании туров сейчас, цены на туры меньше 50% от их обычной стоимости.',
#     'attachments': [{'type': 'video',
#       'video': {'access_key': '902e41fa4a9d11e6f5',
#        'can_comment': 0,
#        'can_like': 1,
#        'can_repost': 1,
#        'can_subscribe': 1,
#        'can_add_to_faves': 1,
#        'can_add': 1,
#        'comments': 9,
#        'date': 1544746556,
#        'description': 'Восхождение на Эльбрус с компанией Страху Нет\nРасписание туров на Эльбрус на этой странице: strahu-net.com\nА все вопросы можно задать, позвонив по телефону:\n+7 495 1087 4 65\n',
#        'duration': 133,
#        'photo_130': 'https://sun9-32.userapi.com/c847221/v847221165/14cd35/c2_Q4uOVOoM.jpg',
#        'photo_320': 'https://sun9-55.userapi.com/c847221/v847221165/14cd37/-G6bdP0jin4.jpg',
#        'photo_800': 'https://sun9-9.userapi.com/c847221/v847221165/14cd38/CJNIcHvnrH0.jpg',
#        'id': 456239036,
#        'owner_id': -9690799,
#        'title': 'Восхождение на Эльбрус с компанией Страху Нет',
#        'track_code': 'video_64bc1050URWgXhl8BET14VLkc6So6j8uSigXNsCTN15xjxxgo6dqPtJWHHMGQ8zYDdBGkprZBh55HhM',
#        'views': 4611,
#        'local_views': 4611,
#        'platform': 'YouTube'}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 452, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 11, 'user_reposted': 0},
#     'views': {'count': 82312}},
#    {'id': 13611,
#     'from_id': -9690799,
#     'owner_id': -9690799,
#     'date': 1600164189,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Потерявший ноги 28-летний уфимец Рустам Набиев совершил восхождение на Эльбрус, пройдя на руках 13 км. Это восхождение он посвятил жене и двум дочерям.',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1600164189,
#        'id': 457242718,
#        'owner_id': -9690799,
#        'has_tags': False,
#        'access_key': '2a0d0e16e0199fc912',
#        'post_id': 13611,
#        'sizes': [{'height': 80,
#          'url': 'https://sun9-69.userapi.com/Kx42No84m22Kdgh0sizr7x43UWHnJl46a2j6vw/KDUi6H45rJo.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 87,
#          'url': 'https://sun9-32.userapi.com/r9uQPUCqzVCNqBLaTXXAo4TqSpySMbQNQw6a4g/RrynmjCF-EU.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 133,
#          'url': 'https://sun9-26.userapi.com/gBP2i47-K_Bt7wBn0JPr3Z5iSL1184z27oUGgg/hVh3HVCJyJ4.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 213,
#          'url': 'https://sun9-71.userapi.com/o9SJqQLBRFj5Jx51qgavVwNQzgunCJcrgVVlNA/jR5N6VK-f8o.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 340,
#          'url': 'https://sun9-35.userapi.com/W93Mdtv9ciyTa-1s65QPiOjlDcLlIzhcCUrBtQ/zBxd36J6nss.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 46,
#          'url': 'https://sun9-57.userapi.com/A_Jb08N64esJ_kyVdGwAu39g7T24W2hSfst8Nw/TEEHZKHZgV4.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 373,
#          'url': 'https://sun9-39.userapi.com/cnU_NvYXu36S6ifWRTPpoiOPlFADs7R7kTxfFQ/ix3JMlPDKek.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 499,
#          'url': 'https://sun9-57.userapi.com/DavX3XB7Fl0nDBxbvo1TyanwMjxkb7vdPPcFYQ/t540iwpVqGM.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 680,
#          'url': 'https://sun9-75.userapi.com/eVb9deE4IRFLBxwTQqnM-QRRNoHYh7qH1KWWzw/LzSoLn4_JBk.jpg',
#          'type': 'z',
#          'width': 1100}],
#        'text': '',
#        'user_id': 100}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 75, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 2272, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 64, 'user_reposted': 0},
#     'views': {'count': 58056}}]}}

# %% [markdown]
# Видим, что сначала идёт общее количество постов, а по ключу `'items'`  —  сами посты. Посмотрим на отдельный пост:
#
# ```python
# response.json()['response']['items'][0]
# ```

# %%
response.json()['response']['items'][0]
# Out:
# {'id': 13830,
#  'from_id': -9690799,
#  'owner_id': -9690799,
#  'date': 1602330529,
#  'marked_as_ads': 0,
#  'post_type': 'post',
#  'text': 'ТУРЫ НА ЭЛЬБРУС, КАЗБЕК, ДЫХТАУ 2021\n(три Российских пятитысячника)\n\n1. Программы 2021:\nЭльбрус с юга (треккинг)\nЭльбрус с юга (комфорт)\nЗимний Эльбрус\nЭльбрус с востока \nЭльбрус с севера (короткий стандартный)\nЭльбрус с севера (треккинг)\nЭльбрус с запада\nЭльбрус с кислородом за 1 день\nКазбек с севера\nКазбек с юга\nДыхтау\n\n2. Гиды - инструкторы альпинизма, чемпионы России по альпинизму, КМС и Мастера Спорта.\n\n3. Офис в Пятигорске и собственный прокат всего снаряжения и одежды.\n\n4. Самый полный набор средств и мер безопасности, включая спутниковую связь и кислородное оборудование для экстренных случаев (для случаев острой горной болезни)\n\n5. Поддержка и помощь на всех этапах: выбор маршрута, физическая подготовка, выбор снаряжения - наши менеджеры всегда на связи с вами.\n\n6. Распродажа при раннем бронировании. Цены на туры в 2021 году стартуют от 10 000 руб при покупке до пятницы включительно.\n\n7. Расписание туров 2021 и бронирование здесь: https://strahu-net.com/',
#  'attachments': [{'type': 'link',
#    'link': {'url': 'https://strahu-net.com/',
#     'title': 'РАСПРОДАЖА ТУРОВ НА ЭЛЬБРУС, КАЗБЕК, ДЫХТАУ 2021',
#     'caption': 'strahu-net.com',
#     'description': 'Восхождения на Эльбрус с 4х сторон Света, 10 маршрутов от 1 до 14 дней, разной сложности, протяженности и уровня комфорта.',
#     'photo': {'album_id': -27,
#      'date': 1602353841,
#      'id': 457316006,
#      'owner_id': 2000046232,
#      'has_tags': False,
#      'sizes': [{'height': 90,
#        'url': 'https://sun9-58.userapi.com/RYLpy1XqFZL0tVXill9e3FCJO_DZWHtVdgz55Q/HRwPkIl3jds.jpg',
#        'type': 'a',
#        'width': 200},
#       {'height': 179,
#        'url': 'https://sun9-20.userapi.com/paj5NQm_4wnNncJnGD5hnBBzmE3A9SQqqx_F6Q/uVWKCpFrBug.jpg',
#        'type': 'b',
#        'width': 400},
#       {'height': 200,
#        'url': 'https://sun9-35.userapi.com/4Wtio0d9wmNtdwTExeoUi75g6zAltz2omJzuGg/7dfuuuCcXJg.jpg',
#        'type': 'c',
#        'width': 200},
#       {'height': 100,
#        'url': 'https://sun9-68.userapi.com/ytwLxss0lGBlFsH0lX_-BIua77kygOaji5-H7g/JuFP1MHXcD0.jpg',
#        'type': 'd',
#        'width': 100},
#       {'height': 50,
#        'url': 'https://sun9-11.userapi.com/5P7k7zNXDMeRAh1MHsiJhcQfi6a6OgHRETWPig/RV3p7p0YjC8.jpg',
#        'type': 'e',
#        'width': 50},
#       {'height': 480,
#        'url': 'https://sun9-10.userapi.com/_Bnc7KBh6K3-vLKB4z1NpwBc3oXuQVC-WkAx8w/YYYR8Geo3H0.jpg',
#        'type': 'k',
#        'width': 1072},
#       {'height': 240,
#        'url': 'https://sun9-50.userapi.com/dvXIYi8oAghg6hhG1fdInNj0lOw2zazIheNrNw/cgUG3zHwWok.jpg',
#        'type': 'l',
#        'width': 537},
#       {'height': 840,
#        'url': 'https://sun9-67.userapi.com/kZVbFiJ-U_egS6wC55s-tIV37g4kgpR_Y4zr6g/tVIDZ2gTf3k.jpg',
#        'type': 'o',
#        'width': 1876}],
#      'text': '',
#      'user_id': 100}}}],
#  'post_source': {'type': 'vk'},
#  'comments': {'count': 11, 'can_post': 1, 'groups_can_post': True},
#  'likes': {'count': 116, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#  'reposts': {'count': 7, 'user_reposted': 0},
#  'views': {'count': 59280},
#  'edited': 1602353841}

# %% [markdown]
# Нужная нам статистика находится в полях `'comments'`, `'likes'` и `'reposts'`. Соберем итоговую статистику для каждого поста в словарь `stats`.
# В качестве ключа будем использовать начало статьи, в качестве значения — список с тремя интересующими нас метриками и временем публикации: `[комментарии, лайки, репосты, дата публикации]`
# ```python
# stats = {}
#
# for record in response.json()['response']['items'][:]:
#     title = record['text'][:30]
#     if title:
#         stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date'] ]
# pprint(stats)
# ```

# %%
stats = {}  
              
for record in response.json()['response']['items'][:]:  
    title = record['text'][:30]  
    if title:  
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date'] ]  
pprint(stats)
# Out:
# {'ВОСХОЖДЕНИЕ НА ДЫХТАУ 2021\nПре': [12, 86, 4, 1601661543],
#  'Восхождение на Эльбрус - это "': [22, 450, 11, 1600677360],
#  'Восхождение на Эльбрус с восто': [18, 1081, 27, 1601543773],
#  'ЗИМНЕЕ ВОСХОЖДЕНИЕ НА ЭЛЬБРУС.': [1, 406, 11, 1602159033],
#  'За первые несколько дней экоту': [31, 492, 13, 1600629516],
#  'Потерявший ноги 28-летний уфим': [75, 2272, 64, 1600164189],
#  'Прямой эфир 27.09.2020 \nИннстр': [5, 43, 2, 1601190530],
#  'Свежие фотографии из нашего по': [13, 288, 4, 1601977706],
#  'ТУРЫ НА ЭЛЬБРУС 2021\nНабираем ': [0, 452, 11, 1600166973],
#  'ТУРЫ НА ЭЛЬБРУС, КАЗБЕК, ДЫХТА': [11, 116, 7, 1602330529]}

# %% [markdown]
# ### Задание 1 - SMM index
# Напишите функцию `get_smm_index(group_name, token)`, которая по имени группы и авторизационному токену API возвращает `smm_index` группы - ***сумму лайков, комментариев и репостов для последних 10 постов, поделённую на количество участников в группе***.

# %%
def get_smm_index(group_name, token):
    # определеям параметры запросов
    url_getMembers = 'https://api.vk.com/method/groups.getMembers'  
    url_wall_get = 'https://api.vk.com/method/wall.get'
    params_getMembers = {  
        'group_id': group_name,  
        'v': 5.95,  
        'access_token': token  
    }
    params_wall_get = {  
        'domain': group_name,  
        'filter': 'owner',  
        'count': 10,  
        'offset': 0,  
        'access_token': token,  
        'v': 5.95  
    }
    
    # плучаем количество участников группы
    response_getMembers = requests.get(url_getMembers, params = params_getMembers)  
    data_getMembers = response_getMembers.json()  
    
    members_count = data_getMembers['response']['count']
    
    # получаем сумму лайков, комментариев и репостов для последних 10 постов
    response_wall_get = requests.get(url_wall_get, params = params_wall_get)  
    data_wall_get = response_wall_get.json()
    
    reaction_sum = 0 
    for i in range(10):
        reaction_sum += (data_wall_get['response']['items'][i]['comments']['count'] +
                         data_wall_get['response']['items'][i]['likes']['count'] +
                         data_wall_get['response']['items'][i]['reposts']['count'])
    
    # вычисляем smm_index
    smm_index = reaction_sum / members_count
    
    return smm_index

# %%
get_smm_index('mountelbrus', token)
# Out:
# 0.08946540413784915

# %% [markdown]
# ## 9.18 Возможности API
# Мы рассмотрели базовое взаимодействие с пользователями и группами. ВКонтакте предоставляет достаточно широкие возможности в своём API: по сути, всё, что можно делать руками через браузер, доступно и в API. Обратим внимание: если вы размещаете рекламу в Вконтакте, то можно выгружать всю статистику через [ads API](https://vk.com/dev/ads).
#
# Полный список методов можно посмотреть в документации - https://vk.com/dev/methods

# %% [markdown]
# ## ПОДВАЛ
