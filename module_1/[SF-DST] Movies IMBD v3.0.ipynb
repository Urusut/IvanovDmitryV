# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from collections import Counter
#print(os.listdir("../input"))

import re
from itertools import product, combinations

# %%
#data = pd.read_csv('../input/imbd-sf/data.csv')
data = pd.read_csv('data.csv')
data.head(5)
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# 0              The park is open.
# 1             What a Lovely Day.
# 2     One Choice Can Destroy You
# 3  Every generation has a story.
# 4            Vengeance Hits Home
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
# 2  Beatrice Prior must confront her inner demons ...      119
# 3  Thirty years after defeating the Galactic Empi...      136
# 4  Deckard Shaw seeks revenge against Dominic Tor...      137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015        5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015        6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015        2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015        5292
# 4  Universal Pictures|Original Film|Media Rights ...     4/1/2015        2947
#
#    vote_average  release_year
# 0           6.5          2015
# 1           7.1          2015
# 2           6.3          2015
# 3           7.5          2015
# 4           7.3          2015

# %%
len(data)
# Out:
# 1890

# %% [markdown]
# # Предобработка датасета

# %%
columns_to_split = data.columns[data.apply(lambda x: x.str.contains('|',regex = False).any())]
data[columns_to_split] = data[columns_to_split].applymap(lambda x: x.split('|'))

# %%
answer_ls = [] # создадим список с ответами. сюда будем добавлять ответы по мере прохождения теста
# сюда можем вписать создание новых колонок в датасете

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?
# Варианты ответов:
# 1. The Dark Knight Rises (tt1345836)
# 2. Spider-Man 3 (tt0413300)
# 3. Avengers: Age of Ultron (tt2395427)
# 4. The Warrior's Way	(tt1032751)
# 5. Pirates of the Caribbean: On Stranger Tides (tt1298650)

# %%
data.original_title.loc[data.budget.idxmax()]
# Out:
# "The Warrior's Way"

# %%
# тут вводим ваш ответ и добавлем в его список ответов (сейчас для примера стоит "1")
answer_ls.append(4)

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)
# 1. The Lord of the Rings: The Return of the King	(tt0167260)
# 2. Gods and Generals	(tt0279111)
# 3. King Kong	(tt0360717)
# 4. Pearl Harbor	(tt0213149)
# 5. Alexander	(tt0346491)

# %%
data.original_title.loc[data.runtime.idxmax()]
# Out:
# 'Gods and Generals'

# %%
answer_ls.append(2)

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)
# Варианты ответов:
#
# 1. Home on the Range	tt0299172
# 2. The Jungle Book 2	tt0283426
# 3. Winnie the Pooh	tt1449283
# 4. Corpse Bride	tt0121164
# 5. Hoodwinked!	tt0443536

# %%
data.original_title.loc[data.runtime.idxmin()]
# Out:
# 'Winnie the Pooh'

# %%
answer_ls.append(3)

# %% [markdown]
# # 4. Средняя длительность фильма?
#
# Варианты ответов:
# 1. 115
# 2. 110
# 3. 105
# 4. 120
# 5. 100

# %%
round(data.runtime.mean())
# Out:
# 110

# %%
answer_ls.append(2)

# %% [markdown]
# # 5. Средняя длительность фильма по медиане?
# Варианты ответов:
# 1. 106
# 2. 112
# 3. 101
# 4. 120
# 5. 115

# %%
round(data.runtime.median())
# Out:
# 106

# %%
answer_ls.append(1)

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# Варианты ответов:
# 1. The Avengers	tt0848228
# 2. Minions	tt2293640
# 3. Star Wars: The Force Awakens	tt2488496
# 4. Furious 7	tt2820852
# 5. Avatar	tt0499549

# %%
data['profit'] = data.revenue - data.budget

# %%
data.original_title.loc[data.profit.idxmax()]
# Out:
# 'Avatar'

# %%
answer_ls.append(5)

# %% [markdown]
# # 7. Какой фильм самый убыточный?
# Варианты ответов:
# 1. Supernova tt0134983
# 2. The Warrior's Way tt1032751
# 3. Flushed Away	tt0424095
# 4. The Adventures of Pluto Nash	tt0180052
# 5. The Lone Ranger	tt1210819

# %%
data.original_title.loc[data.profit.idxmin()]
# Out:
# "The Warrior's Way"

# %%
answer_ls.append(2)

# %% [markdown]
# # 8. Сколько всего фильмов в прибыли?
# Варианты ответов:
# 1. 1478
# 2. 1520
# 3. 1241
# 4. 1135
# 5. 1398

# %%
(data.profit>0).sum()
# Out:
# 1478

# %%
answer_ls.append(1)

# %% [markdown]
# # 9. Самый прибыльный фильм в 2008 году?
# Варианты ответов:
# 1. Madagascar: Escape 2 Africa	tt0479952
# 2. Iron Man	tt0371746
# 3. Kung Fu Panda	tt0441773
# 4. The Dark Knight	tt0468569
# 5. Mamma Mia!	tt0795421

# %%
data2008 = data[data.release_year == 2008]
data2008.original_title.loc[data2008.profit.idxmax()]
# Out:
# 'The Dark Knight'

# %%
answer_ls.append(4)

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 (включительно)?
# Варианты ответов:
# 1. Winter's Tale	tt1837709
# 2. Stolen	tt1656186
# 3. Broken City	tt1235522
# 4. Upside Down	tt1374992
# 5. The Lone Ranger	tt1210819

# %%
data2012_2014 = data[data.release_year.isin([2012,2013,2014])]
data2012_2014.original_title.loc[data2012_2014.profit.idxmin()]
# Out:
# 'The Lone Ranger'

# %%
answer_ls.append(5)

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?
# Варианты ответов:
# 1. Action
# 2. Adventure
# 3. Drama
# 4. Comedy
# 5. Thriller

# %%
total_genres_list = data.genres.sum()

# %%
#%%time
pd.Series(total_genres_list).value_counts()[:1]
# Out:
# Drama    782
# dtype: int64

# %%
#%%time
Counter(total_genres_list).most_common(1) # <------------- побыстрее
# Out:
# [('Drama', 782)]

# %%
answer_ls.append(3)

# %% [markdown]
# # 12. Какого жанра среди прибыльных фильмов больше всего?
# Варианты ответов:
# 1. Drama
# 2. Comedy
# 3. Action
# 4. Thriller
# 5. Adventure

# %%
profit_movie = data.loc[data.profit> 0]
total_genres_list = profit_movie.genres.sum()
Counter(total_genres_list).most_common(1)[0][0]
# Out:
# 'Drama'

# %%
answer_ls.append(1)

# %% [markdown]
# # 13. Кто из режиссеров снял больше всего фильмов?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Ridley Scott
# 3. Steven Soderbergh
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
# %%time
directors_iter = Counter(data.director.sum())
dir_count = Counter()
for person, director in product(directors_iter,data.director):
    if person in director: dir_count[person] += 1
print(dir_count.most_common(1))
# Out:
# [('Steven Soderbergh', 13)]
# Wall time: 376 ms

# %%
def groupby_listfeature(df, by):
    result = pd.DataFrame(columns=df.columns)
    next_index = 0
    to_replace = []
    for df_ind in df.index:
        for list_ind, value in enumerate(df[by][df_ind]):
            result.loc[next_index] = df.loc[df_ind]
            next_index = result.index.max()+1
            to_replace.append(value)
    result[by] = to_replace    
    return result.groupby(by)

# %%
# %%time
groupby_listfeature(data[['director','imdb_id']],'director').count().idxmax()[0]
# А если после стирки не видно разницы, зачем платить больше?
# Out:
# Wall time: 4.69 s
# 'Steven Soderbergh'

# %%
answer_ls.append(3)

# %% [markdown]
# # 14. Кто из режиссеров снял больше всего Прибыльных фильмов?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Clint Eastwood
# 3. Steven Spielberg
# 4. Ridley Scott
# 5. Christopher Nolan

# %%
profit_movie =  data[['director','imdb_id']].loc[data.profit > 0]
groupby_listfeature(profit_movie,'director').count().idxmax()[0] # медленее, зато код короче и читабельнее
# Out:
# 'Ridley Scott'

# %%
answer_ls.append(4)

# %% [markdown]
# # 15. Кто из режиссеров принес больше всего прибыли?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Christopher Nolan
# 3. David Yates
# 4. James Cameron
# 5. Peter Jackson

# %%
#data['profit_per_director'] = data.profit/data.director.apply(len)

# %%
# %%time
directors_iter = Counter(data.director.sum())
profit_count = Counter()
for person in directors_iter:
    profit_count[person] = data.profit.loc[[person in directors for directors in data.director]].sum()   
print(profit_count.most_common(1)[0][0])          # быстрее, много букв
# Out:
# Peter Jackson
# Wall time: 521 ms

# %%
# %%time
print(groupby_listfeature(data[['director','profit']],'director').sum().idxmax()[0]) #медленне, читабельнее
# Out:
# Peter Jackson
# Wall time: 4.93 s

# %%
answer_ls.append(5)

# %% [markdown]
# # 16. Какой актер принес больше всего прибыли?
# Варианты ответов:
# 1. Emma Watson
# 2. Johnny Depp
# 3. Michelle Rodriguez
# 4. Orlando Bloom
# 5. Rupert Grint

# %%
actors = list(Counter(data.cast.sum()))
data['profit_per_actor'] = data.profit/data.cast.apply(len)

# %%
# %%time
actors_profit = Counter()
for actor in actors:
    actors_profit[actor] = data.profit[[actor in x for x in data.cast]].sum()
print(actors_profit.most_common(1)[0][0])
# Out:
# Emma Watson
# Wall time: 2.74 s

# %%
# %%time
print(groupby_listfeature(data[['cast','profit_per_actor']] ,'cast' ).sum().idxmax()[0])
# Out:
# Emma Watson
# Wall time: 22.4 s

# %%
answer_ls.append(1)

# %% [markdown]
# # 17. Какой актер принес меньше всего прибыли в 2012 году?
# Варианты ответов:
# 1. Nicolas Cage
# 2. Danny Huston
# 3. Kirsten Dunst
# 4. Jim Sturgess
# 5. Sami Gayle

# %%
data_2012 = data[data.release_year == 2012]

groupby_listfeature(data_2012[['cast','profit_per_actor']],'cast').sum().idxmin()[0]
# Out:
# 'Kirsten Dunst'

# %%
data_2012 = data[data.release_year == 2012]

groupby_listfeature(data_2012[['cast','profit']],'cast').sum().idxmin()[0]
# Out:
# 'Kirsten Dunst'

# %%
answer_ls.append(3)

# %% [markdown]
# # 18. Какой актер снялся в большем количестве высокобюджетных фильмов? (в фильмах где бюджет выше среднего по данной выборке)
# Варианты ответов:
# 1. Tom Cruise
# 2. Mark Wahlberg
# 3. Matt Damon
# 4. Angelina Jolie
# 5. Adam Sandler

# %%
high_budget_data = data[data.budget > data.budget.mean()]

groupby_listfeature(high_budget_data[['cast','imdb_id']],'cast').count().idxmax()[0]
# Out:
# 'Matt Damon'

# %%
answer_ls.append(3)

# %% [markdown]
# # 19. В фильмах какого жанра больше всего снимался Nicolas Cage?
# Варианты ответа:
# 1. Drama
# 2. Action
# 3. Thriller
# 4. Adventure
# 5. Crime

# %%
Counter(data[['Nicolas Cage' in x for x in data.cast]].genres.sum()).most_common(1)[0][0]
# Out:
# 'Action'

# %%
answer_ls.append(2)

# %% [markdown]
# # 20. Какая студия сняла больше всего фильмов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
Counter((data.production_companies.sum())).most_common(1)[0][0]
# Out:
# 'Universal Pictures'

# %%
answer_ls.append(1)

# %% [markdown]
# # 21. Какая студия сняла больше всего фильмов в 2015 году?
# Варианты ответа:
# 1. Universal Pictures
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
Counter( data[data.release_year == 2015].production_companies.sum()).most_common(1)[0][0]
# Out:
# 'Warner Bros.'

# %%
answer_ls.append(4)

# %% [markdown]
# # 22. Какая студия заработала больше всего денег в жанре комедий за все время?
# Варианты ответа:
# 1. Warner Bros
# 2. Universal Pictures (Universal)
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Walt Disney

# %%
comedy = data[['Comedy' in x for x in data.genres]]

# %%
groupby_listfeature(comedy[['production_companies','profit']] ,'production_companies').sum().idxmax()[0]
# Out:
# 'Universal Pictures'

# %%
data['profit_per_pc'] = data.profit / data.production_companies.apply(len)
comedy = data[['Comedy' in x for x in data.genres]]

groupby_listfeature(comedy[['production_companies','profit_per_pc']] ,'production_companies').sum().idxmax()[0]
# Out:
# 'Walt Disney Pictures'

# %%
answer_ls.append(2)

# %% [markdown]
# # 23. Какая студия заработала больше всего денег в 2012 году?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Lucasfilm

# %%
groupby_listfeature(data_2012[['production_companies','profit']], 'production_companies').sum().idxmax()[0]
# Out:
# 'Columbia Pictures'

# %%
data_2012 = data[data.release_year == 2012]

groupby_listfeature(data_2012[['production_companies','profit_per_pc']], 'production_companies').sum().idxmax()[0]
# Out:
# 'Columbia Pictures'

# %%
answer_ls.append(3)

# %% [markdown]
# # 24. Самый убыточный фильм от Paramount Pictures
# Варианты ответа:
#
# 1. K-19: The Widowmaker tt0267626
# 2. Next tt0435705
# 3. Twisted tt0315297
# 4. The Love Guru tt0811138
# 5. The Fighter tt0964517

# %%
data_ParPic = data[['Paramount Pictures' in x for x in data.production_companies]]
data_ParPic.loc[data_ParPic.profit.idxmin()].original_title
# Out:
# 'K-19: The Widowmaker'

# %%
answer_ls.append(1)

# %% [markdown]
# # 25. Какой Самый прибыльный год (заработали больше всего)?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2002
# 5. 2015

# %%
data.groupby('release_year').profit.sum().idxmax()
# Out:
# 2015

# %%
answer_ls.append(5)

# %% [markdown]
# # 26. Какой Самый прибыльный год для студии Warner Bros?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2010
# 5. 2015

# %%
data_WarBros = data[[pd.Series(['Warner B' in y for y in x]).any() for x in data.production_companies]]
data_WarBros.groupby('release_year').profit.sum().idxmax()
# Out:
# 2014

# %%
data_WarBros.groupby('release_year').profit_per_pc.sum().idxmax()
# Out:
# 2010

# %%
answer_ls.append(1)

# %% [markdown]
# # 27. В каком месяце за все годы суммарно вышло больше всего фильмов?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
data['release_month'] = pd.to_datetime(data.release_date).dt.month

data.groupby('release_month').imdb_id.count().idxmax()
# Out:
# 9

# %%
data.groupby(['release_month','release_year']).imdb_id.count().idxmax() # на всякий случай
# Out:
# (9, 2009)

# %%
answer_ls.append(4)

# %% [markdown]
# # 28. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)
# Варианты ответа:
# 1. 345
# 2. 450
# 3. 478
# 4. 523
# 5. 381

# %%
data [[x in [6,7,8] for x in data.release_month]].imdb_id.count()
# Out:
# 450

# %%
answer_ls.append(2)

# %% [markdown]
# # 29. Какой режисер выпускает (суммарно по годам) больше всего фильмов зимой?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Christopher Nolan
# 3. Clint Eastwood
# 4. Ridley Scott
# 5. Peter Jackson

# %%
# %%time
data_winter = data.query('release_month in [1,2,12]')
# Out:
# Wall time: 15 ms

# %%
# %%time
data_winter = data [[x in [1,2,12] for x in data.release_month]]
# Out:
# Wall time: 4 ms

# %%
groupby_listfeature(data_winter[['director','imdb_id']], 'director').count().idxmax()[0]
# Out:
# 'Peter Jackson'

# %%
answer_ls.append(5)

# %% [markdown]
# # 30. Какой месяц чаще всего по годам самый прибыльный?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
pivtab_year_month = data.pivot_table('profit', index= 'release_year', columns= 'release_month', aggfunc= sum)
pivtab_year_month.idxmax(axis=1).value_counts()
# Out:
# 6     7
# 12    4
# 5     4
# 7     1
# dtype: int64

# %%
answer_ls.append(3)

# %% [markdown]
# # 31. Названия фильмов какой студии в среднем самые длинные по количеству символов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
gruoppedby_pc = groupby_listfeature(data[['production_companies','original_title']],'production_companies')
gruoppedby_pc.original_title.apply(lambda x: len(x.sum())/x.count()).idxmax()
# Out:
# 'Four By Two Productions'

# %%
answer_ls.append(5)

# %% [markdown]
# # 32. Названия фильмов какой студии в среднем самые длинные по количеству слов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
gruoppedby_pc.original_title.apply(lambda x: 
                                   len(((x+" ").sum()).split(' '))
                                   /x.count()).idxmax()
# Out:
# 'Four By Two Productions'

# %%
answer_ls.append(5)

# %% [markdown]
# # 33. Сколько разных слов используется в названиях фильмов?(без учета регистра)
# Варианты ответа:
# 1. 6540
# 2. 1002
# 3. 2461
# 4. 28304
# 5. 3432

# %%
total_title_list = data.original_title.apply(lambda x: x+' ').sum().lower()

pattern = re.compile('(?![-])\S*')

len(pd.Series(pattern.findall(total_title_list)).unique())
# Out:
# 2461

# %%
answer_ls.append(3)

# %% [markdown]
# # 34. Какие фильмы входят в 1 процент лучших по рейтингу?
# Варианты ответа:
# 1. Inside Out, Gone Girl, 12 Years a Slave
# 2. BloodRayne, The Adventures of Rocky & Bullwinkle
# 3. The Lord of the Rings: The Return of the King
# 4. 300, Lucky Number Slevin

# %%
percent_99 = np.percentile(data.vote_average,99)
data.original_title[data.vote_average > percent_99]
# Out:
# 9                                          Inside Out
# 34                                               Room
# 118                                      Interstellar
# 119                           Guardians of the Galaxy
# 125                                The Imitation Game
# 128                                         Gone Girl
# 138                          The Grand Budapest Hotel
# 370                                         Inception
# 600                                   The Dark Knight
# 873                                       The Pianist
# 1082    The Lord of the Rings: The Return of the King
# 1184                          The Wolf of Wall Street
# 1192                                 12 Years a Slave
# 1801                                          Memento
# Name: original_title, dtype: object

# %%
data.original_title.loc[data.vote_average.sort_values(ascending = False)[:int(0.01*(len(data)))].index].sort_index()
# Out:
# 9                                          Inside Out
# 28                                          Spotlight
# 34                                               Room
# 118                                      Interstellar
# 119                           Guardians of the Galaxy
# 125                                The Imitation Game
# 128                                         Gone Girl
# 138                          The Grand Budapest Hotel
# 177                            The Fault in Our Stars
# 283                                        Mr. Nobody
# 370                                         Inception
# 600                                   The Dark Knight
# 864             The Lord of the Rings: The Two Towers
# 873                                       The Pianist
# 1082    The Lord of the Rings: The Return of the King
# 1184                          The Wolf of Wall Street
# 1192                                 12 Years a Slave
# 1801                                          Memento
# Name: original_title, dtype: object

# %%
answer_ls.append(1)

# %% [markdown]
# # 35. Какие актеры чаще всего снимаются в одном фильме вместе
# Варианты ответа:
# 1. Johnny Depp & Helena Bonham Carter
# 2. Hugh Jackman & Ian McKellen
# 3. Vin Diesel & Paul Walker
# 4. Adam Sandler & Kevin James
# 5. Daniel Radcliffe & Rupert Grint

# %%
colleagues_count  = Counter()
for cast in data.cast:
    for one, another in list(combinations(cast, 2)):
        colleagues_count[sorted([one,another])[0] +' + ' + sorted([one,another])[1]] += 1
        
colleagues_count.most_common(1)
# Out:
# [('Daniel Radcliffe + Rupert Grint', 8)]

# %%
answer_ls.append(5)

# %% [markdown]
# # 36. У какого из режиссеров выше вероятность выпустить фильм в прибыли? (5 баллов)101
# Варианты ответа:
# 1. Quentin Tarantino
# 2. Steven Soderbergh
# 3. Robert Rodriguez
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
grouppedby_director = groupby_listfeature(data[['director','profit']],'director')

grouppedby_director.apply(lambda x:(x.profit > 0).sum()/x.profit.count())[
['Quentin Tarantino',
'Steven Soderbergh',
'Robert Rodriguez',
'Christopher Nolan',
'Clint Eastwood']].idxmax()
# Out:
# 'Christopher Nolan'

# %%
answer_ls.append(4)

# %% [markdown]
# # Submission

# %%
len(answer_ls)
# Out:
# 36

# %%
pd.DataFrame({'Id':range(1,len(answer_ls)+1), 'Answer':answer_ls}, columns=['Id', 'Answer'])
# Out:
#     Id  Answer
# 0    1       4
# 1    2       2
# 2    3       3
# 3    4       2
# 4    5       1
# 5    6       5
# 6    7       2
# 7    8       1
# 8    9       4
# 9   10       5
# 10  11       3
# 11  12       1
# 12  13       3
# 13  14       4
# 14  15       5
# 15  16       1
# 16  17       3
# 17  18       3
# 18  19       2
# 19  20       1
# 20  21       4
# 21  22       2
# 22  23       3
# 23  24       1
# 24  25       5
# 25  26       1
# 26  27       4
# 27  28       2
# 28  29       5
# 29  30       3
# 30  31       5
# 31  32       5
# 32  33       3
# 33  34       1
# 34  35       5
# 35  36       4
